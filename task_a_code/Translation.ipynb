# %%
import googletrans
import numpy as np
import imblearn
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
print(googletrans.LANGUAGES)
# Out:
# {'af': 'afrikaans', 'sq': 'albanian', 'am': 'amharic', 'ar': 'arabic', 'hy': 'armenian', 'az': 'azerbaijani', 'eu': 'basque', 'be': 'belarusian', 'bn': 'bengali', 'bs': 'bosnian', 'bg': 'bulgarian', 'ca': 'catalan', 'ceb': 'cebuano', 'ny': 'chichewa', 'zh-cn': 'chinese (simplified)', 'zh-tw': 'chinese (traditional)', 'co': 'corsican', 'hr': 'croatian', 'cs': 'czech', 'da': 'danish', 'nl': 'dutch', 'en': 'english', 'eo': 'esperanto', 'et': 'estonian', 'tl': 'filipino', 'fi': 'finnish', 'fr': 'french', 'fy': 'frisian', 'gl': 'galician', 'ka': 'georgian', 'de': 'german', 'el': 'greek', 'gu': 'gujarati', 'ht': 'haitian creole', 'ha': 'hausa', 'haw': 'hawaiian', 'iw': 'hebrew', 'he': 'hebrew', 'hi': 'hindi', 'hmn': 'hmong', 'hu': 'hungarian', 'is': 'icelandic', 'ig': 'igbo', 'id': 'indonesian', 'ga': 'irish', 'it': 'italian', 'ja': 'japanese', 'jw': 'javanese', 'kn': 'kannada', 'kk': 'kazakh', 'km': 'khmer', 'ko': 'korean', 'ku': 'kurdish (kurmanji)', 'ky': 'kyrgyz', 'lo': 'lao', 'la': 'l
# ...

# %%
tam_train = pd.read_table("../datasets/task_a/tam_sentiment_train.tsv")

# %%
neg = tam_train[tam_train['category'] == 'Negative']

neg
# Out:
#                                                     text  category
# 4                            நம்ப நடே நாசாமா தான் போச்சி  Negative
# 9      Wow! Back to Baasha mode..thalaivaaaa.petta pa...  Negative
# 25              ayyayyo . sruthihassan     . ellame poch  Negative
# 51     எந்தெந்த youtube channel காரங்க எல்லாம் இதை ஜா...  Negative
# 53     Dai pundaikku poranthavane ni la vijay anna va...  Negative
# ...                                                  ...       ...
# 35618  Enna ya idhu trailar la  ye beedhi ya kelapure...  Negative
# 35637  @Memecreator . நிறைய விசயம் இருக்கும் போலயே வை...  Negative
# 35645             Idhu puratchi padam ah flop confirm da  Negative
# 35650          awesome ya  no. Words mass mass paka mass  Negative
# 35653  yeevanikuachu  pula kutti erudhal oodi poyidu....  Negative
#
# [4271 rows x 2 columns]

# %%
neg_tam = neg['text']
neg_tam = neg_tam.tolist()

# %%
kan_train = pd.read_table("../datasets/task_a/kan_sentiment_train.tsv")

# %%
kan_train['category'].value_counts(
)
# Out:
# Positive          2823
# Negative          1188
# not-Kannada        916
# unknown state      711
# Mixed feelings     574
# Name: category, dtype: int64

# %%
1750-1188
# Out:
# 562

# %%
from random import sample
neg_tam_sample = sample(neg_tam,562)
neg_tam_sample
# Out:
# ['Yeppavathu kathuna parava illeEppavume kathikittu iruntha eppadi da??',
#  'yov sathiama indha manushanuku vayasu aguma agadha ya ... pullarikudhu ya ivara pathale 🤘',
#  'Ghatiya just like cartoon movie ......',
#  'Poda punda part 1 Kum ithukum Enada sambantam',
#  'Idhu orru pundai teaser idhukku vandhutainga okkurathuku  Pundai kullans fans pundai modikittu irru   Always sivakarthikeyan is best Surya thevudiya payiya',
#  'சொந்தமா போட போக்கத்தவன் தான் அடுத்தவன் பாட்ட எடுத்து போட்டுப்பான்னு 96க்கு சொன்னீங்களேய்யா!"  "ஏய்! இங்காரு! இந்த பய போட்டுருக்குற பீத்தோவன் மியூசிக்குக்கும் எனக்கும் எந்த சம்பந்தமும் இல்ல"',
#  'Gotha. Edhuk da avlo sound neenga pesuradhu kekkala',
#  'பரதன் விக்கு வெச்சிட்டானாம்   அங்க சிவானு ஒருத்தன் வாயில வெச்சினு  இருக்கான்  அதெல்லாம் கேக்க மாட்டானுவ',
#  'Trailer mayiru madhiri iruku aamai nakkis',
#  'Kala pathamadhiri irukku solra alavukku illa',
# ...

# %%
neg_tam_sample[0]
# Out:
# 'Ivlo kevalama va dance panirukanga. Asinga paduthava da padam edukurenga'

# %%
translator = Translator()

neg_kan = []
for i in range(len(neg_tam_sample)):
    result = translator.translate(neg_tam_sample[i], src ='ta', dest = 'kn')
    neg_kan.append(result.text)

# %%
neg_kan = pd.DataFrame(neg_kan)

# %%
neg_kan.rename(columns={0: "text"}, inplace=True)

# %%
neg_kan['category'] ='Negative'

# %%
neg_kan
# Out:
#                                                   text  category
# 0                  ಅದು ಹರಡಲು ನೀವು ಹೇಗೆ ಕಾಯುತ್ತಿದ್ದೀರಿ?  Negative
# 1    yov sathiama indha manushanuku vayasu aguma ag...  Negative
# 2         ಜಸ್ಟ್ ಲೈಕ್ ಕಾರ್ಟೂನ್ ಮೊವೇಯಿಂದ ತೋರಿಸಲಾಗಿದೆ …….  Negative
# 3       ಬೋಡಾ ಪುಂಡೈ ಭಾಗ 1 ಕ್ಕೂ ಇದಕ್ಕೂ ಯಾವುದೇ ಸಂಬಂಧವಿಲ್ಲ  Negative
# 4    ಇದು ಪುಂಡೈ ಟೀಸರ್ ಇಲ್ಲಿ ಬಂದು ಕೇಳಿ ಪುಂಡೈ ಕಲ್ಲೆನ್ಸ...  Negative
# ..                                                 ...       ...
# 557               ಜಾತಿ ಕು ಎನ್ ಪುಂಡಯ ವೈಕ ಪೊಂಗ ದ ದೇಯಿ 🤣🤣  Negative
# 558        ಹ್ಯಾರಿಸ್, ನೀವು ಯಾಕೆ ಸಂಗೀತ ನುಡಿಸುತ್ತಿದ್ದೀರಿ?  Negative
# 559         ಇಷ್ಟಪಡದಿರಲು ಪನ್ನವೆ ರಥಂ ಕಾಕ್ಕಿ ದಾದಾ ಉಳಿತಾಯ🤣  Negative
# 560  ನಿವೇತಾ ಪೇತುರಾಜ್ ಎಲ್ಲಿ.. ಹಸುವನ್ನು ಸೀನ್ ನಲ್ಲಿ ಹಾ...  Negative
# 561                                       ಯುದ್ಧದ ಆರಂಭ.  Negative
#
# [562 rows x 2 columns]

# %%
kan_train = kan_train.append(neg_kan)

# %%
kan_train['category'].value_counts()
# Out:
# Positive          2823
# Negative          1750
# not-Kannada        916
# unknown state      711
# Mixed feelings     574
# Name: category, dtype: int64

# %%
kan_train.to_csv('kan_train_small_negative_augmented.tsv', sep="\t", index = False)
