# %%
## for data
import json
import pandas as pd
import numpy as np
## for plotting
import matplotlib.pyplot as plt
import seaborn as sns
## for processing
import re
import nltk
## for bag-of-words
from sklearn import metrics, feature_extraction, feature_selection, model_selection, naive_bayes, pipeline, manifold, preprocessing
## for explainer
from lime import lime_text

## for deep learning
from tensorflow.keras import models, layers, preprocessing as kprocessing
from tensorflow.keras import backend as K
import torch

## for bert language model
import transformers
from transformers import AutoTokenizer, AutoModel

# %%
''' The following shows the result of training various non-neural network models on a transliterated
version of the Kannada set. models are trained on an bert vectorizer'''
# Out:
# ' The following shows the result of training various non-neural network models on a transliterated\nversion of the Kannada set. models are trained on an bert vectorizer'

# %%
# import data
kan_train = pd.read_table("../../datasets/task_a/kan_sentiment_train.tsv")
kan_dev = pd.read_table("../../datasets/task_a/kan_sentiment_dev.tsv")

# %%
kan_train = kan_train.rename(columns={'category': 'y'})
kan_dev = kan_dev.rename(columns={'category': 'y'})

# %%
kan_dev
# Out:
#                                                   text               y
# 0    Binduge saryagi ugithidira good go ahead  we a...  Mixed feelings
# 1                               yen song guru ...super        Positive
# 2                                     my fevorat story     not-Kannada
# 3                                    Super ತೋಗರಿ ತೀಪ್ಪ        Positive
# 4    ನಿಮ್ಮ ಮಾತುಗಳು ಅಕ್ಷರಶಃ ಸತ್ಯ... ನಿಮ್ಮ ಈ ಸಾಮಾನ್ಯ ...        Positive
# ..                                                 ...             ...
# 686  @Nandi Parthasarathi ನಿಮ್ಮ ಅಪ್ಪ ದೊಡ್ ಗಾಂಡು ಸೂಳೆಮಗ        Negative
# 687                               Hugi guru badethawke        Negative
# 688                                  Trending no.1 wow        Positive
# 689  @Troll Stupid Fans naanu adikke kano helthirod...        Positive
# 690  @JustAn Opinion ninu Tika mucchu...Evattu Kann...        Positive
#
# [691 rows x 2 columns]

# %%
fig, ax = plt.subplots()
fig.suptitle("y", fontsize=12)
kan_train.groupby("y").count().plot(kind="barh", legend=False, 
        ax=ax).grid(axis='x')
plt.show()

# %%
# transliterate all data from english scrip to kannada script
from indictrans import Transliterator

# instantiate the trasnliteration
trn = Transliterator(source='eng', target='kan', build_lookup=True)

# save the text column as a list in order to improve performance.
orig_kn_train = (kan_train['text'].to_numpy()).tolist()

# create and empty list, iterate through the list of text and append the transliterated text to our list.
list_trans = []
for i in range(len(orig_kn_train)):
    list_trans.append(trn.transform(orig_kn_train[i]))
    
# append the transliterated texts as a column on original dataframe
kan_train['text_trans'] = list_trans

# %%
# do the same for the dev data
# save the text column as a list in order to improve performance.
orig_kn_dev = (kan_dev['text'].to_numpy()).tolist()

# create and empty list, iterate through the list of text and append the transliterated text to our list.
list_trans_dev = []
for i in range(len(orig_kn_dev)):
    list_trans_dev.append(trn.transform(orig_kn_dev[i]))
    
# append the transliterated texts as a column on original dataframe
kan_dev['text_trans'] = list_trans_dev

# %%
kan_train
# Out:
#                                                    text               y  \
# 0     ಒಂದು ದೇಶದ ಮುಂದುವರಿಯುವುದು ಅದರ ಆರ್ಥಿಕ ಸ್ಥಿತಿಯನ್ನ...        Negative
# 1     ಕನ್ನಡದಲ್ಲಿ ಡೈಲಿ ಟೆಕ್ ಅಪ್ಡೇಟ್ಸ್ ಪಡೆಯಲು ಸಬ್ಸ್ಕ್ರ...        Positive
# 2                                        Super sar song     not-Kannada
# 3     Tiktokers present situation... nನೋಡುವವರು ಯಾರು ...        Negative
# 4                             Super ಸಾಂಗ್ ವೆರಿ ನೈಸ್....        Positive
# ...                                                 ...             ...
# 6207  @A.R.W   tumbad tanhaji andhadhun aise bahot h...     not-Kannada
# 6208                  പൊളി ഡാൻസ്🥰 രക്ഷിത് ഷെട്ടി മാസ്സ്     not-Kannada
# 6209  Bro...nNeen este Roast madudru...China ne beku...        Negative
# 6210  ಕೌಶಲ್ಯ ಇದ್ದವರ ಸಂಖ್ಯೆ ಕಡಿಮೆ ಇಲ್ಲ ಸರ್ ತುಂಬಾ ಪ್ರತ...        Positive
# 6211                                         26 M Views  Mixed feelings
#
#                                              text_trans
# 0     ಒಂದು ದೇಶದ ಮುಂದುವರಿಯುವುದು ಅದರ ಆರ್ಥಿಕ ಸ್ಥಿತಿಯನ್ನ...
# 1     ಕನ್ನಡದಲ್ಲಿ ಡೈಲಿ ಟೆಕ್ ಅಪ್ಡೇಟ್ಸ್ ಪಡೆಯಲು ಸಬ್ಸ್ಕ್ರ...
# 2                                       ಸುಪರ್ ಸಾರ ಸೋಂಗ್
# 3     ಟೀಕ್ಟೋಕರ್ಸ್ ಪ್ರಸೇಂಟ್ ಸಿತುಂಏಶನ್... ನನೋಡುವವರು ಯಾ...
# 4                             ಸುಪರ್ ಸಾಂಗ್ ವೆರಿ ನೈಸ್....
# ...                                                 ...
# 6207  @ಆ.ರ.ವ್   ಟುಂಬಾದ್ ತನ್ಹಾಜಿ ಅಂಧಾಧುನ ಐಸೆ ಬಹೋತ ಹೈ ...
# 6208                  പൊളി ഡാൻസ്🥰 രക്ഷിത് ഷെട്ടി മാസ്സ്
# 6209  ಬ್ರೊ...ನ್ನೀನ್ ಎಸ್ಟೆ ರೋಸ್ತ ಮದುದ್ರು...ಚೀನಾ ನೇ ಬೇ...
# 6210  ಕೌಶಲ್ಯ ಇದ್ದವರ ಸಂಖ್ಯೆ ಕಡಿಮೆ ಇಲ್ಲ ಸರ್ ತುಂಬಾ ಪ್ರತ...
# 6211                                         26 ಮ ವಿಊಸ್
#
# [6212 rows x 3 columns]

# %%
# Now we can define our training data and our dev data as well as targets
train = kan_train
test = kan_dev

y_train = kan_train['y'].values
y_test = kan_dev['y'].values

# %% [markdown]
# # Gettint text embeddings from the bert model

# %%
# I'll be using the embeddings from the multilinngual bert model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

tokenizer = AutoTokenizer.from_pretrained('bert-base-multilingual-uncased')
model = AutoModel.from_pretrained('bert-base-multilingual-uncased').to(device)
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-uncased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# We will start by gathering the embeddings for the validation set
cls_val_list = []
batch_size = 1000

for batch_number, batch_test in test.groupby(np.arange(len(test)) // batch_size):
    # tokanizing the text
    tokenized_val = tokenizer(batch_test["text_trans"].values.tolist() , padding = 'max_length', truncation = True,  return_tensors="pt", max_length=256)

    # move on device (GPU)
    tokenized_val = {k:torch.tensor(v).to(device) for k,v in tokenized_val.items()}

    # get the cls hidden state
    with torch.no_grad():
        hidden_val = model(**tokenized_val)
            
    #get only the [CLS] hidden states
    cls_val = hidden_val.last_hidden_state[:,0,:]
    cls_val = cls_val.to("cpu")
    cls_val_list.append(cls_val)
    del cls_val
    del hidden_val
    del tokenized_val
    
    torch.cuda.empty_cache()

cls_val_list_final = []
for i in range(len(cls_val_list)):
    for j in range(len(cls_val_list[i])):
        cls_val_list_final.append(cls_val_list[i][j])
# Out:
# /home/ubuntu/pyenv/lib/python3.6/site-packages/ipykernel_launcher.py:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   # Remove the CWD from sys.path while we load stuff.

# %%
# Get embeddigns for the trainins set
cls_train_list = []
batch_size = 1000

for batch_number, batch_train in train.groupby(np.arange(len(train)) // batch_size):
    # tokanizing the text
    tokenized_train = tokenizer(batch_train["text_trans"].values.tolist() , padding = 'max_length', truncation = True,  return_tensors="pt", max_length=256)

    # move on device (GPU)
    tokenized_train = {k:torch.tensor(v).to(device) for k,v in tokenized_train.items()}

    # get the cls hidden state
    with torch.no_grad():
        hidden_train = model(**tokenized_train)
            
    #get only the [CLS] hidden states
    cls_train = hidden_train.last_hidden_state[:,0,:]
    cls_train = cls_train.to("cpu")
    cls_train_list.append(cls_train)
    del cls_train
    del hidden_train
    del tokenized_train
    
    torch.cuda.empty_cache()

cls_train_list_final = []
for i in range(len(cls_train_list)):
    for j in range(len(cls_train_list[i])):
        cls_train_list_final.append(cls_train_list[i][j])
# Out:
# /home/ubuntu/pyenv/lib/python3.6/site-packages/ipykernel_launcher.py:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   # Remove the CWD from sys.path while we load stuff.

# %%
# Move the poutput embeddigns for the trainign and validation sets into a dataframe
X_train = torch.stack(cls_train_list_final)
X_train = pd.DataFrame(X_train)

X_test = torch.stack(cls_val_list_final)
X_test = pd.DataFrame(X_test)

y_train = kan_train['y'].values
y_test = kan_dev['y'].values

# %% [markdown]
# # Training a cat boost classifier

# %%
from catboost import CatBoostClassifier
cat = CatBoostClassifier(iterations=100, learning_rate=.5)

# %%
## train classifier
cat.fit(X_train, y_train)
predicted = cat.predict(X_test)

predicted_prob = cat.predict_proba(X_test)
# Out:
# 0:	learn: 1.4059978	total: 544ms	remaining: 53.9s
# 1:	learn: 1.3194401	total: 919ms	remaining: 45s
# 2:	learn: 1.2677118	total: 1.27s	remaining: 41.1s
# 3:	learn: 1.2363162	total: 1.63s	remaining: 39s
# 4:	learn: 1.2030683	total: 2s	remaining: 37.9s
# 5:	learn: 1.1769793	total: 2.35s	remaining: 36.9s
# 6:	learn: 1.1610472	total: 2.72s	remaining: 36.1s
# 7:	learn: 1.1453975	total: 3.06s	remaining: 35.2s
# 8:	learn: 1.1303130	total: 3.42s	remaining: 34.6s
# 9:	learn: 1.1177263	total: 3.78s	remaining: 34s
# 10:	learn: 1.1059886	total: 4.12s	remaining: 33.3s
# 11:	learn: 1.0918153	total: 4.48s	remaining: 32.9s
# 12:	learn: 1.0776521	total: 4.84s	remaining: 32.4s
# 13:	learn: 1.0637195	total: 5.2s	remaining: 31.9s
# 14:	learn: 1.0528360	total: 5.55s	remaining: 31.5s
# 15:	learn: 1.0391300	total: 5.92s	remaining: 31.1s
# 16:	learn: 1.0272460	total: 6.28s	remaining: 30.6s
# 17:	learn: 1.0163079	total: 6.63s	remaining: 30.2s
# 18:	learn: 1.0060969	total: 6.97s	remaining: 29.7s
# 19:	learn: 0.9928132	total: 7.34s	remaining: 29.4s
# 20:	learn: 0.9833559	total: 7.7s	remaining: 29s
# 21:	learn: 0.9743222	total: 8.04s	remaining: 28.5s
# 22:	learn: 0.9599616	total: 8.39s	remaining: 28.1s
# 23:	learn: 0.9479241	total: 8.74s	remaining: 27.7s
# 24:	learn: 0.9394110	total: 9.09s	remaining: 27.3s
# 25:	learn: 0.9264904	total: 9.45s	remaining: 26.9s
# 26:	learn: 0.9166054	total: 9.8s	remaining: 26.5s
# 27:	learn: 0.9067725	total: 10.2s	remaining: 26.1s
# 28:	learn: 0.8939009	total: 10.5s	remaining: 25.7s
# 29:	learn: 0.8852019	total: 10.9s	remaining: 25.3s
# 30:	learn: 0.8784806	total: 11.2s	remaining: 24.9s
# 31:	learn: 0.8685505	total: 11.5s	remaining: 24.5s
# 32:	learn: 0.8554085	total: 11.9s	remaining: 24.2s
# 33:	learn: 0.8467390	total: 12.3s	remaining: 23.8s
# 34:	learn: 0.8342810	total: 12.6s	remaining: 23.5s
# 35:	learn: 0.8270375	total: 13s	remaining: 23.1s
# 36:	learn: 0.8204650	total: 13.3s	remaining: 22.7s
# 37:	learn: 0.8088364	total: 13.7s	remaining: 22.4s
# 38:	learn: 0.8059153	total: 14.1s	remaining: 22s
# 39:	learn: 0.7969703	total: 14.4s	remaining: 21.6s
# 40:	learn: 0.7887075	total: 14.8s	remaining: 21.3s
# 41:	learn: 0.7822196	total: 15.1s	remaining: 20.9s
# 42:	learn: 0.7757258	total: 15.5s	remaining: 20.5s
# 43:	learn: 0.7665757	total: 15.8s	remaining: 20.2s
# 44:	learn: 0.7603071	total: 16.2s	remaining: 19.8s
# 45:	learn: 0.7527310	total: 16.5s	remaining: 19.4s
# 46:	learn: 0.7457029	total: 16.9s	remaining: 19s
# 47:	learn: 0.7389152	total: 17.2s	remaining: 18.7s
# 48:	learn: 0.7325519	total: 17.6s	remaining: 18.3s
# 49:	learn: 0.7261567	total: 17.9s	remaining: 17.9s
# 50:	learn: 0.7182328	total: 18.3s	remaining: 17.6s
# 51:	learn: 0.7121924	total: 18.6s	remaining: 17.2s
# 52:	learn: 0.7051709	total: 19s	remaining: 16.9s
# 53:	learn: 0.6976800	total: 19.4s	remaining: 16.5s
# 54:	learn: 0.6910521	total: 19.7s	remaining: 16.1s
# 55:	learn: 0.6842555	total: 20.1s	remaining: 15.8s
# 56:	learn: 0.6796368	total: 20.4s	remaining: 15.4s
# 57:	learn: 0.6751608	total: 20.8s	remaining: 15s
# 58:	learn: 0.6700150	total: 21.1s	remaining: 14.7s
# 59:	learn: 0.6664485	total: 21.5s	remaining: 14.3s
# 60:	learn: 0.6593893	total: 21.8s	remaining: 14s
# 61:	learn: 0.6532078	total: 22.2s	remaining: 13.6s
# 62:	learn: 0.6476074	total: 22.5s	remaining: 13.2s
# 63:	learn: 0.6406527	total: 22.9s	remaining: 12.9s
# 64:	learn: 0.6352216	total: 23.2s	remaining: 12.5s
# 65:	learn: 0.6305141	total: 23.6s	remaining: 12.1s
# 66:	learn: 0.6221971	total: 23.9s	remaining: 11.8s
# 67:	learn: 0.6175327	total: 24.3s	remaining: 11.4s
# 68:	learn: 0.6138348	total: 24.6s	remaining: 11.1s
# 69:	learn: 0.6101381	total: 25s	remaining: 10.7s
# 70:	learn: 0.6035943	total: 25.3s	remaining: 10.3s
# 71:	learn: 0.5985034	total: 25.7s	remaining: 9.98s
# 72:	learn: 0.5949104	total: 26s	remaining: 9.63s
# 73:	learn: 0.5902625	total: 26.4s	remaining: 9.26s
# 74:	learn: 0.5875386	total: 26.7s	remaining: 8.9s
# 75:	learn: 0.5844684	total: 27.1s	remaining: 8.54s
# 76:	learn: 0.5784515	total: 27.4s	remaining: 8.19s
# 77:	learn: 0.5742556	total: 27.8s	remaining: 7.83s
# 78:	learn: 0.5702624	total: 28.1s	remaining: 7.47s
# 79:	learn: 0.5655035	total: 28.5s	remaining: 7.12s
# 80:	learn: 0.5620227	total: 28.8s	remaining: 6.76s
# 81:	learn: 0.5590639	total: 29.1s	remaining: 6.4s
# 82:	learn: 0.5561137	total: 29.5s	remaining: 6.04s
# 83:	learn: 0.5509591	total: 29.8s	remaining: 5.68s
# 84:	learn: 0.5443203	total: 30.2s	remaining: 5.33s
# 85:	learn: 0.5414609	total: 30.6s	remaining: 4.97s
# 86:	learn: 0.5376227	total: 30.9s	remaining: 4.62s
# 87:	learn: 0.5337907	total: 31.3s	remaining: 4.26s
# 88:	learn: 0.5296726	total: 31.6s	remaining: 3.91s
# 89:	learn: 0.5270916	total: 32s	remaining: 3.55s
# 90:	learn: 0.5221618	total: 32.3s	remaining: 3.2s
# 91:	learn: 0.5182078	total: 32.7s	remaining: 2.84s
# 92:	learn: 0.5138599	total: 33s	remaining: 2.48s
# 93:	learn: 0.5100643	total: 33.4s	remaining: 2.13s
# 94:	learn: 0.5082297	total: 33.7s	remaining: 1.77s
# 95:	learn: 0.5035719	total: 34s	remaining: 1.42s
# 96:	learn: 0.5000899	total: 34.4s	remaining: 1.06s
# 97:	learn: 0.4941056	total: 34.8s	remaining: 709ms
# 98:	learn: 0.4916487	total: 35.1s	remaining: 354ms
# 99:	learn: 0.4899122	total: 35.4s	remaining: 0us

# %%
# lets see our model performance
classes = np.unique(y_test)
y_test_array = pd.get_dummies(y_test, drop_first=False).values
    
## Accuracy, Precision, Recall
accuracy = metrics.accuracy_score(y_test, predicted)
auc = metrics.roc_auc_score(y_test, predicted_prob, 
                            multi_class="ovr")
print("Accuracy:",  round(accuracy,2))
print("Auc:", round(auc,2))
print("Detail:")
print(metrics.classification_report(y_test, predicted))
    
## Plot confusion matrix
cm = metrics.confusion_matrix(y_test, predicted)
fig, ax = plt.subplots()
sns.heatmap(cm, annot=True, fmt='d', ax=ax, cmap=plt.cm.Blues, 
            cbar=False)
ax.set(xlabel="Pred", ylabel="True", xticklabels=classes, 
       yticklabels=classes, title="Confusion matrix")
plt.yticks(rotation=0)

fig, ax = plt.subplots(nrows=1, ncols=2)
## Plot roc
for i in range(len(classes)):
    fpr, tpr, thresholds = metrics.roc_curve(y_test_array[:,i],  
                           predicted_prob[:,i])
    ax[0].plot(fpr, tpr, lw=3, 
              label='{0} (area={1:0.2f})'.format(classes[i], 
                              metrics.auc(fpr, tpr))
               )
ax[0].plot([0,1], [0,1], color='navy', lw=3, linestyle='--')
ax[0].set(xlim=[-0.05,1.0], ylim=[0.0,1.05], 
          xlabel='False Positive Rate', 
          ylabel="True Positive Rate (Recall)", 
          title="Receiver operating characteristic")
ax[0].legend(loc="lower right")
ax[0].grid(True)
    
## Plot precision-recall curve
for i in range(len(classes)):
    precision, recall, thresholds = metrics.precision_recall_curve(
                 y_test_array[:,i], predicted_prob[:,i])
    ax[1].plot(recall, precision, lw=3, 
               label='{0} (area={1:0.2f})'.format(classes[i], 
                                  metrics.auc(recall, precision))
              )
ax[1].set(xlim=[0.0,1.05], ylim=[0.0,1.05], xlabel='Recall', 
          ylabel="Precision", title="Precision-Recall curve")
ax[1].legend(loc="best")
ax[1].grid(True)
plt.show()
# Out:
# Accuracy: 0.53
# Auc: 0.76
# Detail:
#                 precision    recall  f1-score   support
#
# Mixed feelings       0.19      0.08      0.11        52
#       Negative       0.48      0.43      0.45       139
#       Positive       0.59      0.74      0.65       321
#    not-Kannada       0.56      0.47      0.51       110
#  unknown state       0.35      0.23      0.28        69
#
#       accuracy                           0.53       691
#      macro avg       0.43      0.39      0.40       691
#   weighted avg       0.51      0.53      0.51       691

# %% [markdown]
# # Training a Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(max_depth=150, n_estimators=15, max_features=768)

# %%
## train classifier
forest.fit(X_train, y_train)
## test
predicted = forest.predict(X_test)
predicted_prob = forest.predict_proba(X_test)

# %%
# lets see our model performance
classes = np.unique(y_test)
y_test_array = pd.get_dummies(y_test, drop_first=False).values
    
## Accuracy, Precision, Recall
accuracy = metrics.accuracy_score(y_test, predicted)
auc = metrics.roc_auc_score(y_test, predicted_prob, 
                            multi_class="ovr")
print("Accuracy:",  round(accuracy,2))
print("Auc:", round(auc,2))
print("Detail:")
print(metrics.classification_report(y_test, predicted))
    
## Plot confusion matrix
cm = metrics.confusion_matrix(y_test, predicted)
fig, ax = plt.subplots()
sns.heatmap(cm, annot=True, fmt='d', ax=ax, cmap=plt.cm.Blues, 
            cbar=False)
ax.set(xlabel="Pred", ylabel="True", xticklabels=classes, 
       yticklabels=classes, title="Confusion matrix")
plt.yticks(rotation=0)

fig, ax = plt.subplots(nrows=1, ncols=2)
## Plot roc
for i in range(len(classes)):
    fpr, tpr, thresholds = metrics.roc_curve(y_test_array[:,i],  
                           predicted_prob[:,i])
    ax[0].plot(fpr, tpr, lw=3, 
              label='{0} (area={1:0.2f})'.format(classes[i], 
                              metrics.auc(fpr, tpr))
               )
ax[0].plot([0,1], [0,1], color='navy', lw=3, linestyle='--')
ax[0].set(xlim=[-0.05,1.0], ylim=[0.0,1.05], 
          xlabel='False Positive Rate', 
          ylabel="True Positive Rate (Recall)", 
          title="Receiver operating characteristic")
ax[0].legend(loc="lower right")
ax[0].grid(True)
    
## Plot precision-recall curve
for i in range(len(classes)):
    precision, recall, thresholds = metrics.precision_recall_curve(
                 y_test_array[:,i], predicted_prob[:,i])
    ax[1].plot(recall, precision, lw=3, 
               label='{0} (area={1:0.2f})'.format(classes[i], 
                                  metrics.auc(recall, precision))
              )
ax[1].set(xlim=[0.0,1.05], ylim=[0.0,1.05], xlabel='Recall', 
          ylabel="Precision", title="Precision-Recall curve")
ax[1].legend(loc="best")
ax[1].grid(True)
plt.show()
# Out:
# Accuracy: 0.55
# Auc: 0.71
# Detail:
#                 precision    recall  f1-score   support
#
# Mixed feelings       0.12      0.04      0.06        52
#       Negative       0.53      0.45      0.49       139
#       Positive       0.58      0.81      0.68       321
#    not-Kannada       0.54      0.34      0.41       110
#  unknown state       0.46      0.23      0.31        69
#
#       accuracy                           0.55       691
#      macro avg       0.44      0.37      0.39       691
#   weighted avg       0.51      0.55      0.51       691

# %% [markdown]
# # fitting a logistic regression classifier

# %%
from sklearn.linear_model import LogisticRegression
log =LogisticRegression(random_state=0, max_iter= 1000)

# %%
## pipeline

## train classifier
log.fit(X_train, y_train)
## test
predicted = log.predict(X_test)
predicted_prob = log.predict_proba(X_test)

# %%
# lets see our model performance
classes = np.unique(y_test)
y_test_array = pd.get_dummies(y_test, drop_first=False).values
    
## Accuracy, Precision, Recall
accuracy = metrics.accuracy_score(y_test, predicted)
auc = metrics.roc_auc_score(y_test, predicted_prob, 
                            multi_class="ovr")
print("Accuracy:",  round(accuracy,2))
print("Auc:", round(auc,2))
print("Detail:")
print(metrics.classification_report(y_test, predicted))
    
## Plot confusion matrix
cm = metrics.confusion_matrix(y_test, predicted)
fig, ax = plt.subplots()
sns.heatmap(cm, annot=True, fmt='d', ax=ax, cmap=plt.cm.Blues, 
            cbar=False)
ax.set(xlabel="Pred", ylabel="True", xticklabels=classes, 
       yticklabels=classes, title="Confusion matrix")
plt.yticks(rotation=0)

fig, ax = plt.subplots(nrows=1, ncols=2)
## Plot roc
for i in range(len(classes)):
    fpr, tpr, thresholds = metrics.roc_curve(y_test_array[:,i],  
                           predicted_prob[:,i])
    ax[0].plot(fpr, tpr, lw=3, 
              label='{0} (area={1:0.2f})'.format(classes[i], 
                              metrics.auc(fpr, tpr))
               )
ax[0].plot([0,1], [0,1], color='navy', lw=3, linestyle='--')
ax[0].set(xlim=[-0.05,1.0], ylim=[0.0,1.05], 
          xlabel='False Positive Rate', 
          ylabel="True Positive Rate (Recall)", 
          title="Receiver operating characteristic")
ax[0].legend(loc="lower right")
ax[0].grid(True)
    
## Plot precision-recall curve
for i in range(len(classes)):
    precision, recall, thresholds = metrics.precision_recall_curve(
                 y_test_array[:,i], predicted_prob[:,i])
    ax[1].plot(recall, precision, lw=3, 
               label='{0} (area={1:0.2f})'.format(classes[i], 
                                  metrics.auc(recall, precision))
              )
ax[1].set(xlim=[0.0,1.05], ylim=[0.0,1.05], xlabel='Recall', 
          ylabel="Precision", title="Precision-Recall curve")
ax[1].legend(loc="best")
ax[1].grid(True)
plt.show()
# Out:
# Accuracy: 0.6
# Auc: 0.81
# Detail:
#                 precision    recall  f1-score   support
#
# Mixed feelings       0.67      0.04      0.07        52
#       Negative       0.55      0.50      0.53       139
#       Positive       0.60      0.81      0.69       321
#    not-Kannada       0.70      0.55      0.61       110
#  unknown state       0.51      0.30      0.38        69
#
#       accuracy                           0.60       691
#      macro avg       0.61      0.44      0.46       691
#   weighted avg       0.60      0.60      0.57       691

# %% [markdown]
# # training a k-neighboot classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=3, weights='distance')

# %%
## train classifier
neigh.fit(X_train, y_train)
## test
predicted = neigh.predict(X_test)
predicted_prob = neigh.predict_proba(X_test)

# %%
# lets see our model performance
classes = np.unique(y_test)
y_test_array = pd.get_dummies(y_test, drop_first=False).values
    
## Accuracy, Precision, Recall
accuracy = metrics.accuracy_score(y_test, predicted)
auc = metrics.roc_auc_score(y_test, predicted_prob, 
                            multi_class="ovr")
print("Accuracy:",  round(accuracy,2))
print("Auc:", round(auc,2))
print("Detail:")
print(metrics.classification_report(y_test, predicted))
    
## Plot confusion matrix
cm = metrics.confusion_matrix(y_test, predicted)
fig, ax = plt.subplots()
sns.heatmap(cm, annot=True, fmt='d', ax=ax, cmap=plt.cm.Blues, 
            cbar=False)
ax.set(xlabel="Pred", ylabel="True", xticklabels=classes, 
       yticklabels=classes, title="Confusion matrix")
plt.yticks(rotation=0)

fig, ax = plt.subplots(nrows=1, ncols=2)
## Plot roc
for i in range(len(classes)):
    fpr, tpr, thresholds = metrics.roc_curve(y_test_array[:,i],  
                           predicted_prob[:,i])
    ax[0].plot(fpr, tpr, lw=3, 
              label='{0} (area={1:0.2f})'.format(classes[i], 
                              metrics.auc(fpr, tpr))
               )
ax[0].plot([0,1], [0,1], color='navy', lw=3, linestyle='--')
ax[0].set(xlim=[-0.05,1.0], ylim=[0.0,1.05], 
          xlabel='False Positive Rate', 
          ylabel="True Positive Rate (Recall)", 
          title="Receiver operating characteristic")
ax[0].legend(loc="lower right")
ax[0].grid(True)
    
## Plot precision-recall curve
for i in range(len(classes)):
    precision, recall, thresholds = metrics.precision_recall_curve(
                 y_test_array[:,i], predicted_prob[:,i])
    ax[1].plot(recall, precision, lw=3, 
               label='{0} (area={1:0.2f})'.format(classes[i], 
                                  metrics.auc(recall, precision))
              )
ax[1].set(xlim=[0.0,1.05], ylim=[0.0,1.05], xlabel='Recall', 
          ylabel="Precision", title="Precision-Recall curve")
ax[1].legend(loc="best")
ax[1].grid(True)
plt.show()
# Out:
# Accuracy: 0.53
# Auc: 0.71
# Detail:
#                 precision    recall  f1-score   support
#
# Mixed feelings       0.22      0.21      0.21        52
#       Negative       0.50      0.42      0.45       139
#       Positive       0.63      0.67      0.65       321
#    not-Kannada       0.51      0.52      0.52       110
#  unknown state       0.36      0.35      0.35        69
#
#       accuracy                           0.53       691
#      macro avg       0.44      0.43      0.44       691
#   weighted avg       0.52      0.53      0.53       691
