# %%
## for data
import json
import pandas as pd
import numpy as np
## for plotting
import matplotlib.pyplot as plt
import seaborn as sns
## for processing
import re
import nltk
## for bag-of-words
from sklearn import metrics, feature_extraction, feature_selection, model_selection, naive_bayes, pipeline, manifold, preprocessing
## for explainer
from lime import lime_text
## for word embedding
import gensim
import gensim.downloader as gensim_api
## for deep learning
from tensorflow.keras import models, layers, preprocessing as kprocessing
from tensorflow.keras import backend as K

## for bert language model
import transformers

# %%
''' The following shows the result of training various non-nerual network models on a original version of the 
Kannada set. models are trained on an tf-idf vectorizer
with dimensionality reduction.'''
# Out:
# ' The following shows the result of training various non-nerual network models on a original version of the \nKannada set. models are trained on an tf-idf vectorizer\nwith dimensionality reduction.'

# %%
# import data
kan_train = pd.read_table("../../datasets/task_a/kan_sentiment_train.tsv")
kan_dev = pd.read_table("../../datasets/task_a/kan_sentiment_dev.tsv")

# %%
kan_train = kan_train.rename(columns={'category': 'y'})
kan_dev = kan_dev.rename(columns={'category': 'y'})

# %%
kan_dev
# Out:
#                                                   text               y
# 0    Binduge saryagi ugithidira good go ahead  we a...  Mixed feelings
# 1                               yen song guru ...super        Positive
# 2                                     my fevorat story     not-Kannada
# 3                                    Super ತೋಗರಿ ತೀಪ್ಪ        Positive
# 4    ನಿಮ್ಮ ಮಾತುಗಳು ಅಕ್ಷರಶಃ ಸತ್ಯ... ನಿಮ್ಮ ಈ ಸಾಮಾನ್ಯ ...        Positive
# ..                                                 ...             ...
# 686  @Nandi Parthasarathi ನಿಮ್ಮ ಅಪ್ಪ ದೊಡ್ ಗಾಂಡು ಸೂಳೆಮಗ        Negative
# 687                               Hugi guru badethawke        Negative
# 688                                  Trending no.1 wow        Positive
# 689  @Troll Stupid Fans naanu adikke kano helthirod...        Positive
# 690  @JustAn Opinion ninu Tika mucchu...Evattu Kann...        Positive
#
# [691 rows x 2 columns]

# %%
fig, ax = plt.subplots()
fig.suptitle("y", fontsize=12)
kan_train.groupby("y").count().plot(kind="barh", legend=False, 
        ax=ax).grid(axis='x')
plt.show()

# %%
kan_dev
# Out:
#                                                   text               y
# 0    Binduge saryagi ugithidira good go ahead  we a...  Mixed feelings
# 1                               yen song guru ...super        Positive
# 2                                     my fevorat story     not-Kannada
# 3                                    Super ತೋಗರಿ ತೀಪ್ಪ        Positive
# 4    ನಿಮ್ಮ ಮಾತುಗಳು ಅಕ್ಷರಶಃ ಸತ್ಯ... ನಿಮ್ಮ ಈ ಸಾಮಾನ್ಯ ...        Positive
# ..                                                 ...             ...
# 686  @Nandi Parthasarathi ನಿಮ್ಮ ಅಪ್ಪ ದೊಡ್ ಗಾಂಡು ಸೂಳೆಮಗ        Negative
# 687                               Hugi guru badethawke        Negative
# 688                                  Trending no.1 wow        Positive
# 689  @Troll Stupid Fans naanu adikke kano helthirod...        Positive
# 690  @JustAn Opinion ninu Tika mucchu...Evattu Kann...        Positive
#
# [691 rows x 2 columns]

# %%
# Now we can define our training data and our dev data as well as targets
train = kan_train
test = kan_dev

y_train = kan_train['y'].values
y_test = kan_dev['y'].values

# %% [markdown]
# ## Using Tf-Idf vectorizer

# %%
## Count (classic BoW)
#vectorizer = feature_extraction.text.CountVectorizer(max_features=10000, ngram_range=(1,2))

## Tf-Idf (advanced variant of BoW)
vectorizer = feature_extraction.text.TfidfVectorizer(max_features=10000, ngram_range=(1,2))

# %%
# now run thse vectorizers on the train data
corpus = train["text"]
vectorizer.fit(corpus)
X_train = vectorizer.transform(corpus)
dic_vocabulary = vectorizer.vocabulary_

# %%
X_train
# Out:
# <6212x10000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 46088 stored elements in Compressed Sparse Row format>

# %%
sns.heatmap(X_train.todense()[:,np.random.randint(0,X_train.shape[1],100)]==0, vmin=0, vmax=1, cbar=False).set_title('Sparse Matrix Sample')
# Out:
# Text(0.5, 1.0, 'Sparse Matrix Sample')

# %% [markdown]
# ## reducing the vectorizers dimensionality

# %%
# reduce dimensionality through feature selection

y = y_train
X_names = vectorizer.get_feature_names()
p_value_limit = 0.95

dtf_features = pd.DataFrame()
for cat in np.unique(y):
    chi2, p = feature_selection.chi2(X_train, y==cat)
    dtf_features = dtf_features.append(pd.DataFrame(
                   {"feature":X_names, "score":1-p, "y":cat}))
    dtf_features = dtf_features.sort_values(["y","score"], 
                    ascending=[True,False])
    dtf_features = dtf_features[dtf_features["score"]>p_value_limit]
X_names = dtf_features["feature"].unique().tolist()

# %%
for cat in np.unique(y):
   print("# {}:".format(cat))
   print("  . selected features:",
         len(dtf_features[dtf_features["y"]==cat]))
   print("  . top features:", ",".join(
dtf_features[dtf_features["y"]==cat]["feature"].values[:10]))
   print(" ")
# Out:
# # Mixed feelings:
#   . selected features: 322
#   . top features: game,yava game,game name,yavadu,game yavdu,bro game,ಅದ ಪದ,bigg boss,32,game yavadu
#
# # Negative:
#   . selected features: 342
#   . top features: nandi,nandi parthasarathi,parthasarathi,super,dislike,sule,nan,rashmika,gandu,prithvi nayak
#
# # Positive:
#   . selected features: 129
#   . top features: ಪರ,ಗಡ ಇದ,ದನ ಗಡ,ಗಡ,ಇದ,ದನ,ಚರ,ಗರ,parthasarathi,nandi
#
# # not-Kannada:
#   . selected features: 324
#   . top features: super,super bro,super song,anjali devi,devi,anjali,bro,song,super super,nice
#
# # unknown state:
#   . selected features: 310
#   . top features: yes,gta,gta bro,paramvah,paramvah music,lokanath,join,yes bro,like,godiyaga

# %% [markdown]
# ## re-fitting the vectorizer on the new vocabulary gained through feature reduction

# %%
# we can now refit the vecotrizer on the corpus by giving this new set of words as input.
# producing a smaller feature matrix and a shorter vocabulary.
vectorizer = feature_extraction.text.TfidfVectorizer(vocabulary=X_names)
vectorizer.fit(corpus)
X_train = vectorizer.transform(corpus)
dic_vocabulary = vectorizer.vocabulary_

# %%
X_train.shape
# Out:
# (6212, 1331)

# %%
sns.heatmap(X_train.todense()[:,np.random.randint(0,X_train.shape[1],100)]==0, vmin=0, vmax=1, cbar=False).set_title('Sparse Matrix Sample')
# Out:
# Text(0.5, 1.0, 'Sparse Matrix Sample')

# %% [markdown]
# # Training a cat boost classifier

# %%
from catboost import CatBoostClassifier
cat = CatBoostClassifier(
    iterations=1500, 
    learning_rate=1, 
    #loss_function='CrossEntropy'
)

# %%
## pipeline
model_cat = pipeline.Pipeline([("vectorizer", vectorizer),  
                           ("classifier", cat)])
## train classifier
model_cat["classifier"].fit(X_train, y_train)
## test
X_test = test["text"].values
predicted = model_cat.predict(X_test)
predicted_prob = model_cat.predict_proba(X_test)
# Out:
# 0:	learn: 1.4016719	total: 33.5ms	remaining: 50.3s
# 1:	learn: 1.3339359	total: 57.4ms	remaining: 43s
# 2:	learn: 1.3076466	total: 81.3ms	remaining: 40.5s
# 3:	learn: 1.2843804	total: 105ms	remaining: 39.2s
# 4:	learn: 1.2624397	total: 129ms	remaining: 38.4s
# 5:	learn: 1.2508378	total: 152ms	remaining: 37.8s
# 6:	learn: 1.2398855	total: 176ms	remaining: 37.5s
# 7:	learn: 1.2214680	total: 200ms	remaining: 37.3s
# 8:	learn: 1.2101472	total: 223ms	remaining: 37s
# 9:	learn: 1.1975268	total: 248ms	remaining: 36.9s
# 10:	learn: 1.1840271	total: 272ms	remaining: 36.8s
# 11:	learn: 1.1753470	total: 295ms	remaining: 36.6s
# 12:	learn: 1.1704125	total: 319ms	remaining: 36.5s
# 13:	learn: 1.1645335	total: 342ms	remaining: 36.3s
# 14:	learn: 1.1570292	total: 367ms	remaining: 36.3s
# 15:	learn: 1.1509059	total: 390ms	remaining: 36.2s
# 16:	learn: 1.1462952	total: 413ms	remaining: 36.1s
# 17:	learn: 1.1419769	total: 437ms	remaining: 36s
# 18:	learn: 1.1356412	total: 461ms	remaining: 35.9s
# 19:	learn: 1.1301187	total: 484ms	remaining: 35.8s
# 20:	learn: 1.1264143	total: 508ms	remaining: 35.8s
# 21:	learn: 1.1220625	total: 531ms	remaining: 35.7s
# 22:	learn: 1.1194854	total: 555ms	remaining: 35.6s
# 23:	learn: 1.1150842	total: 579ms	remaining: 35.6s
# 24:	learn: 1.1102857	total: 603ms	remaining: 35.6s
# 25:	learn: 1.1082308	total: 626ms	remaining: 35.5s
# 26:	learn: 1.1035362	total: 650ms	remaining: 35.5s
# 27:	learn: 1.0998921	total: 675ms	remaining: 35.5s
# 28:	learn: 1.0946972	total: 699ms	remaining: 35.4s
# 29:	learn: 1.0925879	total: 722ms	remaining: 35.4s
# 30:	learn: 1.0890978	total: 746ms	remaining: 35.3s
# 31:	learn: 1.0842824	total: 770ms	remaining: 35.3s
# 32:	learn: 1.0812596	total: 794ms	remaining: 35.3s
# 33:	learn: 1.0791301	total: 818ms	remaining: 35.3s
# 34:	learn: 1.0767118	total: 842ms	remaining: 35.2s
# 35:	learn: 1.0748177	total: 866ms	remaining: 35.2s
# 36:	learn: 1.0726430	total: 890ms	remaining: 35.2s
# 37:	learn: 1.0703550	total: 914ms	remaining: 35.1s
# 38:	learn: 1.0681664	total: 937ms	remaining: 35.1s
# 39:	learn: 1.0658896	total: 961ms	remaining: 35.1s
# 40:	learn: 1.0636342	total: 984ms	remaining: 35s
# 41:	learn: 1.0600561	total: 1.01s	remaining: 35s
# 42:	learn: 1.0579822	total: 1.03s	remaining: 35s
# 43:	learn: 1.0563847	total: 1.05s	remaining: 34.9s
# 44:	learn: 1.0547732	total: 1.08s	remaining: 34.9s
# 45:	learn: 1.0528866	total: 1.1s	remaining: 34.9s
# 46:	learn: 1.0510064	total: 1.13s	remaining: 34.8s
# 47:	learn: 1.0490202	total: 1.15s	remaining: 34.8s
# 48:	learn: 1.0479960	total: 1.17s	remaining: 34.8s
# 49:	learn: 1.0461188	total: 1.2s	remaining: 34.8s
# 50:	learn: 1.0446802	total: 1.22s	remaining: 34.7s
# 51:	learn: 1.0431498	total: 1.24s	remaining: 34.7s
# 52:	learn: 1.0406034	total: 1.27s	remaining: 34.6s
# 53:	learn: 1.0387487	total: 1.29s	remaining: 34.6s
# 54:	learn: 1.0376684	total: 1.32s	remaining: 34.6s
# 55:	learn: 1.0365714	total: 1.34s	remaining: 34.6s
# 56:	learn: 1.0353923	total: 1.36s	remaining: 34.5s
# 57:	learn: 1.0342677	total: 1.39s	remaining: 34.5s
# 58:	learn: 1.0320402	total: 1.41s	remaining: 34.5s
# 59:	learn: 1.0303497	total: 1.43s	remaining: 34.4s
# 60:	learn: 1.0289946	total: 1.46s	remaining: 34.4s
# 61:	learn: 1.0264573	total: 1.48s	remaining: 34.4s
# 62:	learn: 1.0233757	total: 1.5s	remaining: 34.3s
# 63:	learn: 1.0189243	total: 1.53s	remaining: 34.3s
# 64:	learn: 1.0177301	total: 1.55s	remaining: 34.3s
# 65:	learn: 1.0152621	total: 1.58s	remaining: 34.3s
# 66:	learn: 1.0131769	total: 1.6s	remaining: 34.2s
# 67:	learn: 1.0117722	total: 1.62s	remaining: 34.2s
# 68:	learn: 1.0108436	total: 1.65s	remaining: 34.2s
# 69:	learn: 1.0096638	total: 1.67s	remaining: 34.1s
# 70:	learn: 1.0079613	total: 1.69s	remaining: 34.1s
# 71:	learn: 1.0069555	total: 1.72s	remaining: 34.1s
# 72:	learn: 1.0040160	total: 1.74s	remaining: 34.1s
# 73:	learn: 1.0014761	total: 1.77s	remaining: 34s
# 74:	learn: 0.9994426	total: 1.79s	remaining: 34s
# 75:	learn: 0.9980408	total: 1.81s	remaining: 34s
# 76:	learn: 0.9971477	total: 1.84s	remaining: 34s
# 77:	learn: 0.9962305	total: 1.86s	remaining: 33.9s
# 78:	learn: 0.9951656	total: 1.89s	remaining: 33.9s
# 79:	learn: 0.9941376	total: 1.91s	remaining: 33.9s
# 80:	learn: 0.9933014	total: 1.93s	remaining: 33.9s
# 81:	learn: 0.9916630	total: 1.96s	remaining: 33.9s
# 82:	learn: 0.9906060	total: 1.98s	remaining: 33.8s
# 83:	learn: 0.9896585	total: 2s	remaining: 33.8s
# 84:	learn: 0.9880517	total: 2.03s	remaining: 33.8s
# 85:	learn: 0.9864502	total: 2.05s	remaining: 33.8s
# 86:	learn: 0.9848335	total: 2.08s	remaining: 33.7s
# 87:	learn: 0.9837915	total: 2.1s	remaining: 33.7s
# 88:	learn: 0.9829801	total: 2.12s	remaining: 33.7s
# 89:	learn: 0.9817076	total: 2.15s	remaining: 33.6s
# 90:	learn: 0.9808593	total: 2.17s	remaining: 33.6s
# 91:	learn: 0.9792529	total: 2.19s	remaining: 33.6s
# 92:	learn: 0.9785059	total: 2.22s	remaining: 33.6s
# 93:	learn: 0.9775826	total: 2.24s	remaining: 33.5s
# 94:	learn: 0.9764513	total: 2.27s	remaining: 33.5s
# 95:	learn: 0.9749223	total: 2.29s	remaining: 33.5s
# 96:	learn: 0.9730366	total: 2.31s	remaining: 33.5s
# 97:	learn: 0.9724887	total: 2.34s	remaining: 33.4s
# 98:	learn: 0.9710276	total: 2.36s	remaining: 33.4s
# 99:	learn: 0.9699672	total: 2.38s	remaining: 33.4s
# 100:	learn: 0.9688697	total: 2.41s	remaining: 33.4s
# 101:	learn: 0.9681177	total: 2.43s	remaining: 33.3s
# 102:	learn: 0.9666807	total: 2.46s	remaining: 33.3s
# 103:	learn: 0.9657564	total: 2.48s	remaining: 33.3s
# 104:	learn: 0.9648966	total: 2.5s	remaining: 33.3s
# 105:	learn: 0.9641902	total: 2.53s	remaining: 33.2s
# 106:	learn: 0.9636670	total: 2.55s	remaining: 33.2s
# 107:	learn: 0.9624649	total: 2.58s	remaining: 33.2s
# 108:	learn: 0.9609262	total: 2.6s	remaining: 33.2s
# 109:	learn: 0.9601872	total: 2.62s	remaining: 33.2s
# 110:	learn: 0.9594574	total: 2.65s	remaining: 33.1s
# 111:	learn: 0.9586209	total: 2.67s	remaining: 33.1s
# 112:	learn: 0.9573666	total: 2.69s	remaining: 33.1s
# 113:	learn: 0.9568549	total: 2.72s	remaining: 33.1s
# 114:	learn: 0.9565088	total: 2.74s	remaining: 33s
# 115:	learn: 0.9558147	total: 2.77s	remaining: 33s
# 116:	learn: 0.9545590	total: 2.79s	remaining: 33s
# 117:	learn: 0.9539777	total: 2.81s	remaining: 33s
# 118:	learn: 0.9532114	total: 2.84s	remaining: 32.9s
# 119:	learn: 0.9526472	total: 2.86s	remaining: 32.9s
# 120:	learn: 0.9517736	total: 2.88s	remaining: 32.9s
# 121:	learn: 0.9509998	total: 2.91s	remaining: 32.9s
# 122:	learn: 0.9503785	total: 2.93s	remaining: 32.8s
# 123:	learn: 0.9494075	total: 2.96s	remaining: 32.8s
# 124:	learn: 0.9486688	total: 2.98s	remaining: 32.8s
# 125:	learn: 0.9477017	total: 3s	remaining: 32.8s
# 126:	learn: 0.9457518	total: 3.03s	remaining: 32.7s
# 127:	learn: 0.9444351	total: 3.05s	remaining: 32.7s
# 128:	learn: 0.9439826	total: 3.08s	remaining: 32.7s
# 129:	learn: 0.9432420	total: 3.1s	remaining: 32.7s
# 130:	learn: 0.9426831	total: 3.12s	remaining: 32.6s
# 131:	learn: 0.9413821	total: 3.15s	remaining: 32.6s
# 132:	learn: 0.9404585	total: 3.17s	remaining: 32.6s
# 133:	learn: 0.9397513	total: 3.19s	remaining: 32.6s
# 134:	learn: 0.9392828	total: 3.22s	remaining: 32.5s
# 135:	learn: 0.9385833	total: 3.24s	remaining: 32.5s
# 649:	learn: 0.7198598	total: 15.5s	remaining: 20.3s
# 650:	learn: 0.7195018	total: 15.6s	remaining: 20.3s
# 651:	learn: 0.7193458	total: 15.6s	remaining: 20.3s
# 652:	learn: 0.7191471	total: 15.6s	remaining: 20.2s
# 653:	learn: 0.7188970	total: 15.6s	remaining: 20.2s
# 654:	learn: 0.7187516	total: 15.6s	remaining: 20.2s
# 655:	learn: 0.7184684	total: 15.7s	remaining: 20.2s
# 656:	learn: 0.7181521	total: 15.7s	remaining: 20.1s
# 657:	learn: 0.7170472	total: 15.7s	remaining: 20.1s
# 658:	learn: 0.7168606	total: 15.7s	remaining: 20.1s
# 659:	learn: 0.7166957	total: 15.8s	remaining: 20.1s
# 660:	learn: 0.7163245	total: 15.8s	remaining: 20s
# 661:	learn: 0.7162075	total: 15.8s	remaining: 20s
# 662:	learn: 0.7160531	total: 15.8s	remaining: 20s
# 663:	learn: 0.7159135	total: 15.9s	remaining: 20s
# 664:	learn: 0.7157410	total: 15.9s	remaining: 19.9s
# 665:	learn: 0.7153717	total: 15.9s	remaining: 19.9s
# 666:	learn: 0.7152587	total: 15.9s	remaining: 19.9s
# 667:	learn: 0.7150030	total: 16s	remaining: 19.9s
# 668:	learn: 0.7147536	total: 16s	remaining: 19.9s
# 669:	learn: 0.7145739	total: 16s	remaining: 19.8s
# 670:	learn: 0.7143330	total: 16s	remaining: 19.8s
# 671:	learn: 0.7142134	total: 16.1s	remaining: 19.8s
# 672:	learn: 0.7140913	total: 16.1s	remaining: 19.8s
# 673:	learn: 0.7137781	total: 16.1s	remaining: 19.7s
# 674:	learn: 0.7135441	total: 16.1s	remaining: 19.7s
# 675:	learn: 0.7130118	total: 16.1s	remaining: 19.7s
# 676:	learn: 0.7128337	total: 16.2s	remaining: 19.7s
# 677:	learn: 0.7127293	total: 16.2s	remaining: 19.6s
# 678:	learn: 0.7125601	total: 16.2s	remaining: 19.6s
# 679:	learn: 0.7124083	total: 16.2s	remaining: 19.6s
# 680:	learn: 0.7122538	total: 16.3s	remaining: 19.6s
# 681:	learn: 0.7122076	total: 16.3s	remaining: 19.5s
# 682:	learn: 0.7120011	total: 16.3s	remaining: 19.5s
# 683:	learn: 0.7118743	total: 16.3s	remaining: 19.5s
# 684:	learn: 0.7116004	total: 16.4s	remaining: 19.5s
# 685:	learn: 0.7114969	total: 16.4s	remaining: 19.4s
# 686:	learn: 0.7113521	total: 16.4s	remaining: 19.4s
# 687:	learn: 0.7112610	total: 16.4s	remaining: 19.4s
# 688:	learn: 0.7110572	total: 16.5s	remaining: 19.4s
# 689:	learn: 0.7109582	total: 16.5s	remaining: 19.4s
# 690:	learn: 0.7104227	total: 16.5s	remaining: 19.3s
# 691:	learn: 0.7102076	total: 16.5s	remaining: 19.3s
# 692:	learn: 0.7100838	total: 16.6s	remaining: 19.3s
# 693:	learn: 0.7098045	total: 16.6s	remaining: 19.3s
# 694:	learn: 0.7095959	total: 16.6s	remaining: 19.2s
# 695:	learn: 0.7094529	total: 16.6s	remaining: 19.2s
# 1468:	learn: 0.6310131	total: 35.2s	remaining: 742ms
# 1469:	learn: 0.6309645	total: 35.2s	remaining: 718ms
# 1470:	learn: 0.6308877	total: 35.2s	remaining: 694ms
# 1471:	learn: 0.6308747	total: 35.2s	remaining: 670ms
# 1472:	learn: 0.6308614	total: 35.3s	remaining: 646ms
# 1473:	learn: 0.6308127	total: 35.3s	remaining: 622ms
# 1474:	learn: 0.6307868	total: 35.3s	remaining: 598ms
# 1475:	learn: 0.6307626	total: 35.3s	remaining: 574ms
# 1476:	learn: 0.6307136	total: 35.4s	remaining: 551ms
# 1477:	learn: 0.6306935	total: 35.4s	remaining: 527ms
# 1478:	learn: 0.6306413	total: 35.4s	remaining: 503ms
# 1479:	learn: 0.6305700	total: 35.4s	remaining: 479ms
# 1480:	learn: 0.6305368	total: 35.4s	remaining: 455ms
# 1481:	learn: 0.6305183	total: 35.5s	remaining: 431ms
# 1482:	learn: 0.6304766	total: 35.5s	remaining: 407ms
# 1483:	learn: 0.6304061	total: 35.5s	remaining: 383ms
# 1484:	learn: 0.6303916	total: 35.5s	remaining: 359ms
# 1485:	learn: 0.6303328	total: 35.6s	remaining: 335ms
# 1486:	learn: 0.6303154	total: 35.6s	remaining: 311ms
# 1487:	learn: 0.6302801	total: 35.6s	remaining: 287ms
# 1488:	learn: 0.6302347	total: 35.6s	remaining: 263ms
# 1489:	learn: 0.6302185	total: 35.7s	remaining: 239ms
# 1490:	learn: 0.6302010	total: 35.7s	remaining: 215ms
# 1491:	learn: 0.6301556	total: 35.7s	remaining: 191ms
# 1492:	learn: 0.6301173	total: 35.7s	remaining: 168ms
# 1493:	learn: 0.6300787	total: 35.8s	remaining: 144ms
# 1494:	learn: 0.6300419	total: 35.8s	remaining: 120ms
# 1495:	learn: 0.6300110	total: 35.8s	remaining: 95.7ms
# 1496:	learn: 0.6299902	total: 35.8s	remaining: 71.8ms
# 1497:	learn: 0.6299665	total: 35.9s	remaining: 47.9ms
# 1498:	learn: 0.6299554	total: 35.9s	remaining: 23.9ms
# 1499:	learn: 0.6298725	total: 35.9s	remaining: 0us

# %%
# lets see our model performance
classes = np.unique(y_test)
y_test_array = pd.get_dummies(y_test, drop_first=False).values
    
## Accuracy, Precision, Recall
accuracy = metrics.accuracy_score(y_test, predicted)
auc = metrics.roc_auc_score(y_test, predicted_prob, 
                            multi_class="ovr")
print("Accuracy:",  round(accuracy,2))
print("Auc:", round(auc,2))
print("Detail:")
print(metrics.classification_report(y_test, predicted))
    
## Plot confusion matrix
cm = metrics.confusion_matrix(y_test, predicted)
fig, ax = plt.subplots()
sns.heatmap(cm, annot=True, fmt='d', ax=ax, cmap=plt.cm.Blues, 
            cbar=False)
ax.set(xlabel="Pred", ylabel="True", xticklabels=classes, 
       yticklabels=classes, title="Confusion matrix")
plt.yticks(rotation=0)

fig, ax = plt.subplots(nrows=1, ncols=2)
## Plot roc
for i in range(len(classes)):
    fpr, tpr, thresholds = metrics.roc_curve(y_test_array[:,i],  
                           predicted_prob[:,i])
    ax[0].plot(fpr, tpr, lw=3, 
              label='{0} (area={1:0.2f})'.format(classes[i], 
                              metrics.auc(fpr, tpr))
               )
ax[0].plot([0,1], [0,1], color='navy', lw=3, linestyle='--')
ax[0].set(xlim=[-0.05,1.0], ylim=[0.0,1.05], 
          xlabel='False Positive Rate', 
          ylabel="True Positive Rate (Recall)", 
          title="Receiver operating characteristic")
ax[0].legend(loc="lower right")
ax[0].grid(True)
    
## Plot precision-recall curve
for i in range(len(classes)):
    precision, recall, thresholds = metrics.precision_recall_curve(
                 y_test_array[:,i], predicted_prob[:,i])
    ax[1].plot(recall, precision, lw=3, 
               label='{0} (area={1:0.2f})'.format(classes[i], 
                                  metrics.auc(recall, precision))
              )
ax[1].set(xlim=[0.0,1.05], ylim=[0.0,1.05], xlabel='Recall', 
          ylabel="Precision", title="Precision-Recall curve")
ax[1].legend(loc="best")
ax[1].grid(True)
plt.show()
# Out:
# Accuracy: 0.57
# Auc: 0.79
# Detail:
#                 precision    recall  f1-score   support
#
# Mixed feelings       0.38      0.19      0.26        52
#       Negative       0.61      0.48      0.54       139
#       Positive       0.58      0.79      0.67       321
#    not-Kannada       0.58      0.52      0.55       110
#  unknown state       0.29      0.10      0.15        69
#
#       accuracy                           0.57       691
#      macro avg       0.49      0.42      0.43       691
#   weighted avg       0.54      0.57      0.54       691

# %% [markdown]
# # Training a Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(max_depth=150, n_estimators=30, max_features=1331)

# %%
## pipeline
model_forest = pipeline.Pipeline([("vectorizer", vectorizer),  
                           ("classifier", forest)])
## train classifier
model_forest["classifier"].fit(X_train, y_train)
## test
X_test = test["text"].values
predicted = model_forest.predict(X_test)
predicted_prob = model_forest.predict_proba(X_test)

# %%
# lets see our model performance
classes = np.unique(y_test)
y_test_array = pd.get_dummies(y_test, drop_first=False).values
    
## Accuracy, Precision, Recall
accuracy = metrics.accuracy_score(y_test, predicted)
auc = metrics.roc_auc_score(y_test, predicted_prob, 
                            multi_class="ovr")
print("Accuracy:",  round(accuracy,2))
print("Auc:", round(auc,2))
print("Detail:")
print(metrics.classification_report(y_test, predicted))
    
## Plot confusion matrix
cm = metrics.confusion_matrix(y_test, predicted)
fig, ax = plt.subplots()
sns.heatmap(cm, annot=True, fmt='d', ax=ax, cmap=plt.cm.Blues, 
            cbar=False)
ax.set(xlabel="Pred", ylabel="True", xticklabels=classes, 
       yticklabels=classes, title="Confusion matrix")
plt.yticks(rotation=0)

fig, ax = plt.subplots(nrows=1, ncols=2)
## Plot roc
for i in range(len(classes)):
    fpr, tpr, thresholds = metrics.roc_curve(y_test_array[:,i],  
                           predicted_prob[:,i])
    ax[0].plot(fpr, tpr, lw=3, 
              label='{0} (area={1:0.2f})'.format(classes[i], 
                              metrics.auc(fpr, tpr))
               )
ax[0].plot([0,1], [0,1], color='navy', lw=3, linestyle='--')
ax[0].set(xlim=[-0.05,1.0], ylim=[0.0,1.05], 
          xlabel='False Positive Rate', 
          ylabel="True Positive Rate (Recall)", 
          title="Receiver operating characteristic")
ax[0].legend(loc="lower right")
ax[0].grid(True)
    
## Plot precision-recall curve
for i in range(len(classes)):
    precision, recall, thresholds = metrics.precision_recall_curve(
                 y_test_array[:,i], predicted_prob[:,i])
    ax[1].plot(recall, precision, lw=3, 
               label='{0} (area={1:0.2f})'.format(classes[i], 
                                  metrics.auc(recall, precision))
              )
ax[1].set(xlim=[0.0,1.05], ylim=[0.0,1.05], xlabel='Recall', 
          ylabel="Precision", title="Precision-Recall curve")
ax[1].legend(loc="best")
ax[1].grid(True)
plt.show()
# Out:
# Accuracy: 0.58
# Auc: 0.78
# Detail:
#                 precision    recall  f1-score   support
#
# Mixed feelings       0.50      0.13      0.21        52
#       Negative       0.66      0.51      0.57       139
#       Positive       0.58      0.82      0.68       321
#    not-Kannada       0.58      0.50      0.54       110
#  unknown state       0.25      0.07      0.11        69
#
#       accuracy                           0.58       691
#      macro avg       0.51      0.41      0.42       691
#   weighted avg       0.56      0.58      0.54       691

# %% [markdown]
# # fitting a logistic regression classifier

# %%
from sklearn.linear_model import LogisticRegression
log =LogisticRegression(random_state=0, max_iter= 200)

# %%
## pipeline
model_log = pipeline.Pipeline([("vectorizer", vectorizer),  
                           ("classifier", log)])
## train classifier
model_log["classifier"].fit(X_train, y_train)
## test
X_test = test["text"].values
predicted = model_log.predict(X_test)
predicted_prob = model_log.predict_proba(X_test)

# %%
# lets see our model performance
classes = np.unique(y_test)
y_test_array = pd.get_dummies(y_test, drop_first=False).values
    
## Accuracy, Precision, Recall
accuracy = metrics.accuracy_score(y_test, predicted)
auc = metrics.roc_auc_score(y_test, predicted_prob, 
                            multi_class="ovr")
print("Accuracy:",  round(accuracy,2))
print("Auc:", round(auc,2))
print("Detail:")
print(metrics.classification_report(y_test, predicted))
    
## Plot confusion matrix
cm = metrics.confusion_matrix(y_test, predicted)
fig, ax = plt.subplots()
sns.heatmap(cm, annot=True, fmt='d', ax=ax, cmap=plt.cm.Blues, 
            cbar=False)
ax.set(xlabel="Pred", ylabel="True", xticklabels=classes, 
       yticklabels=classes, title="Confusion matrix")
plt.yticks(rotation=0)

fig, ax = plt.subplots(nrows=1, ncols=2)
## Plot roc
for i in range(len(classes)):
    fpr, tpr, thresholds = metrics.roc_curve(y_test_array[:,i],  
                           predicted_prob[:,i])
    ax[0].plot(fpr, tpr, lw=3, 
              label='{0} (area={1:0.2f})'.format(classes[i], 
                              metrics.auc(fpr, tpr))
               )
ax[0].plot([0,1], [0,1], color='navy', lw=3, linestyle='--')
ax[0].set(xlim=[-0.05,1.0], ylim=[0.0,1.05], 
          xlabel='False Positive Rate', 
          ylabel="True Positive Rate (Recall)", 
          title="Receiver operating characteristic")
ax[0].legend(loc="lower right")
ax[0].grid(True)
    
## Plot precision-recall curve
for i in range(len(classes)):
    precision, recall, thresholds = metrics.precision_recall_curve(
                 y_test_array[:,i], predicted_prob[:,i])
    ax[1].plot(recall, precision, lw=3, 
               label='{0} (area={1:0.2f})'.format(classes[i], 
                                  metrics.auc(recall, precision))
              )
ax[1].set(xlim=[0.0,1.05], ylim=[0.0,1.05], xlabel='Recall', 
          ylabel="Precision", title="Precision-Recall curve")
ax[1].legend(loc="best")
ax[1].grid(True)
plt.show()
# Out:
# Accuracy: 0.58
# Auc: 0.81
# Detail:
#                 precision    recall  f1-score   support
#
# Mixed feelings       0.50      0.08      0.13        52
#       Negative       0.62      0.54      0.58       139
#       Positive       0.58      0.84      0.69       321
#    not-Kannada       0.63      0.37      0.47       110
#  unknown state       0.36      0.14      0.21        69
#
#       accuracy                           0.58       691
#      macro avg       0.54      0.40      0.41       691
#   weighted avg       0.57      0.58      0.54       691

# %% [markdown]
# # training a k-neighboot classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=7, weights='distance')

# %%
## pipeline
model_neigh = pipeline.Pipeline([("vectorizer", vectorizer),  
                           ("classifier", neigh)])
## train classifier
model_neigh["classifier"].fit(X_train, y_train)
## test
X_test = test["text"].values
predicted = model_neigh.predict(X_test)
predicted_prob = model_neigh.predict_proba(X_test)

# %%
# lets see our model performance
classes = np.unique(y_test)
y_test_array = pd.get_dummies(y_test, drop_first=False).values
    
## Accuracy, Precision, Recall
accuracy = metrics.accuracy_score(y_test, predicted)
auc = metrics.roc_auc_score(y_test, predicted_prob, 
                            multi_class="ovr")
print("Accuracy:",  round(accuracy,2))
print("Auc:", round(auc,2))
print("Detail:")
print(metrics.classification_report(y_test, predicted))
    
## Plot confusion matrix
cm = metrics.confusion_matrix(y_test, predicted)
fig, ax = plt.subplots()
sns.heatmap(cm, annot=True, fmt='d', ax=ax, cmap=plt.cm.Blues, 
            cbar=False)
ax.set(xlabel="Pred", ylabel="True", xticklabels=classes, 
       yticklabels=classes, title="Confusion matrix")
plt.yticks(rotation=0)

fig, ax = plt.subplots(nrows=1, ncols=2)
## Plot roc
for i in range(len(classes)):
    fpr, tpr, thresholds = metrics.roc_curve(y_test_array[:,i],  
                           predicted_prob[:,i])
    ax[0].plot(fpr, tpr, lw=3, 
              label='{0} (area={1:0.2f})'.format(classes[i], 
                              metrics.auc(fpr, tpr))
               )
ax[0].plot([0,1], [0,1], color='navy', lw=3, linestyle='--')
ax[0].set(xlim=[-0.05,1.0], ylim=[0.0,1.05], 
          xlabel='False Positive Rate', 
          ylabel="True Positive Rate (Recall)", 
          title="Receiver operating characteristic")
ax[0].legend(loc="lower right")
ax[0].grid(True)
    
## Plot precision-recall curve
for i in range(len(classes)):
    precision, recall, thresholds = metrics.precision_recall_curve(
                 y_test_array[:,i], predicted_prob[:,i])
    ax[1].plot(recall, precision, lw=3, 
               label='{0} (area={1:0.2f})'.format(classes[i], 
                                  metrics.auc(recall, precision))
              )
ax[1].set(xlim=[0.0,1.05], ylim=[0.0,1.05], xlabel='Recall', 
          ylabel="Precision", title="Precision-Recall curve")
ax[1].legend(loc="best")
ax[1].grid(True)
plt.show()
# Out:
# Accuracy: 0.56
# Auc: 0.74
# Detail:
#                 precision    recall  f1-score   support
#
# Mixed feelings       0.33      0.21      0.26        52
#       Negative       0.66      0.42      0.51       139
#       Positive       0.58      0.79      0.67       321
#    not-Kannada       0.53      0.49      0.51       110
#  unknown state       0.31      0.14      0.20        69
#
#       accuracy                           0.56       691
#      macro avg       0.48      0.41      0.43       691
#   weighted avg       0.54      0.56      0.54       691
