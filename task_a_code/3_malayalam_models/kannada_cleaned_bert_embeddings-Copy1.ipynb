# %%
## for data
import json
import pandas as pd
import numpy as np
## for plotting
import matplotlib.pyplot as plt
import seaborn as sns
## for processing
import re
import nltk
## for bag-of-words
from sklearn import metrics, feature_extraction, feature_selection, model_selection, naive_bayes, pipeline, manifold, preprocessing
## for explainer
from lime import lime_text

## for deep learning
from tensorflow.keras import models, layers, preprocessing as kprocessing
from tensorflow.keras import backend as K
import torch

## for bert language model
import transformers
from transformers import AutoTokenizer, AutoModel

# %%
''' The following shows the result of training various non-neural network models on a transliterated and cleaned
version of the Kannada set. models are trained on an bert vectorizer'''
# Out:
# ' The following shows the result of training various non-neural network models on a transliterated and cleaned\nversion of the Kannada set. models are trained on an bert vectorizer'

# %%
# import data
kan_train = pd.read_table("../../datasets/task_a/kan_sentiment_train.tsv")
kan_dev = pd.read_table("../../datasets/task_a/kan_sentiment_dev.tsv")

# %%
kan_train = kan_train.rename(columns={'category': 'y'})
kan_dev = kan_dev.rename(columns={'category': 'y'})

# %%
kan_dev
# Out:
#                                                   text               y
# 0    Binduge saryagi ugithidira good go ahead  we a...  Mixed feelings
# 1                               yen song guru ...super        Positive
# 2                                     my fevorat story     not-Kannada
# 3                                    Super ತೋಗರಿ ತೀಪ್ಪ        Positive
# 4    ನಿಮ್ಮ ಮಾತುಗಳು ಅಕ್ಷರಶಃ ಸತ್ಯ... ನಿಮ್ಮ ಈ ಸಾಮಾನ್ಯ ...        Positive
# ..                                                 ...             ...
# 686  @Nandi Parthasarathi ನಿಮ್ಮ ಅಪ್ಪ ದೊಡ್ ಗಾಂಡು ಸೂಳೆಮಗ        Negative
# 687                               Hugi guru badethawke        Negative
# 688                                  Trending no.1 wow        Positive
# 689  @Troll Stupid Fans naanu adikke kano helthirod...        Positive
# 690  @JustAn Opinion ninu Tika mucchu...Evattu Kann...        Positive
#
# [691 rows x 2 columns]

# %%
fig, ax = plt.subplots()
fig.suptitle("y", fontsize=12)
kan_train.groupby("y").count().plot(kind="barh", legend=False, 
        ax=ax).grid(axis='x')
plt.show()

# %%
# read in the list of stopwords in Kannada
with open('stopwords-kn.txt') as file:
    lines = file.readlines()
    lines = [line.rstrip() for line in lines]

lst_stopwords = lines

# %%
# transliterate all data from english scrip to kannada script
from indictrans import Transliterator

# instantiate the trasnliteration
trn = Transliterator(source='eng', target='kan', build_lookup=True)

# save the text column as a list in order to improve performance.
orig_kn_train = (kan_train['text'].to_numpy()).tolist()

# create and empty list, iterate through the list of text and append the transliterated text to our list.
list_trans = []
for i in range(len(orig_kn_train)):
    list_trans.append(trn.transform(orig_kn_train[i]))
    
# append the transliterated texts as a column on original dataframe
kan_train['text_trans'] = list_trans

# %%
kan_train
# Out:
#                                                    text               y  \
# 0     ಒಂದು ದೇಶದ ಮುಂದುವರಿಯುವುದು ಅದರ ಆರ್ಥಿಕ ಸ್ಥಿತಿಯನ್ನ...        Negative
# 1     ಕನ್ನಡದಲ್ಲಿ ಡೈಲಿ ಟೆಕ್ ಅಪ್ಡೇಟ್ಸ್ ಪಡೆಯಲು ಸಬ್ಸ್ಕ್ರ...        Positive
# 2                                        Super sar song     not-Kannada
# 3     Tiktokers present situation... nನೋಡುವವರು ಯಾರು ...        Negative
# 4                             Super ಸಾಂಗ್ ವೆರಿ ನೈಸ್....        Positive
# ...                                                 ...             ...
# 6207  @A.R.W   tumbad tanhaji andhadhun aise bahot h...     not-Kannada
# 6208                  പൊളി ഡാൻസ്🥰 രക്ഷിത് ഷെട്ടി മാസ്സ്     not-Kannada
# 6209  Bro...nNeen este Roast madudru...China ne beku...        Negative
# 6210  ಕೌಶಲ್ಯ ಇದ್ದವರ ಸಂಖ್ಯೆ ಕಡಿಮೆ ಇಲ್ಲ ಸರ್ ತುಂಬಾ ಪ್ರತ...        Positive
# 6211                                         26 M Views  Mixed feelings
#
#                                              text_trans
# 0     ಒಂದು ದೇಶದ ಮುಂದುವರಿಯುವುದು ಅದರ ಆರ್ಥಿಕ ಸ್ಥಿತಿಯನ್ನ...
# 1     ಕನ್ನಡದಲ್ಲಿ ಡೈಲಿ ಟೆಕ್ ಅಪ್ಡೇಟ್ಸ್ ಪಡೆಯಲು ಸಬ್ಸ್ಕ್ರ...
# 2                                       ಸುಪರ್ ಸಾರ ಸೋಂಗ್
# 3     ಟೀಕ್ಟೋಕರ್ಸ್ ಪ್ರಸೇಂಟ್ ಸಿತುಂಏಶನ್... ನನೋಡುವವರು ಯಾ...
# 4                             ಸುಪರ್ ಸಾಂಗ್ ವೆರಿ ನೈಸ್....
# ...                                                 ...
# 6207  @ಆ.ರ.ವ್   ಟುಂಬಾದ್ ತನ್ಹಾಜಿ ಅಂಧಾಧುನ ಐಸೆ ಬಹೋತ ಹೈ ...
# 6208                  പൊളി ഡാൻസ്🥰 രക്ഷിത് ഷെട്ടി മാസ്സ്
# 6209  ಬ್ರೊ...ನ್ನೀನ್ ಎಸ್ಟೆ ರೋಸ್ತ ಮದುದ್ರು...ಚೀನಾ ನೇ ಬೇ...
# 6210  ಕೌಶಲ್ಯ ಇದ್ದವರ ಸಂಖ್ಯೆ ಕಡಿಮೆ ಇಲ್ಲ ಸರ್ ತುಂಬಾ ಪ್ರತ...
# 6211                                         26 ಮ ವಿಊಸ್
#
# [6212 rows x 3 columns]

# %%
# do the same for the dev data
# save the text column as a list in order to improve performance.
orig_kn_dev = (kan_dev['text'].to_numpy()).tolist()

# create and empty list, iterate through the list of text and append the transliterated text to our list.
list_trans_dev = []
for i in range(len(orig_kn_dev)):
    list_trans_dev.append(trn.transform(orig_kn_dev[i]))
    
# append the transliterated texts as a column on original dataframe
kan_dev['text_trans'] = list_trans_dev

# %%
kan_dev
# Out:
#                                                   text               y  \
# 0    Binduge saryagi ugithidira good go ahead  we a...  Mixed feelings
# 1                               yen song guru ...super        Positive
# 2                                     my fevorat story     not-Kannada
# 3                                    Super ತೋಗರಿ ತೀಪ್ಪ        Positive
# 4    ನಿಮ್ಮ ಮಾತುಗಳು ಅಕ್ಷರಶಃ ಸತ್ಯ... ನಿಮ್ಮ ಈ ಸಾಮಾನ್ಯ ...        Positive
# ..                                                 ...             ...
# 686  @Nandi Parthasarathi ನಿಮ್ಮ ಅಪ್ಪ ದೊಡ್ ಗಾಂಡು ಸೂಳೆಮಗ        Negative
# 687                               Hugi guru badethawke        Negative
# 688                                  Trending no.1 wow        Positive
# 689  @Troll Stupid Fans naanu adikke kano helthirod...        Positive
# 690  @JustAn Opinion ninu Tika mucchu...Evattu Kann...        Positive
#
#                                             text_trans
# 0    ಬಿಂದೂಗೇ ಸರ್ಯಗೀ ಉಗೀಥೀದೀರಾ ಗುಡ್ ಗೋ ಅಹೆಡ್  ವೇ ಅರೇ...
# 1                              ಯೇನ ಸೋಂಗ್ ಗುರು ...ಸುಪರ್
# 2                                      ಮೀ ಫೆವರತ ಸ್ಟೋರಿ
# 3                                    ಸುಪರ್ ತೋಗರಿ ತೀಪ್ಪ
# 4    ನಿಮ್ಮ ಮಾತುಗಳು ಅಕ್ಷರಶಃ ಸತ್ಯ... ನಿಮ್ಮ ಈ ಸಾಮಾನ್ಯ ...
# ..                                                 ...
# 686      @ನಂದೀ ಪಾರ್ಥಾಸರಥೀ ನಿಮ್ಮ ಅಪ್ಪ ದೊಡ್ ಗಾಂಡು ಸೂಳೆಮಗ
# 687                                  ಹುಗೀ ಗುರು ಬದೇತಾಕೆ
# 688                                 ಟ್ರೆಂಡಿಂಗ್ ನೋ.1 ವೋ
# 689  @ಟ್ರೋಲ್ ಸ್ತುಪಿಡ್ ಫಂಸ ನಾನು ಆದಿಕಏ ಕಾನೋ ಹೇಲ್ಥೀರೋದ...
# 690  @ಜುಸ್ತಾನ್ ಓಪಿನಿಯೋನ್ ನೀನು ಟಿಕಾ ಮುಕ್ಚು...ಇವತ್ತು ...
#
# [691 rows x 3 columns]

# %%
'''
Preprocess a string.
:parameter
    :param text: string - name of column containing text
    :param lst_stopwords: list - list of stopwords to remove
:return
    cleaned text
'''
def utils_preprocess_text(text, lst_stopwords=None):
    ## clean (convert to lowercase and remove punctuations and characters and then strip)
    text = re.sub(r'[^\w\s]', '', str(text).lower().strip())
            
    ## Tokenize (convert from string to list)
    lst_text = text.split()
    ## remove Stopwords
    if lst_stopwords is not None:
        lst_text = [word for word in lst_text if word not in 
                    lst_stopwords]
                
    ## back to string from list
    text = " ".join(lst_text)
    return text

# %%
#Now we can apply the preprocessing function to our data

kan_train["text_clean"] = kan_train["text_trans"].apply(lambda x: 
          utils_preprocess_text(x, lst_stopwords=lst_stopwords))

kan_dev["text_clean"] = kan_dev["text_trans"].apply(lambda x: 
          utils_preprocess_text(x, lst_stopwords=lst_stopwords))

# %%
kan_train
# Out:
#                                                    text               y  \
# 0     ಒಂದು ದೇಶದ ಮುಂದುವರಿಯುವುದು ಅದರ ಆರ್ಥಿಕ ಸ್ಥಿತಿಯನ್ನ...        Negative
# 1     ಕನ್ನಡದಲ್ಲಿ ಡೈಲಿ ಟೆಕ್ ಅಪ್ಡೇಟ್ಸ್ ಪಡೆಯಲು ಸಬ್ಸ್ಕ್ರ...        Positive
# 2                                        Super sar song     not-Kannada
# 3     Tiktokers present situation... nನೋಡುವವರು ಯಾರು ...        Negative
# 4                             Super ಸಾಂಗ್ ವೆರಿ ನೈಸ್....        Positive
# ...                                                 ...             ...
# 6207  @A.R.W   tumbad tanhaji andhadhun aise bahot h...     not-Kannada
# 6208                  പൊളി ഡാൻസ്🥰 രക്ഷിത് ഷെട്ടി മാസ്സ്     not-Kannada
# 6209  Bro...nNeen este Roast madudru...China ne beku...        Negative
# 6210  ಕೌಶಲ್ಯ ಇದ್ದವರ ಸಂಖ್ಯೆ ಕಡಿಮೆ ಇಲ್ಲ ಸರ್ ತುಂಬಾ ಪ್ರತ...        Positive
# 6211                                         26 M Views  Mixed feelings
#
#                                              text_trans  \
# 0     ಒಂದು ದೇಶದ ಮುಂದುವರಿಯುವುದು ಅದರ ಆರ್ಥಿಕ ಸ್ಥಿತಿಯನ್ನ...
# 1     ಕನ್ನಡದಲ್ಲಿ ಡೈಲಿ ಟೆಕ್ ಅಪ್ಡೇಟ್ಸ್ ಪಡೆಯಲು ಸಬ್ಸ್ಕ್ರ...
# 2                                       ಸುಪರ್ ಸಾರ ಸೋಂಗ್
# 3     ಟೀಕ್ಟೋಕರ್ಸ್ ಪ್ರಸೇಂಟ್ ಸಿತುಂಏಶನ್... ನನೋಡುವವರು ಯಾ...
# 4                             ಸುಪರ್ ಸಾಂಗ್ ವೆರಿ ನೈಸ್....
# ...                                                 ...
# 6207  @ಆ.ರ.ವ್   ಟುಂಬಾದ್ ತನ್ಹಾಜಿ ಅಂಧಾಧುನ ಐಸೆ ಬಹೋತ ಹೈ ...
# 6208                  പൊളി ഡാൻസ്🥰 രക്ഷിത് ഷെട്ടി മാസ്സ്
# 6209  ಬ್ರೊ...ನ್ನೀನ್ ಎಸ್ಟೆ ರೋಸ್ತ ಮದುದ್ರು...ಚೀನಾ ನೇ ಬೇ...
# 6210  ಕೌಶಲ್ಯ ಇದ್ದವರ ಸಂಖ್ಯೆ ಕಡಿಮೆ ಇಲ್ಲ ಸರ್ ತುಂಬಾ ಪ್ರತ...
# 6211                                         26 ಮ ವಿಊಸ್
#
#                                              text_clean
# 0     ಒದ ದಶದ ಮದವರಯವದ ಆರಥಕ ಸಥತಯನನ ಅವಲಬಸವದಲಲ ಮನವಯತಯಲಲ ...
# 1          ಕನನಡದಲಲ ಡಲ ಟಕ ಅಪಡಟಸ ಪಡಯಲ ಸಬಸಕರಬ ಮಡ ನಮಮ ಚನನಲಗ
# 2                                             ಸಪರ ಸರ ಸಗ
# 3                  ಟಕಟಕರಸ ಪರಸಟ ಸತಏಶನ ನನಡವವರ ಯರ ನಮಮ ವಡಯನ
# 4                                          ಸಪರ ಸಗ ವರ ನಸ
# ...                                                 ...
# 6207  ಆರವ ಟಬದ ತನಹಜ ಅಧಧನ ಐಸ ಬಹತ ಹ ಪರ ಕಸಕ ಬಟಕ ಕಯ ಫದ ನಹ...
# 6208                                പള ഡൻസ രകഷത ഷടട മസസ
# 6209  ಬರನನನ ಎಸಟ ರಸತ ಮದದರಚನ ಬಕ ಅತರ ಇವರನಲ ಗಣ ಥಗಡ ಶತ ಮಡ...
# 6210  ಕಶಲಯ ಇದದವರ ಸಖಯ ಕಡಮ ಇಲಲ ಸರ ತಬ ಪರತಭವತರದದರ ಇನಫಲಎನ...
# 6211                                           26 ಮ ವಊಸ
#
# [6212 rows x 4 columns]

# %%
# Now we can define our training data and our dev data as well as targets
train = kan_train
test = kan_dev

y_train = kan_train['y'].values
y_test = kan_dev['y'].values

# %% [markdown]
# # Gettint text embeddings from the bert model

# %%
# I'll be using the embeddings from the multilinngual bert model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

tokenizer = AutoTokenizer.from_pretrained('bert-base-multilingual-uncased')
model = AutoModel.from_pretrained('bert-base-multilingual-uncased').to(device)
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-uncased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# We will start by gathering the embeddings for the validation set
cls_val_list = []
batch_size = 1000

for batch_number, batch_test in test.groupby(np.arange(len(test)) // batch_size):
    # tokanizing the text
    tokenized_val = tokenizer(batch_test["text_clean"].values.tolist() , padding = 'max_length', truncation = True,  return_tensors="pt", max_length=256)

    # move on device (GPU)
    tokenized_val = {k:torch.tensor(v).to(device) for k,v in tokenized_val.items()}

    # get the cls hidden state
    with torch.no_grad():
        hidden_val = model(**tokenized_val)
            
    #get only the [CLS] hidden states
    cls_val = hidden_val.last_hidden_state[:,0,:]
    cls_val = cls_val.to("cpu")
    cls_val_list.append(cls_val)
    del cls_val
    del hidden_val
    del tokenized_val
    
    torch.cuda.empty_cache()

cls_val_list_final = []
for i in range(len(cls_val_list)):
    for j in range(len(cls_val_list[i])):
        cls_val_list_final.append(cls_val_list[i][j])
# Out:
# /home/ubuntu/pyenv/lib/python3.6/site-packages/ipykernel_launcher.py:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   # Remove the CWD from sys.path while we load stuff.

# %%
# Get embeddigns for the trainins set
cls_train_list = []
batch_size = 1000

for batch_number, batch_train in train.groupby(np.arange(len(train)) // batch_size):
    # tokanizing the text
    tokenized_train = tokenizer(batch_train["text_clean"].values.tolist() , padding = 'max_length', truncation = True,  return_tensors="pt", max_length=256)

    # move on device (GPU)
    tokenized_train = {k:torch.tensor(v).to(device) for k,v in tokenized_train.items()}

    # get the cls hidden state
    with torch.no_grad():
        hidden_train = model(**tokenized_train)
            
    #get only the [CLS] hidden states
    cls_train = hidden_train.last_hidden_state[:,0,:]
    cls_train = cls_train.to("cpu")
    cls_train_list.append(cls_train)
    del cls_train
    del hidden_train
    del tokenized_train
    
    torch.cuda.empty_cache()

cls_train_list_final = []
for i in range(len(cls_train_list)):
    for j in range(len(cls_train_list[i])):
        cls_train_list_final.append(cls_train_list[i][j])
# Out:
# /home/ubuntu/pyenv/lib/python3.6/site-packages/ipykernel_launcher.py:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   # Remove the CWD from sys.path while we load stuff.

# %%
# Move the poutput embeddigns for the trainign and validation sets into a dataframe
X_train = torch.stack(cls_train_list_final)
X_train = pd.DataFrame(X_train)

X_test = torch.stack(cls_val_list_final)
X_test = pd.DataFrame(X_test)

y_train = kan_train['y'].values
y_test = kan_dev['y'].values

# %% [markdown]
# # Training a cat boost classifier

# %%
from catboost import CatBoostClassifier
classifier = CatBoostClassifier(iterations=150, learning_rate=.5)

# %%
## train classifier
classifier.fit(X_train, y_train)
predicted = classifier.predict(X_test)

predicted_prob = classifier.predict_proba(X_test)
# Out:
# 0:	learn: 1.3942988	total: 537ms	remaining: 1m 20s
# 1:	learn: 1.3265240	total: 889ms	remaining: 1m 5s
# 2:	learn: 1.2782460	total: 1.25s	remaining: 1m 1s
# 3:	learn: 1.2431024	total: 1.61s	remaining: 59s
# 4:	learn: 1.2100898	total: 1.97s	remaining: 57.2s
# 5:	learn: 1.1901691	total: 2.33s	remaining: 55.9s
# 6:	learn: 1.1661307	total: 2.71s	remaining: 55.4s
# 7:	learn: 1.1497834	total: 3.07s	remaining: 54.5s
# 8:	learn: 1.1345137	total: 3.44s	remaining: 53.8s
# 9:	learn: 1.1212390	total: 3.79s	remaining: 53.1s
# 10:	learn: 1.1104832	total: 4.16s	remaining: 52.5s
# 11:	learn: 1.1008817	total: 4.51s	remaining: 51.9s
# 12:	learn: 1.0846930	total: 4.87s	remaining: 51.3s
# 13:	learn: 1.0722295	total: 5.23s	remaining: 50.8s
# 14:	learn: 1.0591695	total: 5.59s	remaining: 50.3s
# 15:	learn: 1.0427979	total: 5.97s	remaining: 50s
# 16:	learn: 1.0303178	total: 6.32s	remaining: 49.5s
# 17:	learn: 1.0204147	total: 6.68s	remaining: 49s
# 18:	learn: 1.0112855	total: 7.03s	remaining: 48.4s
# 19:	learn: 1.0005360	total: 7.37s	remaining: 47.9s
# 20:	learn: 0.9895483	total: 7.72s	remaining: 47.4s
# 21:	learn: 0.9796880	total: 8.07s	remaining: 47s
# 22:	learn: 0.9694337	total: 8.43s	remaining: 46.6s
# 23:	learn: 0.9596003	total: 8.79s	remaining: 46.1s
# 24:	learn: 0.9474135	total: 9.15s	remaining: 45.8s
# 25:	learn: 0.9372679	total: 9.5s	remaining: 45.3s
# 26:	learn: 0.9268734	total: 9.85s	remaining: 44.9s
# 27:	learn: 0.9152083	total: 10.2s	remaining: 44.5s
# 28:	learn: 0.9070513	total: 10.6s	remaining: 44.1s
# 29:	learn: 0.9014799	total: 10.9s	remaining: 43.7s
# 30:	learn: 0.8923111	total: 11.3s	remaining: 43.3s
# 31:	learn: 0.8829056	total: 11.6s	remaining: 42.9s
# 32:	learn: 0.8748419	total: 12s	remaining: 42.5s
# 33:	learn: 0.8655687	total: 12.3s	remaining: 42.1s
# 34:	learn: 0.8576204	total: 12.7s	remaining: 41.7s
# 35:	learn: 0.8500590	total: 13s	remaining: 41.3s
# 36:	learn: 0.8408632	total: 13.4s	remaining: 40.9s
# 37:	learn: 0.8343516	total: 13.8s	remaining: 40.5s
# 38:	learn: 0.8288287	total: 14.1s	remaining: 40.1s
# 39:	learn: 0.8188095	total: 14.5s	remaining: 39.7s
# 40:	learn: 0.8118122	total: 14.8s	remaining: 39.3s
# 41:	learn: 0.8041586	total: 15.1s	remaining: 38.9s
# 42:	learn: 0.7971242	total: 15.5s	remaining: 38.5s
# 43:	learn: 0.7904184	total: 15.8s	remaining: 38.1s
# 44:	learn: 0.7829220	total: 16.2s	remaining: 37.8s
# 45:	learn: 0.7774063	total: 16.5s	remaining: 37.4s
# 46:	learn: 0.7687478	total: 16.9s	remaining: 37s
# 47:	learn: 0.7611919	total: 17.2s	remaining: 36.6s
# 48:	learn: 0.7558063	total: 17.6s	remaining: 36.3s
# 49:	learn: 0.7498029	total: 17.9s	remaining: 35.9s
# 50:	learn: 0.7438678	total: 18.3s	remaining: 35.5s
# 51:	learn: 0.7351614	total: 18.6s	remaining: 35.1s
# 52:	learn: 0.7291203	total: 19s	remaining: 34.8s
# 53:	learn: 0.7217803	total: 19.4s	remaining: 34.4s
# 54:	learn: 0.7170604	total: 19.7s	remaining: 34s
# 55:	learn: 0.7093733	total: 20.1s	remaining: 33.7s
# 56:	learn: 0.7038219	total: 20.4s	remaining: 33.3s
# 57:	learn: 0.6973571	total: 20.8s	remaining: 32.9s
# 58:	learn: 0.6911210	total: 21.1s	remaining: 32.5s
# 59:	learn: 0.6849429	total: 21.4s	remaining: 32.2s
# 60:	learn: 0.6758060	total: 21.8s	remaining: 31.8s
# 61:	learn: 0.6707170	total: 22.1s	remaining: 31.4s
# 62:	learn: 0.6644537	total: 22.5s	remaining: 31s
# 63:	learn: 0.6556547	total: 22.8s	remaining: 30.7s
# 64:	learn: 0.6508127	total: 23.2s	remaining: 30.3s
# 65:	learn: 0.6448944	total: 23.5s	remaining: 29.9s
# 66:	learn: 0.6387890	total: 23.9s	remaining: 29.6s
# 67:	learn: 0.6293898	total: 24.2s	remaining: 29.2s
# 68:	learn: 0.6223991	total: 24.6s	remaining: 28.9s
# 69:	learn: 0.6145202	total: 24.9s	remaining: 28.5s
# 70:	learn: 0.6083833	total: 25.3s	remaining: 28.1s
# 71:	learn: 0.6040984	total: 25.6s	remaining: 27.8s
# 72:	learn: 0.5997041	total: 26s	remaining: 27.4s
# 73:	learn: 0.5958564	total: 26.3s	remaining: 27s
# 74:	learn: 0.5915597	total: 26.7s	remaining: 26.7s
# 75:	learn: 0.5862045	total: 27s	remaining: 26.3s
# 76:	learn: 0.5819409	total: 27.4s	remaining: 26s
# 77:	learn: 0.5794816	total: 27.7s	remaining: 25.6s
# 78:	learn: 0.5747682	total: 28.1s	remaining: 25.2s
# 79:	learn: 0.5687580	total: 28.4s	remaining: 24.9s
# 80:	learn: 0.5648835	total: 28.8s	remaining: 24.5s
# 81:	learn: 0.5587363	total: 29.2s	remaining: 24.2s
# 82:	learn: 0.5544466	total: 29.5s	remaining: 23.8s
# 83:	learn: 0.5513295	total: 29.9s	remaining: 23.5s
# 84:	learn: 0.5465505	total: 30.2s	remaining: 23.1s
# 85:	learn: 0.5420767	total: 30.5s	remaining: 22.7s
# 86:	learn: 0.5380026	total: 30.9s	remaining: 22.4s
# 87:	learn: 0.5338075	total: 31.2s	remaining: 22s
# 88:	learn: 0.5309826	total: 31.6s	remaining: 21.6s
# 89:	learn: 0.5287095	total: 31.9s	remaining: 21.3s
# 90:	learn: 0.5260840	total: 32.3s	remaining: 20.9s
# 91:	learn: 0.5225792	total: 32.6s	remaining: 20.6s
# 92:	learn: 0.5194476	total: 33s	remaining: 20.2s
# 93:	learn: 0.5144887	total: 33.3s	remaining: 19.8s
# 94:	learn: 0.5110365	total: 33.7s	remaining: 19.5s
# 95:	learn: 0.5084108	total: 34s	remaining: 19.1s
# 96:	learn: 0.5047305	total: 34.4s	remaining: 18.8s
# 97:	learn: 0.5020701	total: 34.7s	remaining: 18.4s
# 98:	learn: 0.4990457	total: 35s	remaining: 18.1s
# 99:	learn: 0.4951020	total: 35.4s	remaining: 17.7s
# 100:	learn: 0.4895636	total: 35.8s	remaining: 17.3s
# 101:	learn: 0.4870412	total: 36.1s	remaining: 17s
# 102:	learn: 0.4829441	total: 36.5s	remaining: 16.6s
# 103:	learn: 0.4797303	total: 36.8s	remaining: 16.3s
# 104:	learn: 0.4759764	total: 37.2s	remaining: 15.9s
# 105:	learn: 0.4704377	total: 37.5s	remaining: 15.6s
# 106:	learn: 0.4670879	total: 37.9s	remaining: 15.2s
# 107:	learn: 0.4636203	total: 38.2s	remaining: 14.9s
# 108:	learn: 0.4595143	total: 38.6s	remaining: 14.5s
# 109:	learn: 0.4546629	total: 39s	remaining: 14.2s
# 110:	learn: 0.4514607	total: 39.3s	remaining: 13.8s
# 111:	learn: 0.4488198	total: 39.7s	remaining: 13.5s
# 112:	learn: 0.4434514	total: 40s	remaining: 13.1s
# 113:	learn: 0.4408783	total: 40.4s	remaining: 12.7s
# 114:	learn: 0.4378852	total: 40.7s	remaining: 12.4s
# 115:	learn: 0.4358298	total: 41.1s	remaining: 12s
# 116:	learn: 0.4322953	total: 41.4s	remaining: 11.7s
# 117:	learn: 0.4300321	total: 41.8s	remaining: 11.3s
# 118:	learn: 0.4277794	total: 42.1s	remaining: 11s
# 119:	learn: 0.4258377	total: 42.4s	remaining: 10.6s
# 120:	learn: 0.4217925	total: 42.8s	remaining: 10.3s
# 121:	learn: 0.4207203	total: 43.1s	remaining: 9.9s
# 122:	learn: 0.4180973	total: 43.5s	remaining: 9.54s
# 123:	learn: 0.4142075	total: 43.8s	remaining: 9.19s
# 124:	learn: 0.4095377	total: 44.2s	remaining: 8.84s
# 125:	learn: 0.4064197	total: 44.5s	remaining: 8.48s
# 126:	learn: 0.4037986	total: 44.9s	remaining: 8.13s
# 127:	learn: 0.4013958	total: 45.2s	remaining: 7.77s
# 128:	learn: 0.3986614	total: 45.6s	remaining: 7.42s
# 129:	learn: 0.3964114	total: 45.9s	remaining: 7.07s
# 130:	learn: 0.3934005	total: 46.3s	remaining: 6.71s
# 131:	learn: 0.3907547	total: 46.6s	remaining: 6.36s
# 132:	learn: 0.3870012	total: 47s	remaining: 6s
# 133:	learn: 0.3836833	total: 47.3s	remaining: 5.65s
# 134:	learn: 0.3821173	total: 47.7s	remaining: 5.3s
# 135:	learn: 0.3783276	total: 48s	remaining: 4.95s
# 136:	learn: 0.3762111	total: 48.4s	remaining: 4.59s
# 137:	learn: 0.3735607	total: 48.8s	remaining: 4.24s
# 138:	learn: 0.3720445	total: 49.1s	remaining: 3.88s
# 139:	learn: 0.3674083	total: 49.5s	remaining: 3.53s
# 140:	learn: 0.3663772	total: 49.8s	remaining: 3.18s
# 141:	learn: 0.3650745	total: 50.2s	remaining: 2.83s
# 142:	learn: 0.3636116	total: 50.5s	remaining: 2.47s
# 143:	learn: 0.3620192	total: 50.8s	remaining: 2.12s
# 144:	learn: 0.3594051	total: 51.2s	remaining: 1.76s
# 145:	learn: 0.3567541	total: 51.5s	remaining: 1.41s
# 146:	learn: 0.3552477	total: 51.9s	remaining: 1.06s
# 147:	learn: 0.3544565	total: 52.2s	remaining: 706ms
# 148:	learn: 0.3519899	total: 52.6s	remaining: 353ms
# 149:	learn: 0.3494419	total: 52.9s	remaining: 0us

# %%
# lets see our model performance
classes = np.unique(y_test)
y_test_array = pd.get_dummies(y_test, drop_first=False).values
    
## Accuracy, Precision, Recall
accuracy = metrics.accuracy_score(y_test, predicted)
auc = metrics.roc_auc_score(y_test, predicted_prob, 
                            multi_class="ovr")
print("Accuracy:",  round(accuracy,2))
print("Auc:", round(auc,2))
print("Detail:")
print(metrics.classification_report(y_test, predicted))
    
## Plot confusion matrix
cm = metrics.confusion_matrix(y_test, predicted)
fig, ax = plt.subplots()
sns.heatmap(cm, annot=True, fmt='d', ax=ax, cmap=plt.cm.Blues, 
            cbar=False)
ax.set(xlabel="Pred", ylabel="True", xticklabels=classes, 
       yticklabels=classes, title="Confusion matrix")
plt.yticks(rotation=0)

fig, ax = plt.subplots(nrows=1, ncols=2)
## Plot roc
for i in range(len(classes)):
    fpr, tpr, thresholds = metrics.roc_curve(y_test_array[:,i],  
                           predicted_prob[:,i])
    ax[0].plot(fpr, tpr, lw=3, 
              label='{0} (area={1:0.2f})'.format(classes[i], 
                              metrics.auc(fpr, tpr))
               )
ax[0].plot([0,1], [0,1], color='navy', lw=3, linestyle='--')
ax[0].set(xlim=[-0.05,1.0], ylim=[0.0,1.05], 
          xlabel='False Positive Rate', 
          ylabel="True Positive Rate (Recall)", 
          title="Receiver operating characteristic")
ax[0].legend(loc="lower right")
ax[0].grid(True)
    
## Plot precision-recall curve
for i in range(len(classes)):
    precision, recall, thresholds = metrics.precision_recall_curve(
                 y_test_array[:,i], predicted_prob[:,i])
    ax[1].plot(recall, precision, lw=3, 
               label='{0} (area={1:0.2f})'.format(classes[i], 
                                  metrics.auc(recall, precision))
              )
ax[1].set(xlim=[0.0,1.05], ylim=[0.0,1.05], xlabel='Recall', 
          ylabel="Precision", title="Precision-Recall curve")
ax[1].legend(loc="best")
ax[1].grid(True)
plt.show()
# Out:
# Accuracy: 0.53
# Auc: 0.74
# Detail:
#                 precision    recall  f1-score   support
#
# Mixed feelings       0.24      0.10      0.14        52
#       Negative       0.48      0.40      0.44       139
#       Positive       0.57      0.72      0.64       321
#    not-Kannada       0.61      0.55      0.58       110
#  unknown state       0.31      0.22      0.26        69
#
#       accuracy                           0.53       691
#      macro avg       0.44      0.40      0.41       691
#   weighted avg       0.51      0.53      0.51       691

# %% [markdown]
# # Training a Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(max_depth=150, n_estimators=15, max_features=768)

# %%
## train classifier
classifier.fit(X_train, y_train)
## test
predicted = classifier.predict(X_test)
predicted_prob = classifier.predict_proba(X_test)

# %%
# lets see our model performance
classes = np.unique(y_test)
y_test_array = pd.get_dummies(y_test, drop_first=False).values
    
## Accuracy, Precision, Recall
accuracy = metrics.accuracy_score(y_test, predicted)
auc = metrics.roc_auc_score(y_test, predicted_prob, 
                            multi_class="ovr")
print("Accuracy:",  round(accuracy,2))
print("Auc:", round(auc,2))
print("Detail:")
print(metrics.classification_report(y_test, predicted))
    
## Plot confusion matrix
cm = metrics.confusion_matrix(y_test, predicted)
fig, ax = plt.subplots()
sns.heatmap(cm, annot=True, fmt='d', ax=ax, cmap=plt.cm.Blues, 
            cbar=False)
ax.set(xlabel="Pred", ylabel="True", xticklabels=classes, 
       yticklabels=classes, title="Confusion matrix")
plt.yticks(rotation=0)

fig, ax = plt.subplots(nrows=1, ncols=2)
## Plot roc
for i in range(len(classes)):
    fpr, tpr, thresholds = metrics.roc_curve(y_test_array[:,i],  
                           predicted_prob[:,i])
    ax[0].plot(fpr, tpr, lw=3, 
              label='{0} (area={1:0.2f})'.format(classes[i], 
                              metrics.auc(fpr, tpr))
               )
ax[0].plot([0,1], [0,1], color='navy', lw=3, linestyle='--')
ax[0].set(xlim=[-0.05,1.0], ylim=[0.0,1.05], 
          xlabel='False Positive Rate', 
          ylabel="True Positive Rate (Recall)", 
          title="Receiver operating characteristic")
ax[0].legend(loc="lower right")
ax[0].grid(True)
    
## Plot precision-recall curve
for i in range(len(classes)):
    precision, recall, thresholds = metrics.precision_recall_curve(
                 y_test_array[:,i], predicted_prob[:,i])
    ax[1].plot(recall, precision, lw=3, 
               label='{0} (area={1:0.2f})'.format(classes[i], 
                                  metrics.auc(recall, precision))
              )
ax[1].set(xlim=[0.0,1.05], ylim=[0.0,1.05], xlabel='Recall', 
          ylabel="Precision", title="Precision-Recall curve")
ax[1].legend(loc="best")
ax[1].grid(True)
plt.show()
# Out:
# Accuracy: 0.51
# Auc: 0.71
# Detail:
#                 precision    recall  f1-score   support
#
# Mixed feelings       0.19      0.08      0.11        52
#       Negative       0.43      0.34      0.38       139
#       Positive       0.56      0.76      0.64       321
#    not-Kannada       0.56      0.45      0.50       110
#  unknown state       0.32      0.16      0.21        69
#
#       accuracy                           0.51       691
#      macro avg       0.41      0.36      0.37       691
#   weighted avg       0.48      0.51      0.48       691

# %% [markdown]
# # fitting a logistic regression classifier

# %%
from sklearn.linear_model import LogisticRegression
classifier =LogisticRegression(random_state=0, max_iter= 300)

# %%
## pipeline

## train classifier
classifier.fit(X_train, y_train)
## test
predicted = classifier.predict(X_test)
predicted_prob = classifier.predict_proba(X_test)
# Out:
# /home/ubuntu/pyenv/lib/python3.6/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
# lets see our model performance
classes = np.unique(y_test)
y_test_array = pd.get_dummies(y_test, drop_first=False).values
    
## Accuracy, Precision, Recall
accuracy = metrics.accuracy_score(y_test, predicted)
auc = metrics.roc_auc_score(y_test, predicted_prob, 
                            multi_class="ovr")
print("Accuracy:",  round(accuracy,2))
print("Auc:", round(auc,2))
print("Detail:")
print(metrics.classification_report(y_test, predicted))
    
## Plot confusion matrix
cm = metrics.confusion_matrix(y_test, predicted)
fig, ax = plt.subplots()
sns.heatmap(cm, annot=True, fmt='d', ax=ax, cmap=plt.cm.Blues, 
            cbar=False)
ax.set(xlabel="Pred", ylabel="True", xticklabels=classes, 
       yticklabels=classes, title="Confusion matrix")
plt.yticks(rotation=0)

fig, ax = plt.subplots(nrows=1, ncols=2)
## Plot roc
for i in range(len(classes)):
    fpr, tpr, thresholds = metrics.roc_curve(y_test_array[:,i],  
                           predicted_prob[:,i])
    ax[0].plot(fpr, tpr, lw=3, 
              label='{0} (area={1:0.2f})'.format(classes[i], 
                              metrics.auc(fpr, tpr))
               )
ax[0].plot([0,1], [0,1], color='navy', lw=3, linestyle='--')
ax[0].set(xlim=[-0.05,1.0], ylim=[0.0,1.05], 
          xlabel='False Positive Rate', 
          ylabel="True Positive Rate (Recall)", 
          title="Receiver operating characteristic")
ax[0].legend(loc="lower right")
ax[0].grid(True)
    
## Plot precision-recall curve
for i in range(len(classes)):
    precision, recall, thresholds = metrics.precision_recall_curve(
                 y_test_array[:,i], predicted_prob[:,i])
    ax[1].plot(recall, precision, lw=3, 
               label='{0} (area={1:0.2f})'.format(classes[i], 
                                  metrics.auc(recall, precision))
              )
ax[1].set(xlim=[0.0,1.05], ylim=[0.0,1.05], xlabel='Recall', 
          ylabel="Precision", title="Precision-Recall curve")
ax[1].legend(loc="best")
ax[1].grid(True)
plt.show()
# Out:
# Accuracy: 0.58
# Auc: 0.81
# Detail:
#                 precision    recall  f1-score   support
#
# Mixed feelings       0.00      0.00      0.00        52
#       Negative       0.57      0.46      0.51       139
#       Positive       0.59      0.83      0.69       321
#    not-Kannada       0.63      0.52      0.57       110
#  unknown state       0.42      0.20      0.27        69
#
#       accuracy                           0.58       691
#      macro avg       0.44      0.40      0.41       691
#   weighted avg       0.53      0.58      0.54       691

# %% [markdown]
# # training a k-neighboot classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=3, weights='distance')

# %%
## train classifier
classifier.fit(X_train, y_train)
## test
predicted = classifier.predict(X_test)
predicted_prob = classifier.predict_proba(X_test)

# %%
# lets see our model performance
classes = np.unique(y_test)
y_test_array = pd.get_dummies(y_test, drop_first=False).values
    
## Accuracy, Precision, Recall
accuracy = metrics.accuracy_score(y_test, predicted)
auc = metrics.roc_auc_score(y_test, predicted_prob, 
                            multi_class="ovr")
print("Accuracy:",  round(accuracy,2))
print("Auc:", round(auc,2))
print("Detail:")
print(metrics.classification_report(y_test, predicted))
    
## Plot confusion matrix
cm = metrics.confusion_matrix(y_test, predicted)
fig, ax = plt.subplots()
sns.heatmap(cm, annot=True, fmt='d', ax=ax, cmap=plt.cm.Blues, 
            cbar=False)
ax.set(xlabel="Pred", ylabel="True", xticklabels=classes, 
       yticklabels=classes, title="Confusion matrix")
plt.yticks(rotation=0)

fig, ax = plt.subplots(nrows=1, ncols=2)
## Plot roc
for i in range(len(classes)):
    fpr, tpr, thresholds = metrics.roc_curve(y_test_array[:,i],  
                           predicted_prob[:,i])
    ax[0].plot(fpr, tpr, lw=3, 
              label='{0} (area={1:0.2f})'.format(classes[i], 
                              metrics.auc(fpr, tpr))
               )
ax[0].plot([0,1], [0,1], color='navy', lw=3, linestyle='--')
ax[0].set(xlim=[-0.05,1.0], ylim=[0.0,1.05], 
          xlabel='False Positive Rate', 
          ylabel="True Positive Rate (Recall)", 
          title="Receiver operating characteristic")
ax[0].legend(loc="lower right")
ax[0].grid(True)
    
## Plot precision-recall curve
for i in range(len(classes)):
    precision, recall, thresholds = metrics.precision_recall_curve(
                 y_test_array[:,i], predicted_prob[:,i])
    ax[1].plot(recall, precision, lw=3, 
               label='{0} (area={1:0.2f})'.format(classes[i], 
                                  metrics.auc(recall, precision))
              )
ax[1].set(xlim=[0.0,1.05], ylim=[0.0,1.05], xlabel='Recall', 
          ylabel="Precision", title="Precision-Recall curve")
ax[1].legend(loc="best")
ax[1].grid(True)
plt.show()
# Out:
# Accuracy: 0.54
# Auc: 0.69
# Detail:
#                 precision    recall  f1-score   support
#
# Mixed feelings       0.17      0.13      0.15        52
#       Negative       0.56      0.46      0.51       139
#       Positive       0.61      0.70      0.65       321
#    not-Kannada       0.55      0.52      0.54       110
#  unknown state       0.31      0.29      0.30        69
#
#       accuracy                           0.54       691
#      macro avg       0.44      0.42      0.43       691
#   weighted avg       0.53      0.54      0.53       691
