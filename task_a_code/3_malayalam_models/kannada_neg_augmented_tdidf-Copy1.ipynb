# %%
## for data
import json
import pandas as pd
import numpy as np
## for plotting
import matplotlib.pyplot as plt
import seaborn as sns
## for processing
import re
import nltk
## for bag-of-words
from sklearn import metrics, feature_extraction, feature_selection, model_selection, naive_bayes, pipeline, manifold, preprocessing
## for explainer
from lime import lime_text
## for word embedding
import gensim
import gensim.downloader as gensim_api
## for deep learning
from tensorflow.keras import models, layers, preprocessing as kprocessing
from tensorflow.keras import backend as K

## for bert language model
import transformers

# %%
''' The following shows the result of training various non-nerual network models on an augemnted version of the 
Kannada set with negative lebel equalling the positive lebel. models are trained on an tf-idf vectorizer
with dimensionality reduction.'''
# Out:
# ' The following shows the result of training various non-nerual network models on an augemnted version of the \nKannada set with negative lebel equalling the positive lebel. models are trained on an tf-idf vectorizer\nwith dimensionality reduction.'

# %%
# import data
kan_train = pd.read_table("../../datasets/task_a/augmented/kan_train_negative_augmented.tsv")
kan_dev = pd.read_table("../../datasets/task_a/kan_sentiment_dev.tsv")

# %%
kan_train = kan_train.rename(columns={'category': 'y'})
kan_dev = kan_dev.rename(columns={'category': 'y'})

# %%
kan_dev
# Out:
#                                                   text               y
# 0    Binduge saryagi ugithidira good go ahead  we a...  Mixed feelings
# 1                               yen song guru ...super        Positive
# 2                                     my fevorat story     not-Kannada
# 3                                    Super ತೋಗರಿ ತೀಪ್ಪ        Positive
# 4    ನಿಮ್ಮ ಮಾತುಗಳು ಅಕ್ಷರಶಃ ಸತ್ಯ... ನಿಮ್ಮ ಈ ಸಾಮಾನ್ಯ ...        Positive
# ..                                                 ...             ...
# 686  @Nandi Parthasarathi ನಿಮ್ಮ ಅಪ್ಪ ದೊಡ್ ಗಾಂಡು ಸೂಳೆಮಗ        Negative
# 687                               Hugi guru badethawke        Negative
# 688                                  Trending no.1 wow        Positive
# 689  @Troll Stupid Fans naanu adikke kano helthirod...        Positive
# 690  @JustAn Opinion ninu Tika mucchu...Evattu Kann...        Positive
#
# [691 rows x 2 columns]

# %%
fig, ax = plt.subplots()
fig.suptitle("y", fontsize=12)
kan_train.groupby("y").count().plot(kind="barh", legend=False, 
        ax=ax).grid(axis='x')
plt.show()

# %%
kan_train
# Out:
#                                                    text            y
# 0     ಒಂದು ದೇಶದ ಮುಂದುವರಿಯುವುದು ಅದರ ಆರ್ಥಿಕ ಸ್ಥಿತಿಯನ್ನ...     Negative
# 1     ಕನ್ನಡದಲ್ಲಿ ಡೈಲಿ ಟೆಕ್ ಅಪ್ಡೇಟ್ಸ್ ಪಡೆಯಲು ಸಬ್ಸ್ಕ್ರ...     Positive
# 2                                        Super sar song  not-Kannada
# 3     Tiktokers present situation... nನೋಡುವವರು ಯಾರು ...     Negative
# 4                             Super ಸಾಂಗ್ ವೆರಿ ನೈಸ್....     Positive
# ...                                                 ...          ...
# 7842      ಇಡೈಲಾ ಕೆಜಿಎಫ್ ಬಿಜಿಎಂ ಕೆಡತು ಎನಕು ಮಧುಮಥಾನ 🤔🤔🤔🤔🤯     Negative
# 7843                 ಜಯಲಲಿತಾ ಮೇಡಂ ಅವರಿಗೆ ಅಮೋಘ ನಿಗ್ರಹ...     Negative
# 7844                ದಯವಿಟ್ಟು ಎಲ್ಲದರ ಚಿತ್ರ ತೆಗೆಯಿರಿ ಸರ್.     Negative
# 7845  ಭಾರತದ ಅತಿ ದೊಡ್ಡ ಹೆದ್ದಾರಿ! ಭಾರತದ ದೊಡ್ಡ ತಾರೆಗಳು!...     Negative
# 7846        ವಾವ್ ರಜಿನಿ ಕರು ರಾಜಿಜಿ ಪಾಲ್ಸ್ ಲೈಕ್ ಹಿಟ್ ಮಾಡಿ     Negative
#
# [7847 rows x 2 columns]

# %%
# Now we can define our training data and our dev data as well as targets
train = kan_train
test = kan_dev

y_train = kan_train['y'].values
y_test = kan_dev['y'].values

# %% [markdown]
# ## Using Tf-Idf vectorizer

# %%
## Count (classic BoW)
#vectorizer = feature_extraction.text.CountVectorizer(max_features=10000, ngram_range=(1,2))

## Tf-Idf (advanced variant of BoW)
vectorizer = feature_extraction.text.TfidfVectorizer(max_features=10000, ngram_range=(1,2))

# %%
# now run thse vectorizers on the train data
corpus = train["text"]
vectorizer.fit(corpus)
X_train = vectorizer.transform(corpus)
dic_vocabulary = vectorizer.vocabulary_

# %%
X_train
# Out:
# <7847x10000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 56107 stored elements in Compressed Sparse Row format>

# %%
sns.heatmap(X_train.todense()[:,np.random.randint(0,X_train.shape[1],100)]==0, vmin=0, vmax=1, cbar=False).set_title('Sparse Matrix Sample')
# Out:
# Text(0.5, 1.0, 'Sparse Matrix Sample')

# %% [markdown]
# ## reducing the vectorizers dimensionality

# %%
# reduce dimensionality through feature selection

y = y_train
X_names = vectorizer.get_feature_names()
p_value_limit = 0.95

dtf_features = pd.DataFrame()
for cat in np.unique(y):
    chi2, p = feature_selection.chi2(X_train, y==cat)
    dtf_features = dtf_features.append(pd.DataFrame(
                   {"feature":X_names, "score":1-p, "y":cat}))
    dtf_features = dtf_features.sort_values(["y","score"], 
                    ascending=[True,False])
    dtf_features = dtf_features[dtf_features["score"]>p_value_limit]
X_names = dtf_features["feature"].unique().tolist()

# %%
for cat in np.unique(y):
   print("# {}:".format(cat))
   print("  . selected features:",
         len(dtf_features[dtf_features["y"]==cat]))
   print("  . top features:", ",".join(
dtf_features[dtf_features["y"]==cat]["feature"].values[:10]))
   print(" ")
# Out:
# # Mixed feelings:
#   . selected features: 410
#   . top features: game,yava game,game name,yavadu,game yavdu,ಅದ ಪದ,bro game,bigg boss,32,game yavadu
#
# # Negative:
#   . selected features: 392
#   . top features: super,ಲರ,song,bro,ಅಜ,ಇಲ,ಜಯ,ಆಹ,ಎಲ,ದರ
#
# # Positive:
#   . selected features: 189
#   . top features: ದನ ಗಡ,ಗಡ ಇದ,ಪರ,guru,ಚರ,ದನ,ಅವತ,anna,ಇದ ಚರ,ಚರ ಅವತ
#
# # not-Kannada:
#   . selected features: 475
#   . top features: bro,super,super bro,super song,song,anjali devi,devi,anjali,super super,nice
#
# # unknown state:
#   . selected features: 447
#   . top features: yes,gta,gta bro,paramvah,paramvah music,lokanath,like,join,yes bro,abhi

# %% [markdown]
# ## re-fitting the vectorizer on the new vocabulary gained through feature reduction

# %%
# we can now refit the vecotrizer on the corpus by giving this new set of words as input.
# producing a smaller feature matrix and a shorter vocabulary.
vectorizer = feature_extraction.text.TfidfVectorizer(vocabulary=X_names)
vectorizer.fit(corpus)
X_train = vectorizer.transform(corpus)
dic_vocabulary = vectorizer.vocabulary_

# %%
X_train.shape
# Out:
# (7847, 1700)

# %%
sns.heatmap(X_train.todense()[:,np.random.randint(0,X_train.shape[1],100)]==0, vmin=0, vmax=1, cbar=False).set_title('Sparse Matrix Sample')
# Out:
# Text(0.5, 1.0, 'Sparse Matrix Sample')

# %% [markdown]
# # Training a Naive Bayes Classifier

# %%
# Now we can train a model. i'm using a naive bayes classifier
classifier = naive_bayes.MultinomialNB()

# %%
## pipeline
model = pipeline.Pipeline([("vectorizer", vectorizer),  
                           ("classifier", classifier)])
## train classifier
model["classifier"].fit(X_train, y_train)
## test
X_test = test["text"].values
predicted = model.predict(X_test)
predicted_prob = model.predict_proba(X_test)

# %%
# lets see our model performance
classes = np.unique(y_test)
y_test_array = pd.get_dummies(y_test, drop_first=False).values
    
## Accuracy, Precision, Recall
accuracy = metrics.accuracy_score(y_test, predicted)
auc = metrics.roc_auc_score(y_test, predicted_prob, 
                            multi_class="ovr")
print("Accuracy:",  round(accuracy,2))
print("Auc:", round(auc,2))
print("Detail:")
print(metrics.classification_report(y_test, predicted))
    
## Plot confusion matrix
cm = metrics.confusion_matrix(y_test, predicted)
fig, ax = plt.subplots()
sns.heatmap(cm, annot=True, fmt='d', ax=ax, cmap=plt.cm.Blues, 
            cbar=False)
ax.set(xlabel="Pred", ylabel="True", xticklabels=classes, 
       yticklabels=classes, title="Confusion matrix")
plt.yticks(rotation=0)

fig, ax = plt.subplots(nrows=1, ncols=2)
## Plot roc
for i in range(len(classes)):
    fpr, tpr, thresholds = metrics.roc_curve(y_test_array[:,i],  
                           predicted_prob[:,i])
    ax[0].plot(fpr, tpr, lw=3, 
              label='{0} (area={1:0.2f})'.format(classes[i], 
                              metrics.auc(fpr, tpr))
               )
ax[0].plot([0,1], [0,1], color='navy', lw=3, linestyle='--')
ax[0].set(xlim=[-0.05,1.0], ylim=[0.0,1.05], 
          xlabel='False Positive Rate', 
          ylabel="True Positive Rate (Recall)", 
          title="Receiver operating characteristic")
ax[0].legend(loc="lower right")
ax[0].grid(True)
    
## Plot precision-recall curve
for i in range(len(classes)):
    precision, recall, thresholds = metrics.precision_recall_curve(
                 y_test_array[:,i], predicted_prob[:,i])
    ax[1].plot(recall, precision, lw=3, 
               label='{0} (area={1:0.2f})'.format(classes[i], 
                                  metrics.auc(recall, precision))
              )
ax[1].set(xlim=[0.0,1.05], ylim=[0.0,1.05], xlabel='Recall', 
          ylabel="Precision", title="Precision-Recall curve")
ax[1].legend(loc="best")
ax[1].grid(True)
plt.show()
# Out:
# Accuracy: 0.52
# Auc: 0.77
# Detail:
#                 precision    recall  f1-score   support
#
# Mixed feelings       1.00      0.02      0.04        52
#       Negative       0.38      0.63      0.48       139
#       Positive       0.57      0.73      0.64       321
#    not-Kannada       0.64      0.25      0.36       110
#  unknown state       0.55      0.09      0.15        69
#
#       accuracy                           0.52       691
#      macro avg       0.63      0.34      0.33       691
#   weighted avg       0.58      0.52      0.47       691

# %%
#expolainer

## select observation
i = 1
txt_instance = test["text"].iloc[i]
## check true value and predicted value
print("True:", y_test[i], "--> Pred:", predicted[i], "| Prob:", round(np.max(predicted_prob[i]),2))
## show explanation
explainer = lime_text.LimeTextExplainer(class_names=
             np.unique(y_train))
explained = explainer.explain_instance(txt_instance, 
             model.predict_proba, num_features=3)
explained.show_in_notebook(text=txt_instance, predict_proba=False)
# Out:
# True: Positive --> Pred: Positive | Prob: 0.89
# /home/ubuntu/pyenv/lib/python3.6/site-packages/lime/lime_text.py:114: FutureWarning: split() requires a non-empty pattern match.
#   self.as_list = [s for s in splitter.split(self.raw) if s]
# <html>
#         <meta http-equiv="content-type" content="text/html; charset=UTF8">
#         <head><script>var lime =
# /******/ (function(modules) { // webpackBootstrap
# /******/ 	// The module cache
# /******/ 	var installedModules = {};
# /******/
# /******/ 	// The require function
# /******/ 	function __webpack_require__(moduleId) {
# /******/
# /******/ 		// Check if module is in cache
# /******/ 		if(installedModules[moduleId])
# /******/ 			return installedModules[moduleId].exports;
# /******/
# /******/ 		// Create a new module (and put it into the cache)
# /******/ 		var module = installedModules[moduleId] = {
# /******/ 			exports: {},
# /******/ 			id: moduleId,
# /******/ 			loaded: false
# /******/ 		};
# /******/
# /******/ 		// Execute the module function
# /******/ 		modules[moduleId].call(module.exports, module, module.exports, __webpack_require__);
# /******/
# /******/ 		// Flag the module as loaded
# /******/ 		module.loaded = true;
# /******/
# /******/ 		// Return the exports of the module
# /******/ 		return module.exports;
# /******/ 	}
# /******/
# /******/
# /******/ 	// expose the modules object (__webpack_modules__)
# /******/ 	__webpack_require__.m = modules;
# /******/
# /******/ 	// expose the module cache
# /******/ 	__webpack_require__.c = installedModules;
# /******/
# /******/ 	// __webpack_public_path__
# /******/ 	__webpack_require__.p = "";
# /******/
# /******/ 	// Load entry module and return exports
# /******/ 	return __webpack_require__(0);
# /******/ })
# /************************************************************************/
# /******/ ([
# /* 0 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	/* WEBPACK VAR INJECTION */(function(global) {'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
# 	exports.PredictedValue = exports.PredictProba = exports.Barchart = exports.Explanation = undefined;
#
# 	var _explanation = __webpack_require__(1);
#
# 	var _explanation2 = _interopRequireDefault(_explanation);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _predict_proba = __webpack_require__(6);
#
# 	var _predict_proba2 = _interopRequireDefault(_predict_proba);
#
# 	var _predicted_value = __webpack_require__(7);
#
# 	var _predicted_value2 = _interopRequireDefault(_predicted_value);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	if (!global._babelPolyfill) {
# 	  __webpack_require__(8);
# 	}
#
# 	__webpack_require__(339);
#
# 	exports.Explanation = _explanation2.default;
# 	exports.Barchart = _bar_chart2.default;
# 	exports.PredictProba = _predict_proba2.default;
# 	exports.PredictedValue = _predicted_value2.default;
# 	//require('style-loader');
# 	/* WEBPACK VAR INJECTION */}.call(exports, (function() { return this; }())))
#
# /***/ }),
# /* 1 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
#
# 	var _slicedToArray = function () { function sliceIterator(arr, i) { var _arr = []; var _n = true; var _d = false; var _e = undefined; try { for (var _i = arr[Symbol.iterator](), _s; !(_n = (_s = _i.next()).done); _n = true) { _arr.push(_s.value); if (i && _arr.length === i) break; } } catch (err) { _d = true; _e = err; } finally { try { if (!_n && _i["return"]) _i["return"](); } finally { if (_d) throw _e; } } return _arr; } return function (arr, i) { if (Array.isArray(arr)) { return arr; } else if (Symbol.iterator in Object(arr)) { return sliceIterator(arr, i); } else { throw new TypeError("Invalid attempt to destructure non-iterable instance"); } }; }();
#
# 	var _d2 = __webpack_require__(2);
#
# 	var _d3 = _interopRequireDefault(_d2);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _lodash = __webpack_require__(4);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	function _classCallCheck(instance, Constructor) { if (!(instance instanceof Constructor)) { throw new TypeError("Cannot call a class as a function"); } }
#
# 	var Explanation = function () {
# 	  function Explanation(class_names) {
# 	    _classCallCheck(this, Explanation);
#
# 	    this.names = class_names;
# 	    if (class_names.length < 10) {
# 	      this.colors = _d3.default.scale.category10().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category10().domain((0, _lodash.range)(this.names.length));
# 	    } else {
# 	      this.colors = _d3.default.scale.category20().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category20().domain((0, _lodash.range)(this.names.length));
# 	    }
# 	  }
# 	  // exp: [(feature-name, weight), ...]
# 	  // label: int
# 	  // div: d3 selection
#
#
# 	  Explanation.prototype.show = function show(exp, label, div) {
# 	    var svg = div.append('svg').style('width', '100%');
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    var names = ['NOT ' + this.names[label], this.names[label]];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	      names = this.names;
# 	    }
# 	    var plot = new _bar_chart2.default(svg, exp, true, names, colors, true, 10);
# 	    svg.style('height', plot.svg_height + 'px');
# 	  };
# 	  // exp has all ocurrences of words, with start index and weight:
# 	  // exp = [('word', 132, -0.13), ('word3', 111, 1.3)
#
#
# 	  Explanation.prototype.show_raw_text = function show_raw_text(exp, label, raw, div) {
# 	    var opacity = arguments.length > 4 && arguments[4] !== undefined ? arguments[4] : true;
#
# 	    //let colors=['#5F9EA0', this.colors(this.exp['class'])];
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var word_lists = [[], []];
# 	    var max_weight = -1;
# 	    var _iteratorNormalCompletion = true;
# 	    var _didIteratorError = false;
# 	    var _iteratorError = undefined;
#
# 	    try {
# 	      for (var _iterator = exp[Symbol.iterator](), _step; !(_iteratorNormalCompletion = (_step = _iterator.next()).done); _iteratorNormalCompletion = true) {
# 	        var _step$value = _slicedToArray(_step.value, 3),
# 	            word = _step$value[0],
# 	            start = _step$value[1],
# 	            weight = _step$value[2];
#
# 	        if (weight > 0) {
# 	          word_lists[1].push([start, start + word.length, weight]);
# 	        } else {
# 	          word_lists[0].push([start, start + word.length, -weight]);
# 	        }
# 	        max_weight = Math.max(max_weight, Math.abs(weight));
# 	      }
# 	    } catch (err) {
# 	      _didIteratorError = true;
# 	      _iteratorError = err;
# 	    } finally {
# 	      try {
# 	        if (!_iteratorNormalCompletion && _iterator.return) {
# 	          _iterator.return();
# 	        }
# 	      } finally {
# 	        if (_didIteratorError) {
# 	          throw _iteratorError;
# 	        }
# 	      }
# 	    }
#
# 	    if (!opacity) {
# 	      max_weight = 0;
# 	    }
# 	    this.display_raw_text(div, raw, word_lists, colors, max_weight, true);
# 	  };
# 	  // exp is list of (feature_name, value, weight)
#
#
# 	  Explanation.prototype.show_raw_tabular = function show_raw_tabular(exp, label, div) {
# 	    div.classed('lime', true).classed('table_div', true);
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var table = div.append('table');
# 	    var thead = table.append('tr');
# 	    thead.append('td').text('Feature');
# 	    thead.append('td').text('Value');
# 	    thead.style('color', 'black').style('font-size', '20px');
# 	    var _iteratorNormalCompletion2 = true;
# 	    var _didIteratorError2 = false;
# 	    var _iteratorError2 = undefined;
#
# 	    try {
# 	      for (var _iterator2 = exp[Symbol.iterator](), _step2; !(_iteratorNormalCompletion2 = (_step2 = _iterator2.next()).done); _iteratorNormalCompletion2 = true) {
# 	        var _step2$value = _slicedToArray(_step2.value, 3),
# 	            fname = _step2$value[0],
# 	            value = _step2$value[1],
# 	            weight = _s

# %% [markdown]
# # Training a cat boost classifier

# %%
from catboost import CatBoostClassifier
classifier = CatBoostClassifier(
    iterations=1500, 
    learning_rate=1.5, 
    #loss_function='CrossEntropy'
)

# %%
## pipeline
model = pipeline.Pipeline([("vectorizer", vectorizer),  
                           ("classifier", classifier)])
## train classifier
model["classifier"].fit(X_train, y_train)
## test
X_test = test["text"].values
predicted = model.predict(X_test)
predicted_prob = model.predict_proba(X_test)
# Out:
# learning rate is greater than 1. You probably need to decrease learning rate.
# learning rate is greater than 1. You probably need to decrease learning rate.
# learning rate is greater than 1. You probably need to decrease learning rate.
# 0:	learn: 1.3978169	total: 59.7ms	remaining: 1m 29s
# 1:	learn: 1.3867790	total: 103ms	remaining: 1m 17s
# 2:	learn: 1.3264683	total: 146ms	remaining: 1m 12s
# 3:	learn: 1.3139599	total: 189ms	remaining: 1m 10s
# 4:	learn: 1.2925152	total: 231ms	remaining: 1m 9s
# 5:	learn: 1.3084846	total: 276ms	remaining: 1m 8s
# 6:	learn: 1.3490215	total: 318ms	remaining: 1m 7s
# 7:	learn: 1.9499848	total: 362ms	remaining: 1m 7s
# 8:	learn: 6.0066015	total: 405ms	remaining: 1m 7s
# 9:	learn: 4.1179646	total: 447ms	remaining: 1m 6s
# 10:	learn: 2.9060044	total: 490ms	remaining: 1m 6s
# 11:	learn: 3.6558488	total: 533ms	remaining: 1m 6s
# 12:	learn: 2.8840208	total: 576ms	remaining: 1m 5s
# 13:	learn: 2.5427942	total: 619ms	remaining: 1m 5s
# 14:	learn: 2.1043396	total: 662ms	remaining: 1m 5s
# 15:	learn: 2.0901403	total: 705ms	remaining: 1m 5s
# 16:	learn: 2.0304655	total: 748ms	remaining: 1m 5s
# 17:	learn: 1.9864251	total: 790ms	remaining: 1m 5s
# 18:	learn: 1.9408969	total: 833ms	remaining: 1m 4s
# 19:	learn: 1.9079108	total: 876ms	remaining: 1m 4s
# 20:	learn: 1.8985931	total: 919ms	remaining: 1m 4s
# 21:	learn: 2.1057787	total: 962ms	remaining: 1m 4s
# 22:	learn: 2.2834122	total: 1s	remaining: 1m 4s
# 23:	learn: 2.2667345	total: 1.05s	remaining: 1m 4s
# 24:	learn: 2.1738233	total: 1.09s	remaining: 1m 4s
# 25:	learn: 2.0581447	total: 1.14s	remaining: 1m 4s
# 26:	learn: 2.0040728	total: 1.18s	remaining: 1m 4s
# 27:	learn: 1.8885614	total: 1.22s	remaining: 1m 4s
# 28:	learn: 1.9715317	total: 1.26s	remaining: 1m 4s
# 29:	learn: 1.9715405	total: 1.31s	remaining: 1m 4s
# 30:	learn: 2.5675292	total: 1.35s	remaining: 1m 4s
# 31:	learn: 2.6728098	total: 1.4s	remaining: 1m 4s
# 32:	learn: 2.6713576	total: 1.44s	remaining: 1m 3s
# 33:	learn: 2.2723585	total: 1.48s	remaining: 1m 3s
# 34:	learn: 1.9819434	total: 1.52s	remaining: 1m 3s
# 35:	learn: 1.9997262	total: 1.57s	remaining: 1m 3s
# 36:	learn: 2.2413728	total: 1.61s	remaining: 1m 3s
# 37:	learn: 1.9058239	total: 1.65s	remaining: 1m 3s
# 38:	learn: 1.8469058	total: 1.7s	remaining: 1m 3s
# 39:	learn: 1.8963958	total: 1.74s	remaining: 1m 3s
# 40:	learn: 2.5071989	total: 1.78s	remaining: 1m 3s
# 41:	learn: 1.8554803	total: 1.82s	remaining: 1m 3s
# 42:	learn: 1.6959994	total: 1.87s	remaining: 1m 3s
# 43:	learn: 1.6975851	total: 1.91s	remaining: 1m 3s
# 44:	learn: 1.6836584	total: 1.95s	remaining: 1m 3s
# 45:	learn: 1.6886033	total: 2s	remaining: 1m 3s
# 46:	learn: 1.6495645	total: 2.04s	remaining: 1m 3s
# 47:	learn: 1.6151448	total: 2.08s	remaining: 1m 3s
# 48:	learn: 1.6080632	total: 2.13s	remaining: 1m 2s
# 49:	learn: 1.5998628	total: 2.17s	remaining: 1m 2s
# 50:	learn: 1.6001799	total: 2.21s	remaining: 1m 2s
# 51:	learn: 1.6077924	total: 2.25s	remaining: 1m 2s
# 52:	learn: 1.6011218	total: 2.3s	remaining: 1m 2s
# 53:	learn: 1.5964206	total: 2.34s	remaining: 1m 2s
# 54:	learn: 1.5802482	total: 2.38s	remaining: 1m 2s
# 55:	learn: 1.5745070	total: 2.43s	remaining: 1m 2s
# 56:	learn: 1.5695093	total: 2.47s	remaining: 1m 2s
# 57:	learn: 1.5650939	total: 2.51s	remaining: 1m 2s
# 58:	learn: 1.5611254	total: 2.55s	remaining: 1m 2s
# 59:	learn: 1.5144103	total: 2.6s	remaining: 1m 2s
# 60:	learn: 1.5055654	total: 2.64s	remaining: 1m 2s
# 61:	learn: 1.5000549	total: 2.68s	remaining: 1m 2s
# 62:	learn: 1.4931991	total: 2.72s	remaining: 1m 2s
# 63:	learn: 1.4855080	total: 2.77s	remaining: 1m 2s
# 64:	learn: 1.4833548	total: 2.81s	remaining: 1m 1s
# 65:	learn: 1.4786679	total: 2.85s	remaining: 1m 1s
# 66:	learn: 1.4739648	total: 2.89s	remaining: 1m 1s
# 67:	learn: 1.4678947	total: 2.94s	remaining: 1m 1s
# 68:	learn: 1.4642103	total: 2.98s	remaining: 1m 1s
# 69:	learn: 1.4620190	total: 3.02s	remaining: 1m 1s
# 70:	learn: 1.4566012	total: 3.06s	remaining: 1m 1s
# 71:	learn: 1.4526063	total: 3.1s	remaining: 1m 1s
# 72:	learn: 1.4496444	total: 3.15s	remaining: 1m 1s
# 73:	learn: 1.4471015	total: 3.19s	remaining: 1m 1s
# 169:	learn: 1.2442456	total: 7.28s	remaining: 57s
# 170:	learn: 1.2430318	total: 7.32s	remaining: 56.9s
# 171:	learn: 1.2416289	total: 7.37s	remaining: 56.9s
# 172:	learn: 1.2405509	total: 7.41s	remaining: 56.8s
# 173:	learn: 1.2396320	total: 7.45s	remaining: 56.8s
# 174:	learn: 1.2388408	total: 7.49s	remaining: 56.7s
# 175:	learn: 1.2377373	total: 7.54s	remaining: 56.7s
# 176:	learn: 1.2363788	total: 7.58s	remaining: 56.7s
# 177:	learn: 1.2354400	total: 7.62s	remaining: 56.6s
# 178:	learn: 1.2339295	total: 7.67s	remaining: 56.6s
# 179:	learn: 1.2326519	total: 7.71s	remaining: 56.5s
# 180:	learn: 1.2318049	total: 7.75s	remaining: 56.5s
# 181:	learn: 1.2311560	total: 7.79s	remaining: 56.4s
# 182:	learn: 1.2288081	total: 7.83s	remaining: 56.4s
# 183:	learn: 1.2279562	total: 7.88s	remaining: 56.3s
# 184:	learn: 1.2274684	total: 7.92s	remaining: 56.3s
# 185:	learn: 1.2269856	total: 7.96s	remaining: 56.3s
# 186:	learn: 1.2261802	total: 8.01s	remaining: 56.2s
# 187:	learn: 1.2251016	total: 8.05s	remaining: 56.2s
# 188:	learn: 1.2237425	total: 8.09s	remaining: 56.1s
# 189:	learn: 1.2229524	total: 8.13s	remaining: 56.1s
# 190:	learn: 1.2212468	total: 8.18s	remaining: 56.1s
# 191:	learn: 1.2204680	total: 8.22s	remaining: 56s
# 192:	learn: 1.2194893	total: 8.27s	remaining: 56s
# 193:	learn: 1.2185404	total: 8.31s	remaining: 55.9s
# 194:	learn: 1.2177573	total: 8.35s	remaining: 55.9s
# 195:	learn: 1.2168000	total: 8.39s	remaining: 55.8s
# 196:	learn: 1.2157410	total: 8.44s	remaining: 55.8s
# 197:	learn: 1.2150701	total: 8.48s	remaining: 55.8s
# 198:	learn: 1.2143845	total: 8.52s	remaining: 55.7s
# 199:	learn: 1.2137429	total: 8.56s	remaining: 55.7s
# 200:	learn: 1.2125706	total: 8.61s	remaining: 55.6s
# 201:	learn: 1.2118725	total: 8.65s	remaining: 55.6s
# 202:	learn: 1.2103360	total: 8.69s	remaining: 55.5s
# 203:	learn: 1.2098677	total: 8.73s	remaining: 55.5s
# 204:	learn: 1.2072430	total: 8.78s	remaining: 55.5s
# 205:	learn: 1.2056510	total: 8.82s	remaining: 55.4s
# 206:	learn: 1.2046363	total: 8.86s	remaining: 55.4s
# 207:	learn: 1.2033750	total: 8.91s	remaining: 55.3s
# 208:	learn: 1.2021483	total: 8.95s	remaining: 55.3s
# 209:	learn: 1.2009580	total: 8.99s	remaining: 55.2s
# 210:	learn: 1.2002014	total: 9.04s	remaining: 55.2s
# 211:	learn: 1.1991061	total: 9.08s	remaining: 55.2s
# 212:	learn: 1.1985736	total: 9.12s	remaining: 55.1s
# 213:	learn: 1.1981027	total: 9.16s	remaining: 55.1s
# 214:	learn: 1.1974461	total: 9.21s	remaining: 55s
# 215:	learn: 1.1967854	total: 9.25s	remaining: 55s
# 216:	learn: 1.1936381	total: 9.29s	remaining: 54.9s
# 217:	learn: 1.1928408	total: 9.33s	remaining: 54.9s
# 218:	learn: 1.1920425	total: 9.38s	remaining: 54.8s
# 219:	learn: 1.1910826	total: 9.42s	remaining: 54.8s
# 220:	learn: 1.1905349	total: 9.46s	remaining: 54.8s
# 221:	learn: 1.1891287	total: 9.5s	remaining: 54.7s
# 222:	learn: 1.1883435	total: 9.54s	remaining: 54.7s
# 223:	learn: 1.1877665	total: 9.59s	remaining: 54.6s
# 224:	learn: 1.1867800	total: 9.63s	remaining: 54.6s
# 225:	learn: 1.1859382	total: 9.67s	remaining: 54.5s
# 226:	learn: 1.1852005	total: 9.71s	remaining: 54.5s
# 227:	learn: 1.1846005	total: 9.76s	remaining: 54.4s
# 228:	learn: 1.1826513	total: 9.8s	remaining: 54.4s
# 229:	learn: 1.1813877	total: 9.84s	remaining: 54.4s
# 230:	learn: 1.1806036	total: 9.89s	remaining: 54.3s
# 231:	learn: 1.1797241	total: 9.93s	remaining: 54.3s
# 232:	learn: 1.1790195	total: 9.97s	remaining: 54.2s
# 233:	learn: 1.1784414	total: 10s	remaining: 54.2s
# 234:	learn: 1.1777828	total: 10.1s	remaining: 54.1s
# 235:	learn: 1.1764858	total: 10.1s	remaining: 54.1s
# 236:	learn: 1.1759284	total: 10.1s	remaining: 54s
# 237:	learn: 1.1754276	total: 10.2s	remaining: 54s
# 238:	learn: 1.1734347	total: 10.2s	remaining: 53.9s
# 239:	learn: 1.1729603	total: 10.3s	remaining: 53.9s
# 240:	learn: 1.1724990	total: 10.3s	remaining: 53.9s
# 241:	learn: 1.1703180	total: 10.4s	remaining: 53.8s
# 242:	learn: 1.1698470	total: 10.4s	remaining: 53.8s
# 243:	learn: 1.1692916	total: 10.4s	remaining: 53.7s
# 244:	learn: 1.1687665	total: 10.5s	remaining: 53.7s
# 245:	learn: 1.1673663	total: 10.5s	remaining: 53.7s
# 246:	learn: 1.1666540	total: 10.6s	remaining: 53.6s
# 247:	learn: 1.1662132	total: 10.6s	remaining: 53.6s
# 248:	learn: 1.1656188	total: 10.7s	remaining: 53.5s
# 249:	learn: 1.1644400	total: 10.7s	remaining: 53.5s
# 250:	learn: 1.1635859	total: 10.7s	remaining: 53.4s
# 251:	learn: 1.1605204	total: 10.8s	remaining: 53.4s
# 252:	learn: 1.1595899	total: 10.8s	remaining: 53.3s
# 253:	learn: 1.1588791	total: 10.9s	remaining: 53.3s
# 254:	learn: 1.1584244	total: 10.9s	remaining: 53.3s
# 255:	learn: 1.1567139	total: 11s	remaining: 53.2s
# 256:	learn: 1.1560252	total: 11s	remaining: 53.2s
# 257:	learn: 1.1550156	total: 11s	remaining: 53.1s
# 258:	learn: 1.1535682	total: 11.1s	remaining: 53.1s
# 259:	learn: 1.1531234	total: 11.1s	remaining: 53s
# 260:	learn: 1.1522643	total: 11.2s	remaining: 53s
# 261:	learn: 1.1513389	total: 11.2s	remaining: 53s
# 262:	learn: 1.1505799	total: 11.3s	remaining: 52.9s
# 263:	learn: 1.1499222	total: 11.3s	remaining: 52.9s
# 264:	learn: 1.1488853	total: 11.3s	remaining: 52.8s
# 265:	learn: 1.1477163	total: 11.4s	remaining: 52.8s
# 266:	learn: 1.1470909	total: 11.4s	remaining: 52.7s
# 267:	learn: 1.1462857	total: 11.5s	remaining: 52.7s
# 268:	learn: 1.1441252	total: 11.5s	remaining: 52.7s
# 269:	learn: 1.1429478	total: 11.5s	remaining: 52.6s
# 270:	learn: 1.1425642	total: 11.6s	remaining: 52.6s
# 271:	learn: 1.1417676	total: 11.6s	remaining: 52.5s
# 272:	learn: 1.1409706	total: 11.7s	remaining: 52.5s
# 273:	learn: 1.1399192	total: 11.7s	remaining: 52.4s
# 274:	learn: 1.1369845	total: 11.8s	remaining: 52.4s
# 275:	learn: 1.1362664	total: 11.8s	remaining: 52.4s
# 276:	learn: 1.1356469	total: 11.8s	remaining: 52.3s
# 277:	learn: 1.1348492	total: 11.9s	remaining: 52.3s
# 278:	learn: 1.1320736	total: 11.9s	remaining: 52.2s
# 279:	learn: 1.1310085	total: 12s	remaining: 52.2s
# 280:	learn: 1.1301604	total: 12s	remaining: 52.1s
# 281:	learn: 1.1296025	total: 12.1s	remaining: 52.1s
# 282:	learn: 1.1272175	total: 12.1s	remaining: 52.1s
# 283:	learn: 1.1262967	total: 12.1s	remaining: 52s
# 284:	learn: 1.1256783	total: 12.2s	remaining: 52s
# 285:	learn: 1.1249499	total: 12.2s	remaining: 51.9s
# 286:	learn: 1.1240721	total: 12.3s	remaining: 51.9s
# 287:	learn: 1.1235262	total: 12.3s	remaining: 51.8s
# 288:	learn: 1.1232124	total: 12.4s	remaining: 51.8s
# 289:	learn: 1.1227854	total: 12.4s	remaining: 51.8s
# 290:	learn: 1.1222226	total: 12.4s	remaining: 51.7s
# 291:	learn: 1.1213678	total: 12.5s	remaining: 51.7s
# 292:	learn: 1.1207618	total: 12.5s	remaining: 51.6s
# 293:	learn: 1.1199647	total: 12.6s	remaining: 51.6s
# 294:	learn: 1.1184148	total: 12.6s	remaining: 51.5s
# 295:	learn: 1.1175978	total: 12.7s	remaining: 51.5s
# 296:	learn: 1.1170971	total: 12.7s	remaining: 51.5s
# 297:	learn: 1.1162896	total: 12.7s	remaining: 51.4s
# 298:	learn: 1.1147497	total: 12.8s	remaining: 51.4s
# 299:	learn: 1.1140465	total: 12.8s	remaining: 51.3s
# 300:	learn: 1.1132098	total: 12.9s	remaining: 51.3s
# 301:	learn: 1.1024753	total: 12.9s	remaining: 51.2s
# 302:	learn: 1.0997688	total: 13s	remaining: 51.2s
# 303:	learn: 1.0992312	total: 13s	remaining: 51.2s
# 304:	learn: 1.0967938	total: 13s	remaining: 51.1s
# 305:	learn: 1.0962358	total: 13.1s	remaining: 51.1s
# 306:	learn: 1.0957472	total: 13.1s	remaining: 51s
# 307:	learn: 1.0953232	total: 13.2s	remaining: 51s
# 308:	learn: 1.0944804	total: 13.2s	remaining: 50.9s
# 309:	learn: 1.0935819	total: 13.3s	remaining: 50.9s
# 310:	learn: 1.0928223	total: 13.3s	remaining: 50.9s
# 311:	learn: 1.0921431	total: 13.3s	remaining: 50.8s
# 312:	learn: 1.0917807	total: 13.4s	remaining: 50.8s
# 313:	learn: 1.0912372	total: 13.4s	remaining: 50.7s
# 314:	learn: 1.0908092	total: 13.5s	remaining: 50.7s
# 315:	learn: 1.0903831	total: 13.5s	remaining: 50.6s
# 316:	learn: 1.0898971	total: 13.6s	remaining: 50.6s
# 317:	learn: 1.0894366	total: 13.6s	remaining: 50.6s
# 318:	learn: 1.0890066	total: 13.6s	remaining: 50.5s
# 319:	learn: 1.0883590	total: 13.7s	remaining: 50.5s
# 320:	learn: 1.0879465	total: 13.7s	remaining: 50.4s
# 321:	learn: 1.0868447	total: 13.8s	remaining: 50.4s
# 322:	learn: 1.0861694	total: 13.8s	remaining: 50.3s
# 323:	learn: 1.0856261	total: 13.9s	remaining: 50.3s
# 324:	learn: 1.0852913	total: 13.9s	remaining: 50.3s
# 325:	learn: 1.0839925	total: 13.9s	remaining: 50.2s
# 326:	learn: 1.0834220	total: 14s	remaining: 50.2s
# 327:	learn: 1.0827696	total: 14s	remaining: 50.1s
# 328:	learn: 1.0823603	total: 14.1s	remaining: 50.1s
# 329:	learn: 1.0815584	total: 14.1s	remaining: 50s
# 330:	learn: 1.0810488	total: 14.2s	remaining: 50s
# 331:	learn: 1.0806649	total: 14.2s	remaining: 50s
# 332:	learn: 1.0797809	total: 14.2s	remaining: 49.9s
# 333:	learn: 1.0790932	total: 14.3s	remaining: 49.9s
# 334:	learn: 1.0784849	total: 14.3s	remaining: 49.8s
# 335:	learn: 1.0777787	total: 14.4s	remaining: 49.8s
# 336:	learn: 1.0773427	total: 14.4s	remaining: 49.7s
# 337:	learn: 1.0765005	total: 14.5s	remaining: 49.7s
# 338:	learn: 1.0744202	total: 14.5s	remaining: 49.6s
# 339:	learn: 1.0700715	total: 14.5s	remaining: 49.6s
# 340:	learn: 1.0691658	total: 14.6s	remaining: 49.6s
# 341:	learn: 1.0688085	total: 14.6s	remaining: 49.5s
# 342:	learn: 1.0680845	total: 14.7s	remaining: 49.5s
# 343:	learn: 1.0676879	total: 14.7s	remaining: 49.4s
# 344:	learn: 1.0669181	total: 14.8s	remaining: 49.4s
# 345:	learn: 1.0664427	total: 14.8s	remaining: 49.4s
# 346:	learn: 1.0649364	total: 14.8s	remaining: 49.3s
# 347:	learn: 1.0640526	total: 14.9s	remaining: 49.3s
# 348:	learn: 1.0635977	total: 14.9s	remaining: 49.2s
# 349:	learn: 1.0631777	total: 15s	remaining: 49.2s
# 350:	learn: 1.0613725	total: 15s	remaining: 49.1s
# 351:	learn: 1.0607878	total: 15.1s	remaining: 49.1s
# 352:	learn: 1.0599702	total: 15.1s	remaining: 49.1s
# 353:	learn: 1.0590532	total: 15.1s	remaining: 49s
# 354:	learn: 1.0565464	total: 15.2s	remaining: 49s
# 355:	learn: 1.0560794	total: 15.2s	remaining: 48.9s
# 356:	learn: 1.0504211	total: 15.3s	remaining: 48.9s
# 357:	learn: 1.0499268	total: 15.3s	remaining: 48.8s
# 358:	learn: 1.0495000	total: 15.4s	remaining: 48.8s
# 359:	learn: 1.0491114	total: 15.4s	remaining: 48.8s
# 360:	learn: 1.0485294	total: 15.4s	remaining: 48.7s
# 361:	learn: 1.0452117	total: 15.5s	remaining: 48.7s
# 362:	learn: 1.0448357	total: 15.5s	remaining: 48.6s
# 363:	learn: 1.0438276	total: 15.6s	remaining: 48.6s
# 364:	learn: 1.0430724	total: 15.6s	remaining: 48.5s
# 365:	learn: 1.0426722	total: 15.7s	remaining: 48.5s
# 366:	learn: 1.0420204	total: 15.7s	remaining: 48.5s
# 367:	learn: 1.0412270	total: 15.7s	remaining: 48.4s
# 368:	learn: 1.0405416	total: 15.8s	remaining: 48.4s
# 369:	learn: 1.0400593	total: 15.8s	remaining: 48.3s
# 370:	learn: 1.0393702	total: 15.9s	remaining: 48.3s
# 371:	learn: 1.0386345	total: 15.9s	remaining: 48.2s
# 372:	learn: 1.0381407	total: 15.9s	remaining: 48.2s
# 373:	learn: 1.0377156	total: 16s	remaining: 48.1s
# 374:	learn: 1.0359358	total: 16s	remaining: 48.1s
# 375:	learn: 1.0353785	total: 16.1s	remaining: 48.1s
# 376:	learn: 1.0349301	total: 16.1s	remaining: 48s
# 377:	learn: 1.0339592	total: 16.2s	remaining: 48s
# 378:	learn: 1.0333541	total: 16.2s	remaining: 47.9s
# 379:	learn: 1.0323326	total: 16.2s	remaining: 47.9s
# 380:	learn: 1.0318198	total: 16.3s	remaining: 47.9s
# 381:	learn: 1.0314919	total: 16.3s	remaining: 47.8s
# 382:	learn: 1.0310817	total: 16.4s	remaining: 47.8s
# 383:	learn: 1.0304234	total: 16.4s	remaining: 47.7s
# 384:	learn: 1.0301045	total: 16.5s	remaining: 47.7s
# 385:	learn: 1.0293122	total: 16.5s	remaining: 47.6s
# 386:	learn: 1.0288153	total: 16.5s	remaining: 47.6s
# 387:	learn: 1.0270754	total: 16.6s	remaining: 47.6s
# 388:	learn: 1.0266951	total: 16.6s	remaining: 47.5s
# 389:	learn: 1.0261408	total: 16.7s	remaining: 47.5s
# 390:	learn: 1.0233145	total: 16.7s	remaining: 47.4s
# 391:	learn: 1.0228191	total: 16.8s	remaining: 47.4s
# 392:	learn: 1.0222592	total: 16.8s	remaining: 47.3s
# 393:	learn: 1.0217972	total: 16.8s	remaining: 47.3s
# 394:	learn: 1.0204485	total: 16.9s	remaining: 47.3s
# 395:	learn: 1.0190512	total: 16.9s	remaining: 47.2s
# 396:	learn: 1.0184714	total: 17s	remaining: 47.2s
# 397:	learn: 1.0173995	total: 17s	remaining: 47.1s
# 398:	learn: 1.0169295	total: 17.1s	remaining: 47.1s
# 399:	learn: 1.0160776	total: 17.1s	remaining: 47s
# 400:	learn: 1.0155568	total: 17.1s	remaining: 47s
# 401:	learn: 1.0151778	total: 17.2s	remaining: 46.9s
# 402:	learn: 1.0146745	total: 17.2s	remaining: 46.9s
# 403:	learn: 1.0143306	total: 17.3s	remaining: 46.9s
# 404:	learn: 1.0131925	total: 17.3s	remaining: 46.8s
# 452:	learn: 0.9762761	total: 19.4s	remaining: 44.8s
# 453:	learn: 0.9759332	total: 19.4s	remaining: 44.7s
# 454:	learn: 0.9753134	total: 19.4s	remaining: 44.7s
# 455:	learn: 0.9738448	total: 19.5s	remaining: 44.6s
# 456:	learn: 0.9735187	total: 19.5s	remaining: 44.6s
# 457:	learn: 0.9726429	total: 19.6s	remaining: 44.5s
# 458:	learn: 0.9721369	total: 19.6s	remaining: 44.5s
# 459:	learn: 0.9702868	total: 19.7s	remaining: 44.5s
# 460:	learn: 0.9699018	total: 19.7s	remaining: 44.4s
# 461:	learn: 0.9692299	total: 19.8s	remaining: 44.4s
# 462:	learn: 0.9686288	total: 19.8s	remaining: 44.3s
# 463:	learn: 0.9679314	total: 19.8s	remaining: 44.3s
# 464:	learn: 0.9673489	total: 19.9s	remaining: 44.2s
# 465:	learn: 0.9669680	total: 19.9s	remaining: 44.2s
# 466:	learn: 0.9665790	total: 20s	remaining: 44.2s
# 467:	learn: 0.9661950	total: 20s	remaining: 44.1s
# 468:	learn: 0.9658182	total: 20s	remaining: 44.1s
# 469:	learn: 0.9652548	total: 20.1s	remaining: 44s
# 470:	learn: 0.9647758	total: 20.1s	remaining: 44s
# 471:	learn: 0.9628613	total: 20.2s	remaining: 43.9s
# 472:	learn: 0.9623194	total: 20.2s	remaining: 43.9s
# 473:	learn: 0.9618236	total: 20.3s	remaining: 43.9s
# 474:	learn: 0.9613912	total: 20.3s	remaining: 43.8s
# 475:	learn: 0.9612299	total: 20.3s	remaining: 43.8s
# 476:	learn: 0.9604162	total: 20.4s	remaining: 43.7s
# 477:	learn: 0.9594898	total: 20.4s	remaining: 43.7s
# 478:	learn: 0.9591721	total: 20.5s	remaining: 43.6s
# 479:	learn: 0.9586087	total: 20.5s	remaining: 43.6s
# 480:	learn: 0.9582160	total: 20.6s	remaining: 43.6s
# 481:	learn: 0.9576054	total: 20.6s	remaining: 43.5s
# 482:	learn: 0.9571780	total: 20.7s	remaining: 43.5s
# 483:	learn: 0.9567227	total: 20.7s	remaining: 43.5s
# 484:	learn: 0.9562721	total: 20.7s	remaining: 43.4s
# 485:	learn: 0.9552790	total: 20.8s	remaining: 43.4s
# 486:	learn: 0.9542198	total: 20.8s	remaining: 43.3s
# 487:	learn: 0.9539425	total: 20.9s	remaining: 43.3s
# 488:	learn: 0.9534789	total: 20.9s	remaining: 43.3s
# 489:	learn: 0.9531507	total: 21s	remaining: 43.2s
# 490:	learn: 0.9527666	total: 21s	remaining: 43.2s
# 491:	learn: 0.9512134	total: 21.1s	remaining: 43.1s
# 492:	learn: 0.9508473	total: 21.1s	remaining: 43.1s
# 493:	learn: 0.9501507	total: 21.1s	remaining: 43.1s
# 494:	learn: 0.9491868	total: 21.2s	remaining: 43s
# 495:	learn: 0.9489722	total: 21.2s	remaining: 43s
# 496:	learn: 0.9485827	total: 21.3s	remaining: 42.9s
# 497:	learn: 0.9476564	total: 21.3s	remaining: 42.9s
# 498:	learn: 0.9473153	total: 21.4s	remaining: 42.9s
# 1468:	learn: 0.5868059	total: 1m 2s	remaining: 1.32s
# 1469:	learn: 0.5867517	total: 1m 2s	remaining: 1.28s
# 1470:	learn: 0.5865589	total: 1m 2s	remaining: 1.24s
# 1471:	learn: 0.5864769	total: 1m 2s	remaining: 1.2s
# 1472:	learn: 0.5864456	total: 1m 2s	remaining: 1.15s
# 1473:	learn: 0.5863392	total: 1m 2s	remaining: 1.11s
# 1474:	learn: 0.5862333	total: 1m 3s	remaining: 1.07s
# 1475:	learn: 0.5861865	total: 1m 3s	remaining: 1.02s
# 1476:	learn: 0.5861156	total: 1m 3s	remaining: 983ms
# 1477:	learn: 0.5859095	total: 1m 3s	remaining: 940ms
# 1478:	learn: 0.5856307	total: 1m 3s	remaining: 897ms
# 1479:	learn: 0.5855732	total: 1m 3s	remaining: 855ms
# 1480:	learn: 0.5853597	total: 1m 3s	remaining: 812ms
# 1481:	learn: 0.5851890	total: 1m 3s	remaining: 769ms
# 1482:	learn: 0.5850842	total: 1m 3s	remaining: 726ms
# 1483:	learn: 0.5849768	total: 1m 3s	remaining: 684ms
# 1484:	learn: 0.5849372	total: 1m 3s	remaining: 641ms
# 1485:	learn: 0.5845591	total: 1m 3s	remaining: 598ms
# 1486:	learn: 0.5845124	total: 1m 3s	remaining: 555ms
# 1487:	learn: 0.5844396	total: 1m 3s	remaining: 513ms
# 1488:	learn: 0.5838058	total: 1m 3s	remaining: 470ms
# 1489:	learn: 0.5837145	total: 1m 3s	remaining: 427ms
# 1490:	learn: 0.5836165	total: 1m 3s	remaining: 385ms
# 1491:	learn: 0.5835980	total: 1m 3s	remaining: 342ms
# 1492:	learn: 0.5835375	total: 1m 3s	remaining: 299ms
# 1493:	learn: 0.5834049	total: 1m 3s	remaining: 256ms
# 1494:	learn: 0.5832380	total: 1m 3s	remaining: 214ms
# 1495:	learn: 0.5831653	total: 1m 3s	remaining: 171ms
# 1496:	learn: 0.5830537	total: 1m 3s	remaining: 128ms
# 1497:	learn: 0.5830121	total: 1m 4s	remaining: 85.5ms
# 1498:	learn: 0.5826949	total: 1m 4s	remaining: 42.7ms
# 1499:	learn: 0.5826584	total: 1m 4s	remaining: 0us

# %%
# lets see our model performance
classes = np.unique(y_test)
y_test_array = pd.get_dummies(y_test, drop_first=False).values
    
## Accuracy, Precision, Recall
accuracy = metrics.accuracy_score(y_test, predicted)
auc = metrics.roc_auc_score(y_test, predicted_prob, 
                            multi_class="ovr")
print("Accuracy:",  round(accuracy,2))
print("Auc:", round(auc,2))
print("Detail:")
print(metrics.classification_report(y_test, predicted))
    
## Plot confusion matrix
cm = metrics.confusion_matrix(y_test, predicted)
fig, ax = plt.subplots()
sns.heatmap(cm, annot=True, fmt='d', ax=ax, cmap=plt.cm.Blues, 
            cbar=False)
ax.set(xlabel="Pred", ylabel="True", xticklabels=classes, 
       yticklabels=classes, title="Confusion matrix")
plt.yticks(rotation=0)

fig, ax = plt.subplots(nrows=1, ncols=2)
## Plot roc
for i in range(len(classes)):
    fpr, tpr, thresholds = metrics.roc_curve(y_test_array[:,i],  
                           predicted_prob[:,i])
    ax[0].plot(fpr, tpr, lw=3, 
              label='{0} (area={1:0.2f})'.format(classes[i], 
                              metrics.auc(fpr, tpr))
               )
ax[0].plot([0,1], [0,1], color='navy', lw=3, linestyle='--')
ax[0].set(xlim=[-0.05,1.0], ylim=[0.0,1.05], 
          xlabel='False Positive Rate', 
          ylabel="True Positive Rate (Recall)", 
          title="Receiver operating characteristic")
ax[0].legend(loc="lower right")
ax[0].grid(True)
    
## Plot precision-recall curve
for i in range(len(classes)):
    precision, recall, thresholds = metrics.precision_recall_curve(
                 y_test_array[:,i], predicted_prob[:,i])
    ax[1].plot(recall, precision, lw=3, 
               label='{0} (area={1:0.2f})'.format(classes[i], 
                                  metrics.auc(recall, precision))
              )
ax[1].set(xlim=[0.0,1.05], ylim=[0.0,1.05], xlabel='Recall', 
          ylabel="Precision", title="Precision-Recall curve")
ax[1].legend(loc="best")
ax[1].grid(True)
plt.show()
# Out:
# Accuracy: 0.52
# Auc: 0.76
# Detail:
#                 precision    recall  f1-score   support
#
# Mixed feelings       0.31      0.15      0.21        52
#       Negative       0.36      0.57      0.44       139
#       Positive       0.66      0.62      0.64       321
#    not-Kannada       0.61      0.56      0.58       110
#  unknown state       0.28      0.17      0.21        69
#
#       accuracy                           0.52       691
#      macro avg       0.44      0.42      0.42       691
#   weighted avg       0.53      0.52      0.52       691

# %% [markdown]
# # Training a Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(max_depth=200, n_estimators=15, max_features=1700)

# %%
## pipeline
model = pipeline.Pipeline([("vectorizer", vectorizer),  
                           ("classifier", classifier)])
## train classifier
model["classifier"].fit(X_train, y_train)
## test
X_test = test["text"].values
predicted = model.predict(X_test)
predicted_prob = model.predict_proba(X_test)

# %%
# lets see our model performance
classes = np.unique(y_test)
y_test_array = pd.get_dummies(y_test, drop_first=False).values
    
## Accuracy, Precision, Recall
accuracy = metrics.accuracy_score(y_test, predicted)
auc = metrics.roc_auc_score(y_test, predicted_prob, 
                            multi_class="ovr")
print("Accuracy:",  round(accuracy,2))
print("Auc:", round(auc,2))
print("Detail:")
print(metrics.classification_report(y_test, predicted))
    
## Plot confusion matrix
cm = metrics.confusion_matrix(y_test, predicted)
fig, ax = plt.subplots()
sns.heatmap(cm, annot=True, fmt='d', ax=ax, cmap=plt.cm.Blues, 
            cbar=False)
ax.set(xlabel="Pred", ylabel="True", xticklabels=classes, 
       yticklabels=classes, title="Confusion matrix")
plt.yticks(rotation=0)

fig, ax = plt.subplots(nrows=1, ncols=2)
## Plot roc
for i in range(len(classes)):
    fpr, tpr, thresholds = metrics.roc_curve(y_test_array[:,i],  
                           predicted_prob[:,i])
    ax[0].plot(fpr, tpr, lw=3, 
              label='{0} (area={1:0.2f})'.format(classes[i], 
                              metrics.auc(fpr, tpr))
               )
ax[0].plot([0,1], [0,1], color='navy', lw=3, linestyle='--')
ax[0].set(xlim=[-0.05,1.0], ylim=[0.0,1.05], 
          xlabel='False Positive Rate', 
          ylabel="True Positive Rate (Recall)", 
          title="Receiver operating characteristic")
ax[0].legend(loc="lower right")
ax[0].grid(True)
    
## Plot precision-recall curve
for i in range(len(classes)):
    precision, recall, thresholds = metrics.precision_recall_curve(
                 y_test_array[:,i], predicted_prob[:,i])
    ax[1].plot(recall, precision, lw=3, 
               label='{0} (area={1:0.2f})'.format(classes[i], 
                                  metrics.auc(recall, precision))
              )
ax[1].set(xlim=[0.0,1.05], ylim=[0.0,1.05], xlabel='Recall', 
          ylabel="Precision", title="Precision-Recall curve")
ax[1].legend(loc="best")
ax[1].grid(True)
plt.show()
# Out:
# Accuracy: 0.51
# Auc: 0.75
# Detail:
#                 precision    recall  f1-score   support
#
# Mixed feelings       0.24      0.08      0.12        52
#       Negative       0.35      0.62      0.44       139
#       Positive       0.67      0.63      0.65       321
#    not-Kannada       0.56      0.45      0.49       110
#  unknown state       0.24      0.13      0.17        69
#
#       accuracy                           0.51       691
#      macro avg       0.41      0.38      0.37       691
#   weighted avg       0.51      0.51      0.49       691

# %% [markdown]
# # fitting a logistic regression classifier

# %%
from sklearn.linear_model import LogisticRegression
classifier =LogisticRegression(random_state=0, max_iter= 100)

# %%
## pipeline
model = pipeline.Pipeline([("vectorizer", vectorizer),  
                           ("classifier", classifier)])
## train classifier
model["classifier"].fit(X_train, y_train)
## test
X_test = test["text"].values
predicted = model.predict(X_test)
predicted_prob = model.predict_proba(X_test)
# Out:
# /home/ubuntu/pyenv/lib/python3.6/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
# lets see our model performance
classes = np.unique(y_test)
y_test_array = pd.get_dummies(y_test, drop_first=False).values
    
## Accuracy, Precision, Recall
accuracy = metrics.accuracy_score(y_test, predicted)
auc = metrics.roc_auc_score(y_test, predicted_prob, 
                            multi_class="ovr")
print("Accuracy:",  round(accuracy,2))
print("Auc:", round(auc,2))
print("Detail:")
print(metrics.classification_report(y_test, predicted))
    
## Plot confusion matrix
cm = metrics.confusion_matrix(y_test, predicted)
fig, ax = plt.subplots()
sns.heatmap(cm, annot=True, fmt='d', ax=ax, cmap=plt.cm.Blues, 
            cbar=False)
ax.set(xlabel="Pred", ylabel="True", xticklabels=classes, 
       yticklabels=classes, title="Confusion matrix")
plt.yticks(rotation=0)

fig, ax = plt.subplots(nrows=1, ncols=2)
## Plot roc
for i in range(len(classes)):
    fpr, tpr, thresholds = metrics.roc_curve(y_test_array[:,i],  
                           predicted_prob[:,i])
    ax[0].plot(fpr, tpr, lw=3, 
              label='{0} (area={1:0.2f})'.format(classes[i], 
                              metrics.auc(fpr, tpr))
               )
ax[0].plot([0,1], [0,1], color='navy', lw=3, linestyle='--')
ax[0].set(xlim=[-0.05,1.0], ylim=[0.0,1.05], 
          xlabel='False Positive Rate', 
          ylabel="True Positive Rate (Recall)", 
          title="Receiver operating characteristic")
ax[0].legend(loc="lower right")
ax[0].grid(True)
    
## Plot precision-recall curve
for i in range(len(classes)):
    precision, recall, thresholds = metrics.precision_recall_curve(
                 y_test_array[:,i], predicted_prob[:,i])
    ax[1].plot(recall, precision, lw=3, 
               label='{0} (area={1:0.2f})'.format(classes[i], 
                                  metrics.auc(recall, precision))
              )
ax[1].set(xlim=[0.0,1.05], ylim=[0.0,1.05], xlabel='Recall', 
          ylabel="Precision", title="Precision-Recall curve")
ax[1].legend(loc="best")
ax[1].grid(True)
plt.show()
# Out:
# Accuracy: 0.54
# Auc: 0.78
# Detail:
#                 precision    recall  f1-score   support
#
# Mixed feelings       0.40      0.04      0.07        52
#       Negative       0.39      0.65      0.49       139
#       Positive       0.65      0.67      0.66       321
#    not-Kannada       0.53      0.42      0.47       110
#  unknown state       0.43      0.23      0.30        69
#
#       accuracy                           0.54       691
#      macro avg       0.48      0.40      0.40       691
#   weighted avg       0.54      0.54      0.51       691

# %% [markdown]
# # training a k-neighboot classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=5, weights='distance')

# %%
## pipeline
model = pipeline.Pipeline([("vectorizer", vectorizer),  
                           ("classifier", classifier)])
## train classifier
model["classifier"].fit(X_train, y_train)
## test
X_test = test["text"].values
predicted = model.predict(X_test)
predicted_prob = model.predict_proba(X_test)

# %%
# lets see our model performance
classes = np.unique(y_test)
y_test_array = pd.get_dummies(y_test, drop_first=False).values
    
## Accuracy, Precision, Recall
accuracy = metrics.accuracy_score(y_test, predicted)
auc = metrics.roc_auc_score(y_test, predicted_prob, 
                            multi_class="ovr")
print("Accuracy:",  round(accuracy,2))
print("Auc:", round(auc,2))
print("Detail:")
print(metrics.classification_report(y_test, predicted))
    
## Plot confusion matrix
cm = metrics.confusion_matrix(y_test, predicted)
fig, ax = plt.subplots()
sns.heatmap(cm, annot=True, fmt='d', ax=ax, cmap=plt.cm.Blues, 
            cbar=False)
ax.set(xlabel="Pred", ylabel="True", xticklabels=classes, 
       yticklabels=classes, title="Confusion matrix")
plt.yticks(rotation=0)

fig, ax = plt.subplots(nrows=1, ncols=2)
## Plot roc
for i in range(len(classes)):
    fpr, tpr, thresholds = metrics.roc_curve(y_test_array[:,i],  
                           predicted_prob[:,i])
    ax[0].plot(fpr, tpr, lw=3, 
              label='{0} (area={1:0.2f})'.format(classes[i], 
                              metrics.auc(fpr, tpr))
               )
ax[0].plot([0,1], [0,1], color='navy', lw=3, linestyle='--')
ax[0].set(xlim=[-0.05,1.0], ylim=[0.0,1.05], 
          xlabel='False Positive Rate', 
          ylabel="True Positive Rate (Recall)", 
          title="Receiver operating characteristic")
ax[0].legend(loc="lower right")
ax[0].grid(True)
    
## Plot precision-recall curve
for i in range(len(classes)):
    precision, recall, thresholds = metrics.precision_recall_curve(
                 y_test_array[:,i], predicted_prob[:,i])
    ax[1].plot(recall, precision, lw=3, 
               label='{0} (area={1:0.2f})'.format(classes[i], 
                                  metrics.auc(recall, precision))
              )
ax[1].set(xlim=[0.0,1.05], ylim=[0.0,1.05], xlabel='Recall', 
          ylabel="Precision", title="Precision-Recall curve")
ax[1].legend(loc="best")
ax[1].grid(True)
plt.show()
# Out:
# Accuracy: 0.49
# Auc: 0.69
# Detail:
#                 precision    recall  f1-score   support
#
# Mixed feelings       0.22      0.15      0.18        52
#       Negative       0.35      0.55      0.43       139
#       Positive       0.64      0.56      0.60       321
#    not-Kannada       0.52      0.55      0.54       110
#  unknown state       0.28      0.16      0.20        69
#
#       accuracy                           0.49       691
#      macro avg       0.40      0.40      0.39       691
#   weighted avg       0.50      0.49      0.48       691
