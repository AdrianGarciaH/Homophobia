# %%
## for data
import json
import pandas as pd
import numpy as np
## for plotting
import matplotlib.pyplot as plt
import seaborn as sns
## for processing
import re
import nltk
## for bag-of-words
from sklearn import metrics, feature_extraction, feature_selection, model_selection, naive_bayes, pipeline, manifold, preprocessing
## for explainer
from lime import lime_text

## for deep learning
from tensorflow.keras import models, layers, preprocessing as kprocessing
from tensorflow.keras import backend as K
import torch

## for bert language model
import transformers
from transformers import AutoTokenizer, AutoModel

# %%
''' The following shows the result of training various non-neural network models on an augmented version of the 
Kannada set so that the negative label equals the positive label. models are trained on an bert vectorizer'''
# Out:
# ' The following shows the result of training various non-neural network models on an augmented version of the \nKannada set so that the negative label equals the positive label. models are trained on an bert vectorizer'

# %%
# import data
kan_train = pd.read_table("../../datasets/task_a/kan_train_negative_augmented.tsv")
kan_dev = pd.read_table("../../datasets/task_a/kan_sentiment_dev.tsv")

# %%
kan_train = kan_train.rename(columns={'category': 'y'})
kan_dev = kan_dev.rename(columns={'category': 'y'})

# %%
kan_dev
# Out:
#                                                   text               y
# 0    Binduge saryagi ugithidira good go ahead  we a...  Mixed feelings
# 1                               yen song guru ...super        Positive
# 2                                     my fevorat story     not-Kannada
# 3                                    Super ತೋಗರಿ ತೀಪ್ಪ        Positive
# 4    ನಿಮ್ಮ ಮಾತುಗಳು ಅಕ್ಷರಶಃ ಸತ್ಯ... ನಿಮ್ಮ ಈ ಸಾಮಾನ್ಯ ...        Positive
# ..                                                 ...             ...
# 686  @Nandi Parthasarathi ನಿಮ್ಮ ಅಪ್ಪ ದೊಡ್ ಗಾಂಡು ಸೂಳೆಮಗ        Negative
# 687                               Hugi guru badethawke        Negative
# 688                                  Trending no.1 wow        Positive
# 689  @Troll Stupid Fans naanu adikke kano helthirod...        Positive
# 690  @JustAn Opinion ninu Tika mucchu...Evattu Kann...        Positive
#
# [691 rows x 2 columns]

# %%
kan_train
# Out:
#                                                    text            y
# 0     ಒಂದು ದೇಶದ ಮುಂದುವರಿಯುವುದು ಅದರ ಆರ್ಥಿಕ ಸ್ಥಿತಿಯನ್ನ...     Negative
# 1     ಕನ್ನಡದಲ್ಲಿ ಡೈಲಿ ಟೆಕ್ ಅಪ್ಡೇಟ್ಸ್ ಪಡೆಯಲು ಸಬ್ಸ್ಕ್ರ...     Positive
# 2                                        Super sar song  not-Kannada
# 3     Tiktokers present situation... nನೋಡುವವರು ಯಾರು ...     Negative
# 4                             Super ಸಾಂಗ್ ವೆರಿ ನೈಸ್....     Positive
# ...                                                 ...          ...
# 7842      ಇಡೈಲಾ ಕೆಜಿಎಫ್ ಬಿಜಿಎಂ ಕೆಡತು ಎನಕು ಮಧುಮಥಾನ 🤔🤔🤔🤔🤯     Negative
# 7843                 ಜಯಲಲಿತಾ ಮೇಡಂ ಅವರಿಗೆ ಅಮೋಘ ನಿಗ್ರಹ...     Negative
# 7844                ದಯವಿಟ್ಟು ಎಲ್ಲದರ ಚಿತ್ರ ತೆಗೆಯಿರಿ ಸರ್.     Negative
# 7845  ಭಾರತದ ಅತಿ ದೊಡ್ಡ ಹೆದ್ದಾರಿ! ಭಾರತದ ದೊಡ್ಡ ತಾರೆಗಳು!...     Negative
# 7846        ವಾವ್ ರಜಿನಿ ಕರು ರಾಜಿಜಿ ಪಾಲ್ಸ್ ಲೈಕ್ ಹಿಟ್ ಮಾಡಿ     Negative
#
# [7847 rows x 2 columns]

# %%
fig, ax = plt.subplots()
fig.suptitle("y", fontsize=12)
kan_train.groupby("y").count().plot(kind="barh", legend=False, 
        ax=ax).grid(axis='x')
plt.show()

# %%
# Now we can define our training data and our dev data as well as targets
train = kan_train
test = kan_dev

y_train = kan_train['y'].values
y_test = kan_dev['y'].values

# %%
# for ensemble: 
results = pd.DataFrame(kan_dev['y'])

# %% [markdown]
# # Gettint text embeddings from the bert model

# %%
# I'll be using the embeddings from the multilinngual bert model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

tokenizer = AutoTokenizer.from_pretrained('bert-base-multilingual-uncased')
model = AutoModel.from_pretrained('bert-base-multilingual-uncased').to(device)
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-uncased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# We will start by gathering the embeddings for the validation set
cls_val_list = []
batch_size = 1000

for batch_number, batch_test in test.groupby(np.arange(len(test)) // batch_size):
    # tokanizing the text
    tokenized_val = tokenizer(batch_test["text"].values.tolist() , padding = 'max_length', truncation = True,  return_tensors="pt", max_length=256)

    # move on device (GPU)
    tokenized_val = {k:torch.tensor(v).to(device) for k,v in tokenized_val.items()}

    # get the cls hidden state
    with torch.no_grad():
        hidden_val = model(**tokenized_val)
            
    #get only the [CLS] hidden states
    cls_val = hidden_val.last_hidden_state[:,0,:]
    cls_val = cls_val.to("cpu")
    cls_val_list.append(cls_val)
    del cls_val
    del hidden_val
    del tokenized_val
    
    torch.cuda.empty_cache()

cls_val_list_final = []
for i in range(len(cls_val_list)):
    for j in range(len(cls_val_list[i])):
        cls_val_list_final.append(cls_val_list[i][j])
# Out:
# /home/ubuntu/pyenv/lib/python3.6/site-packages/ipykernel_launcher.py:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   # Remove the CWD from sys.path while we load stuff.

# %%
# Get embeddigns for the trainins set
cls_train_list = []
batch_size = 1000

for batch_number, batch_train in train.groupby(np.arange(len(train)) // batch_size):
    # tokanizing the text
    tokenized_train = tokenizer(batch_train["text"].values.tolist() , padding = 'max_length', truncation = True,  return_tensors="pt", max_length=256)

    # move on device (GPU)
    tokenized_train = {k:torch.tensor(v).to(device) for k,v in tokenized_train.items()}

    # get the cls hidden state
    with torch.no_grad():
        hidden_train = model(**tokenized_train)
            
    #get only the [CLS] hidden states
    cls_train = hidden_train.last_hidden_state[:,0,:]
    cls_train = cls_train.to("cpu")
    cls_train_list.append(cls_train)
    del cls_train
    del hidden_train
    del tokenized_train
    
    torch.cuda.empty_cache()

cls_train_list_final = []
for i in range(len(cls_train_list)):
    for j in range(len(cls_train_list[i])):
        cls_train_list_final.append(cls_train_list[i][j])
# Out:
# /home/ubuntu/pyenv/lib/python3.6/site-packages/ipykernel_launcher.py:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   # Remove the CWD from sys.path while we load stuff.

# %%
len(cls_val_list_final)
# Out:
# 691

# %%
len(cls_train_list_final)
# Out:
# 7847

# %%
X_train = torch.stack(cls_train_list_final)
X_train = pd.DataFrame(X_train)
X_test = torch.stack(cls_val_list_final)
X_test = pd.DataFrame(X_test)

y_train = kan_train['y'].values
y_test = kan_dev['y'].values

# %% [markdown]
# # Training a cat boost classifier

# %%
from catboost import CatBoostClassifier
cat = CatBoostClassifier(
    iterations=180, 
    learning_rate=.8, 
    #loss_function='CrossEntropy'
)

# %%
## train classifier
cat.fit(X_train, y_train)
predicted = cat.predict(X_test)
results['cat_boost_neg_bert'] = predicted
predicted_prob = cat.predict_proba(X_test)
# Out:
# 0:	learn: 1.2753231	total: 685ms	remaining: 2m 2s
# 1:	learn: 1.2109927	total: 1.05s	remaining: 1m 33s
# 2:	learn: 1.1610282	total: 1.48s	remaining: 1m 27s
# 3:	learn: 1.1263691	total: 1.86s	remaining: 1m 21s
# 4:	learn: 1.0987560	total: 2.24s	remaining: 1m 18s
# 5:	learn: 1.0717563	total: 2.62s	remaining: 1m 15s
# 6:	learn: 1.0517400	total: 3s	remaining: 1m 14s
# 7:	learn: 1.0314840	total: 3.37s	remaining: 1m 12s
# 8:	learn: 1.0059292	total: 3.74s	remaining: 1m 11s
# 9:	learn: 0.9898275	total: 4.11s	remaining: 1m 9s
# 10:	learn: 0.9706538	total: 4.5s	remaining: 1m 9s
# 11:	learn: 0.9501629	total: 4.87s	remaining: 1m 8s
# 12:	learn: 0.9378949	total: 5.23s	remaining: 1m 7s
# 13:	learn: 0.9246136	total: 5.59s	remaining: 1m 6s
# 14:	learn: 0.9086223	total: 5.96s	remaining: 1m 5s
# 15:	learn: 0.8962478	total: 6.31s	remaining: 1m 4s
# 16:	learn: 0.8798263	total: 6.68s	remaining: 1m 4s
# 17:	learn: 0.8689316	total: 7.02s	remaining: 1m 3s
# 18:	learn: 0.8588913	total: 7.36s	remaining: 1m 2s
# 19:	learn: 0.8420928	total: 7.74s	remaining: 1m 1s
# 20:	learn: 0.8314829	total: 8.1s	remaining: 1m 1s
# 21:	learn: 0.8213834	total: 8.45s	remaining: 1m
# 22:	learn: 0.8084597	total: 8.82s	remaining: 1m
# 23:	learn: 0.7980153	total: 9.17s	remaining: 59.6s
# 24:	learn: 0.7903674	total: 9.53s	remaining: 59.1s
# 25:	learn: 0.7780568	total: 9.9s	remaining: 58.7s
# 26:	learn: 0.7704615	total: 10.3s	remaining: 58.1s
# 27:	learn: 0.7612213	total: 10.6s	remaining: 57.6s
# 28:	learn: 0.7465747	total: 11s	remaining: 57.1s
# 29:	learn: 0.7371443	total: 11.3s	remaining: 56.7s
# 30:	learn: 0.7268334	total: 11.7s	remaining: 56.3s
# 31:	learn: 0.7140619	total: 12.1s	remaining: 55.8s
# 32:	learn: 0.7065410	total: 12.4s	remaining: 55.3s
# 33:	learn: 0.6947261	total: 12.8s	remaining: 54.9s
# 34:	learn: 0.6856737	total: 13.1s	remaining: 54.4s
# 35:	learn: 0.6800644	total: 13.5s	remaining: 53.9s
# 36:	learn: 0.6719016	total: 13.8s	remaining: 53.4s
# 37:	learn: 0.6681950	total: 14.2s	remaining: 53s
# 38:	learn: 0.6579520	total: 14.5s	remaining: 52.6s
# 39:	learn: 0.6463389	total: 14.9s	remaining: 52.2s
# 40:	learn: 0.6380844	total: 15.3s	remaining: 51.7s
# 41:	learn: 0.6273813	total: 15.6s	remaining: 51.3s
# 42:	learn: 0.6148171	total: 16s	remaining: 50.9s
# 43:	learn: 0.6089235	total: 16.3s	remaining: 50.5s
# 44:	learn: 0.6027841	total: 16.7s	remaining: 50.1s
# 45:	learn: 0.5966085	total: 17s	remaining: 49.6s
# 46:	learn: 0.5876157	total: 17.4s	remaining: 49.2s
# 47:	learn: 0.5776987	total: 17.8s	remaining: 48.8s
# 48:	learn: 0.5693744	total: 18.1s	remaining: 48.4s
# 49:	learn: 0.5629531	total: 18.5s	remaining: 48s
# 50:	learn: 0.5525325	total: 18.9s	remaining: 47.7s
# 51:	learn: 0.5453953	total: 19.2s	remaining: 47.3s
# 52:	learn: 0.5414224	total: 19.6s	remaining: 46.9s
# 53:	learn: 0.5316373	total: 19.9s	remaining: 46.5s
# 54:	learn: 0.5246694	total: 20.3s	remaining: 46.2s
# 55:	learn: 0.5194849	total: 20.7s	remaining: 45.7s
# 56:	learn: 0.5128028	total: 21s	remaining: 45.3s
# 57:	learn: 0.5078602	total: 21.3s	remaining: 44.9s
# 58:	learn: 0.5023055	total: 21.7s	remaining: 44.5s
# 59:	learn: 0.4979342	total: 22s	remaining: 44.1s
# 60:	learn: 0.4911162	total: 22.4s	remaining: 43.7s
# 61:	learn: 0.4872518	total: 22.8s	remaining: 43.3s
# 62:	learn: 0.4788783	total: 23.1s	remaining: 43s
# 63:	learn: 0.4734287	total: 23.5s	remaining: 42.6s
# 64:	learn: 0.4690775	total: 23.8s	remaining: 42.2s
# 65:	learn: 0.4649454	total: 24.2s	remaining: 41.8s
# 66:	learn: 0.4593489	total: 24.6s	remaining: 41.4s
# 67:	learn: 0.4544646	total: 24.9s	remaining: 41.1s
# 68:	learn: 0.4515440	total: 25.3s	remaining: 40.6s
# 69:	learn: 0.4475610	total: 25.6s	remaining: 40.2s
# 70:	learn: 0.4445429	total: 26s	remaining: 39.9s
# 71:	learn: 0.4414923	total: 26.3s	remaining: 39.5s
# 72:	learn: 0.4361253	total: 26.7s	remaining: 39.1s
# 73:	learn: 0.4291064	total: 27s	remaining: 38.7s
# 74:	learn: 0.4275839	total: 27.4s	remaining: 38.3s
# 75:	learn: 0.4232386	total: 27.7s	remaining: 37.9s
# 76:	learn: 0.4209065	total: 28.1s	remaining: 37.5s
# 77:	learn: 0.4176842	total: 28.4s	remaining: 37.2s
# 78:	learn: 0.4117838	total: 28.8s	remaining: 36.8s
# 79:	learn: 0.4092514	total: 29.1s	remaining: 36.4s
# 80:	learn: 0.4047712	total: 29.5s	remaining: 36.1s
# 81:	learn: 0.4024127	total: 29.8s	remaining: 35.7s
# 82:	learn: 0.3995773	total: 30.2s	remaining: 35.3s
# 83:	learn: 0.3961922	total: 30.5s	remaining: 34.9s
# 84:	learn: 0.3911027	total: 30.9s	remaining: 34.6s
# 85:	learn: 0.3890622	total: 31.3s	remaining: 34.2s
# 86:	learn: 0.3848937	total: 31.6s	remaining: 33.8s
# 87:	learn: 0.3806331	total: 32s	remaining: 33.4s
# 88:	learn: 0.3765965	total: 32.3s	remaining: 33.1s
# 89:	learn: 0.3734295	total: 32.7s	remaining: 32.7s
# 90:	learn: 0.3711180	total: 33s	remaining: 32.3s
# 91:	learn: 0.3671999	total: 33.4s	remaining: 31.9s
# 92:	learn: 0.3612621	total: 33.8s	remaining: 31.6s
# 93:	learn: 0.3578264	total: 34.1s	remaining: 31.2s
# 94:	learn: 0.3563536	total: 34.5s	remaining: 30.8s
# 95:	learn: 0.3539583	total: 34.8s	remaining: 30.5s
# 96:	learn: 0.3504014	total: 35.1s	remaining: 30.1s
# 97:	learn: 0.3450481	total: 35.5s	remaining: 29.7s
# 98:	learn: 0.3425198	total: 35.9s	remaining: 29.3s
# 99:	learn: 0.3391654	total: 36.2s	remaining: 29s
# 100:	learn: 0.3367617	total: 36.6s	remaining: 28.6s
# 101:	learn: 0.3338332	total: 36.9s	remaining: 28.2s
# 102:	learn: 0.3295918	total: 37.3s	remaining: 27.9s
# 103:	learn: 0.3248013	total: 37.6s	remaining: 27.5s
# 104:	learn: 0.3223908	total: 38s	remaining: 27.1s
# 105:	learn: 0.3204130	total: 38.3s	remaining: 26.8s
# 106:	learn: 0.3176359	total: 38.7s	remaining: 26.4s
# 107:	learn: 0.3164250	total: 39s	remaining: 26s
# 108:	learn: 0.3140425	total: 39.4s	remaining: 25.7s
# 109:	learn: 0.3114108	total: 39.7s	remaining: 25.3s
# 110:	learn: 0.3098022	total: 40.1s	remaining: 24.9s
# 111:	learn: 0.3079768	total: 40.4s	remaining: 24.5s
# 112:	learn: 0.3043450	total: 40.8s	remaining: 24.2s
# 113:	learn: 0.3034199	total: 41.1s	remaining: 23.8s
# 114:	learn: 0.3014999	total: 41.4s	remaining: 23.4s
# 115:	learn: 0.2994728	total: 41.8s	remaining: 23.1s
# 116:	learn: 0.2979770	total: 42.1s	remaining: 22.7s
# 117:	learn: 0.2954443	total: 42.5s	remaining: 22.3s
# 118:	learn: 0.2919666	total: 42.8s	remaining: 21.9s
# 119:	learn: 0.2905004	total: 43.2s	remaining: 21.6s
# 120:	learn: 0.2881883	total: 43.5s	remaining: 21.2s
# 121:	learn: 0.2865297	total: 43.9s	remaining: 20.9s
# 122:	learn: 0.2834994	total: 44.2s	remaining: 20.5s
# 123:	learn: 0.2822616	total: 44.6s	remaining: 20.1s
# 124:	learn: 0.2802144	total: 44.9s	remaining: 19.8s
# 125:	learn: 0.2786649	total: 45.3s	remaining: 19.4s
# 126:	learn: 0.2772811	total: 45.6s	remaining: 19s
# 127:	learn: 0.2758344	total: 46s	remaining: 18.7s
# 128:	learn: 0.2729497	total: 46.3s	remaining: 18.3s
# 129:	learn: 0.2711387	total: 46.7s	remaining: 18s
# 130:	learn: 0.2693546	total: 47s	remaining: 17.6s
# 131:	learn: 0.2683257	total: 47.4s	remaining: 17.2s
# 132:	learn: 0.2664307	total: 47.7s	remaining: 16.9s
# 133:	learn: 0.2652319	total: 48.1s	remaining: 16.5s
# 134:	learn: 0.2641100	total: 48.4s	remaining: 16.1s
# 135:	learn: 0.2612718	total: 48.8s	remaining: 15.8s
# 136:	learn: 0.2589293	total: 49.1s	remaining: 15.4s
# 137:	learn: 0.2573642	total: 49.5s	remaining: 15.1s
# 138:	learn: 0.2553157	total: 49.8s	remaining: 14.7s
# 139:	learn: 0.2531826	total: 50.2s	remaining: 14.3s
# 140:	learn: 0.2522211	total: 50.6s	remaining: 14s
# 141:	learn: 0.2499061	total: 50.9s	remaining: 13.6s
# 142:	learn: 0.2484036	total: 51.3s	remaining: 13.3s
# 143:	learn: 0.2467141	total: 51.6s	remaining: 12.9s
# 144:	learn: 0.2451940	total: 52s	remaining: 12.5s
# 145:	learn: 0.2436823	total: 52.3s	remaining: 12.2s
# 146:	learn: 0.2419851	total: 52.7s	remaining: 11.8s
# 147:	learn: 0.2409362	total: 53s	remaining: 11.5s
# 148:	learn: 0.2395804	total: 53.4s	remaining: 11.1s
# 149:	learn: 0.2385616	total: 53.7s	remaining: 10.7s
# 150:	learn: 0.2377450	total: 54s	remaining: 10.4s
# 151:	learn: 0.2366402	total: 54.4s	remaining: 10s
# 152:	learn: 0.2358240	total: 54.7s	remaining: 9.66s
# 153:	learn: 0.2340533	total: 55.1s	remaining: 9.3s
# 154:	learn: 0.2327037	total: 55.4s	remaining: 8.94s
# 155:	learn: 0.2302138	total: 55.8s	remaining: 8.58s
# 156:	learn: 0.2283750	total: 56.1s	remaining: 8.22s
# 157:	learn: 0.2266285	total: 56.5s	remaining: 7.87s
# 158:	learn: 0.2259368	total: 56.8s	remaining: 7.5s
# 159:	learn: 0.2234568	total: 57.2s	remaining: 7.15s
# 160:	learn: 0.2219802	total: 57.5s	remaining: 6.79s
# 161:	learn: 0.2208725	total: 57.9s	remaining: 6.43s
# 162:	learn: 0.2189169	total: 58.2s	remaining: 6.07s
# 163:	learn: 0.2176590	total: 58.6s	remaining: 5.72s
# 164:	learn: 0.2160867	total: 59s	remaining: 5.36s
# 165:	learn: 0.2152406	total: 59.3s	remaining: 5s
# 166:	learn: 0.2144673	total: 59.6s	remaining: 4.64s
# 167:	learn: 0.2132880	total: 60s	remaining: 4.29s
# 168:	learn: 0.2122400	total: 1m	remaining: 3.93s
# 169:	learn: 0.2098751	total: 1m	remaining: 3.57s
# 170:	learn: 0.2083538	total: 1m 1s	remaining: 3.21s
# 171:	learn: 0.2069802	total: 1m 1s	remaining: 2.86s
# 172:	learn: 0.2059286	total: 1m 1s	remaining: 2.5s
# 173:	learn: 0.2050833	total: 1m 2s	remaining: 2.14s
# 174:	learn: 0.2040713	total: 1m 2s	remaining: 1.78s
# 175:	learn: 0.2032081	total: 1m 2s	remaining: 1.43s
# 176:	learn: 0.2024290	total: 1m 3s	remaining: 1.07s
# 177:	learn: 0.2010802	total: 1m 3s	remaining: 713ms
# 178:	learn: 0.1999236	total: 1m 3s	remaining: 357ms
# 179:	learn: 0.1992284	total: 1m 4s	remaining: 0us

# %%
# lets see our model performance
classes = np.unique(y_test)
y_test_array = pd.get_dummies(y_test, drop_first=False).values
    
## Accuracy, Precision, Recall
accuracy = metrics.accuracy_score(y_test, predicted)
auc = metrics.roc_auc_score(y_test, predicted_prob, 
                            multi_class="ovr")
print("Accuracy:",  round(accuracy,2))
print("Auc:", round(auc,2))
print("Detail:")
print(metrics.classification_report(y_test, predicted))
    
## Plot confusion matrix
cm = metrics.confusion_matrix(y_test, predicted)
fig, ax = plt.subplots()
sns.heatmap(cm, annot=True, fmt='d', ax=ax, cmap=plt.cm.Blues, 
            cbar=False)
ax.set(xlabel="Pred", ylabel="True", xticklabels=classes, 
       yticklabels=classes, title="Confusion matrix")
plt.yticks(rotation=0)

fig, ax = plt.subplots(nrows=1, ncols=2)
## Plot roc
for i in range(len(classes)):
    fpr, tpr, thresholds = metrics.roc_curve(y_test_array[:,i],  
                           predicted_prob[:,i])
    ax[0].plot(fpr, tpr, lw=3, 
              label='{0} (area={1:0.2f})'.format(classes[i], 
                              metrics.auc(fpr, tpr))
               )
ax[0].plot([0,1], [0,1], color='navy', lw=3, linestyle='--')
ax[0].set(xlim=[-0.05,1.0], ylim=[0.0,1.05], 
          xlabel='False Positive Rate', 
          ylabel="True Positive Rate (Recall)", 
          title="Receiver operating characteristic")
ax[0].legend(loc="lower right")
ax[0].grid(True)
    
## Plot precision-recall curve
for i in range(len(classes)):
    precision, recall, thresholds = metrics.precision_recall_curve(
                 y_test_array[:,i], predicted_prob[:,i])
    ax[1].plot(recall, precision, lw=3, 
               label='{0} (area={1:0.2f})'.format(classes[i], 
                                  metrics.auc(recall, precision))
              )
ax[1].set(xlim=[0.0,1.05], ylim=[0.0,1.05], xlabel='Recall', 
          ylabel="Precision", title="Precision-Recall curve")
ax[1].legend(loc="best")
ax[1].grid(True)
plt.show()
# Out:
# Accuracy: 0.54
# Auc: 0.74
# Detail:
#                 precision    recall  f1-score   support
#
# Mixed feelings       0.23      0.12      0.15        52
#       Negative       0.44      0.54      0.49       139
#       Positive       0.64      0.66      0.65       321
#    not-Kannada       0.61      0.55      0.58       110
#  unknown state       0.29      0.26      0.27        69
#
#       accuracy                           0.54       691
#      macro avg       0.44      0.43      0.43       691
#   weighted avg       0.53      0.54      0.53       691

# %% [markdown]
# # Training a Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(max_depth=150, n_estimators=15, max_features=768)

# %%
## train classifier
forest.fit(X_train, y_train)
## test
predicted = forest.predict(X_test)
results['forest_neg_bert'] = predicted
predicted_prob = forest.predict_proba(X_test)

# %%
# lets see our model performance
classes = np.unique(y_test)
y_test_array = pd.get_dummies(y_test, drop_first=False).values
    
## Accuracy, Precision, Recall
accuracy = metrics.accuracy_score(y_test, predicted)
auc = metrics.roc_auc_score(y_test, predicted_prob, 
                            multi_class="ovr")
print("Accuracy:",  round(accuracy,2))
print("Auc:", round(auc,2))
print("Detail:")
print(metrics.classification_report(y_test, predicted))
    
## Plot confusion matrix
cm = metrics.confusion_matrix(y_test, predicted)
fig, ax = plt.subplots()
sns.heatmap(cm, annot=True, fmt='d', ax=ax, cmap=plt.cm.Blues, 
            cbar=False)
ax.set(xlabel="Pred", ylabel="True", xticklabels=classes, 
       yticklabels=classes, title="Confusion matrix")
plt.yticks(rotation=0)

fig, ax = plt.subplots(nrows=1, ncols=2)
## Plot roc
for i in range(len(classes)):
    fpr, tpr, thresholds = metrics.roc_curve(y_test_array[:,i],  
                           predicted_prob[:,i])
    ax[0].plot(fpr, tpr, lw=3, 
              label='{0} (area={1:0.2f})'.format(classes[i], 
                              metrics.auc(fpr, tpr))
               )
ax[0].plot([0,1], [0,1], color='navy', lw=3, linestyle='--')
ax[0].set(xlim=[-0.05,1.0], ylim=[0.0,1.05], 
          xlabel='False Positive Rate', 
          ylabel="True Positive Rate (Recall)", 
          title="Receiver operating characteristic")
ax[0].legend(loc="lower right")
ax[0].grid(True)
    
## Plot precision-recall curve
for i in range(len(classes)):
    precision, recall, thresholds = metrics.precision_recall_curve(
                 y_test_array[:,i], predicted_prob[:,i])
    ax[1].plot(recall, precision, lw=3, 
               label='{0} (area={1:0.2f})'.format(classes[i], 
                                  metrics.auc(recall, precision))
              )
ax[1].set(xlim=[0.0,1.05], ylim=[0.0,1.05], xlabel='Recall', 
          ylabel="Precision", title="Precision-Recall curve")
ax[1].legend(loc="best")
ax[1].grid(True)
plt.show()
# Out:
# Accuracy: 0.5
# Auc: 0.72
# Detail:
#                 precision    recall  f1-score   support
#
# Mixed feelings       0.24      0.10      0.14        52
#       Negative       0.38      0.55      0.45       139
#       Positive       0.56      0.62      0.59       321
#    not-Kannada       0.56      0.46      0.51       110
#  unknown state       0.55      0.17      0.26        69
#
#       accuracy                           0.50       691
#      macro avg       0.46      0.38      0.39       691
#   weighted avg       0.50      0.50      0.48       691

# %% [markdown]
# # fitting a logistic regression classifier

# %%
from sklearn.linear_model import LogisticRegression
log =LogisticRegression(random_state=0, max_iter= 1000)

# %%
## pipeline

## train classifier
log.fit(X_train, y_train)
## test
predicted = log.predict(X_test)
results['log_neg_bert'] = predicted
predicted_prob = log.predict_proba(X_test)
# Out:
# /home/ubuntu/pyenv/lib/python3.6/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
# lets see our model performance
classes = np.unique(y_test)
y_test_array = pd.get_dummies(y_test, drop_first=False).values
    
## Accuracy, Precision, Recall
accuracy = metrics.accuracy_score(y_test, predicted)
auc = metrics.roc_auc_score(y_test, predicted_prob, 
                            multi_class="ovr")
print("Accuracy:",  round(accuracy,2))
print("Auc:", round(auc,2))
print("Detail:")
print(metrics.classification_report(y_test, predicted))
    
## Plot confusion matrix
cm = metrics.confusion_matrix(y_test, predicted)
fig, ax = plt.subplots()
sns.heatmap(cm, annot=True, fmt='d', ax=ax, cmap=plt.cm.Blues, 
            cbar=False)
ax.set(xlabel="Pred", ylabel="True", xticklabels=classes, 
       yticklabels=classes, title="Confusion matrix")
plt.yticks(rotation=0)

fig, ax = plt.subplots(nrows=1, ncols=2)
## Plot roc
for i in range(len(classes)):
    fpr, tpr, thresholds = metrics.roc_curve(y_test_array[:,i],  
                           predicted_prob[:,i])
    ax[0].plot(fpr, tpr, lw=3, 
              label='{0} (area={1:0.2f})'.format(classes[i], 
                              metrics.auc(fpr, tpr))
               )
ax[0].plot([0,1], [0,1], color='navy', lw=3, linestyle='--')
ax[0].set(xlim=[-0.05,1.0], ylim=[0.0,1.05], 
          xlabel='False Positive Rate', 
          ylabel="True Positive Rate (Recall)", 
          title="Receiver operating characteristic")
ax[0].legend(loc="lower right")
ax[0].grid(True)
    
## Plot precision-recall curve
for i in range(len(classes)):
    precision, recall, thresholds = metrics.precision_recall_curve(
                 y_test_array[:,i], predicted_prob[:,i])
    ax[1].plot(recall, precision, lw=3, 
               label='{0} (area={1:0.2f})'.format(classes[i], 
                                  metrics.auc(recall, precision))
              )
ax[1].set(xlim=[0.0,1.05], ylim=[0.0,1.05], xlabel='Recall', 
          ylabel="Precision", title="Precision-Recall curve")
ax[1].legend(loc="best")
ax[1].grid(True)
plt.show()
# Out:
# Accuracy: 0.58
# Auc: 0.81
# Detail:
#                 precision    recall  f1-score   support
#
# Mixed feelings       0.25      0.02      0.04        52
#       Negative       0.45      0.59      0.51       139
#       Positive       0.64      0.71      0.67       321
#    not-Kannada       0.62      0.65      0.63       110
#  unknown state       0.54      0.28      0.37        69
#
#       accuracy                           0.58       691
#      macro avg       0.50      0.45      0.44       691
#   weighted avg       0.56      0.58      0.56       691

# %% [markdown]
# # training a k-neighboot classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=8, weights='distance')

# %%
## train classifier
neigh.fit(X_train, y_train)
## test
predicted = neigh.predict(X_test)
results['neigh_neg_bert'] = predicted
predicted_prob = neigh.predict_proba(X_test)

# %%
# lets see our model performance
classes = np.unique(y_test)
y_test_array = pd.get_dummies(y_test, drop_first=False).values
    
## Accuracy, Precision, Recall
accuracy = metrics.accuracy_score(y_test, predicted)
auc = metrics.roc_auc_score(y_test, predicted_prob, 
                            multi_class="ovr")
print("Accuracy:",  round(accuracy,2))
print("Auc:", round(auc,2))
print("Detail:")
print(metrics.classification_report(y_test, predicted))
    
## Plot confusion matrix
cm = metrics.confusion_matrix(y_test, predicted)
fig, ax = plt.subplots()
sns.heatmap(cm, annot=True, fmt='d', ax=ax, cmap=plt.cm.Blues, 
            cbar=False)
ax.set(xlabel="Pred", ylabel="True", xticklabels=classes, 
       yticklabels=classes, title="Confusion matrix")
plt.yticks(rotation=0)

fig, ax = plt.subplots(nrows=1, ncols=2)
## Plot roc
for i in range(len(classes)):
    fpr, tpr, thresholds = metrics.roc_curve(y_test_array[:,i],  
                           predicted_prob[:,i])
    ax[0].plot(fpr, tpr, lw=3, 
              label='{0} (area={1:0.2f})'.format(classes[i], 
                              metrics.auc(fpr, tpr))
               )
ax[0].plot([0,1], [0,1], color='navy', lw=3, linestyle='--')
ax[0].set(xlim=[-0.05,1.0], ylim=[0.0,1.05], 
          xlabel='False Positive Rate', 
          ylabel="True Positive Rate (Recall)", 
          title="Receiver operating characteristic")
ax[0].legend(loc="lower right")
ax[0].grid(True)
    
## Plot precision-recall curve
for i in range(len(classes)):
    precision, recall, thresholds = metrics.precision_recall_curve(
                 y_test_array[:,i], predicted_prob[:,i])
    ax[1].plot(recall, precision, lw=3, 
               label='{0} (area={1:0.2f})'.format(classes[i], 
                                  metrics.auc(recall, precision))
              )
ax[1].set(xlim=[0.0,1.05], ylim=[0.0,1.05], xlabel='Recall', 
          ylabel="Precision", title="Precision-Recall curve")
ax[1].legend(loc="best")
ax[1].grid(True)
plt.show()
# Out:
# Accuracy: 0.59
# Auc: 0.75
# Detail:
#                 precision    recall  f1-score   support
#
# Mixed feelings       0.30      0.12      0.17        52
#       Negative       0.48      0.66      0.56       139
#       Positive       0.67      0.68      0.68       321
#    not-Kannada       0.60      0.63      0.61       110
#  unknown state       0.55      0.30      0.39        69
#
#       accuracy                           0.59       691
#      macro avg       0.52      0.48      0.48       691
#   weighted avg       0.58      0.59      0.58       691

# %% [markdown]
# # Ensemble

# %%
results.replace(['Negative', 'Positive','not-Kannada', 'Mixed feelings','unknown state' ], [0,1,2,3,4], inplace=True)
results['neg_majority_label_bert'] = results[results.columns[1:]].mode(axis=1)[0].astype(int)
results.replace([0,1,2,3,4], ['Negative', 'Positive','not-Kannada', 'Mixed feelings','unknown state' ], inplace=True)
results.to_csv('kan_results_neg_bert.tsv', sep="\t", index = False)

# %%
## Plot confusion matrix
print(metrics.classification_report(results['y'], results['neg_majority_label_bert']))
cm = metrics.confusion_matrix(results['y'], results['neg_majority_label_bert'])
fig, ax = plt.subplots()
sns.heatmap(cm, annot=True, fmt='d', ax=ax, cmap=plt.cm.Blues, 
            cbar=False)
ax.set(xlabel="Pred", ylabel="True", xticklabels=classes, 
       yticklabels=classes, title="Confusion matrix")
plt.yticks(rotation=0)
plt.show()
# Out:
#                 precision    recall  f1-score   support
#
# Mixed feelings       0.60      0.06      0.11        52
#       Negative       0.44      0.69      0.54       139
#       Positive       0.63      0.69      0.66       321
#    not-Kannada       0.66      0.55      0.60       110
#  unknown state       0.67      0.23      0.34        69
#
#       accuracy                           0.57       691
#      macro avg       0.60      0.44      0.45       691
#   weighted avg       0.60      0.57      0.55       691
