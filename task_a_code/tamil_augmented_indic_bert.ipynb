# %%
import pandas as pd
import numpy as np
import torch
from torch import cuda
from torch.utils.data import Dataset, DataLoader
from transformers import pipeline
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from sklearn.metrics import accuracy_score, classification_report, precision_score, recall_score, f1_score
from load_data import initialize_data
from reading_datasets import read_task
from labels_to_ids import labels_to_ids_tam
import time
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
def train(epoch, train_loader, model, optimizer, device, grad_step = 1, max_grad_norm = 10):
    tr_loss, tr_accuracy = 0, 0
    tr_precision, tr_recall = 0, 0
    tr_f1score = 0
    nb_tr_examples, nb_tr_steps = 0, 0
    tr_preds, tr_labels = [], []
    # put model in training mode
    model.train()
    optimizer.zero_grad()
    
    for idx, batch in enumerate(train_loader):
        ids = batch['input_ids'].to(device, dtype = torch.long)
        mask = batch['attention_mask'].to(device, dtype = torch.long)
        labels = batch['labels'].to(device, dtype = torch.long)

        if (idx + 1) % 20 == 0:
            print('FINSIHED BATCH:', idx, 'of', len(train_loader))

        #loss, tr_logits = model(input_ids=ids, attention_mask=mask, labels=labels)
        output = model(input_ids=ids, attention_mask=mask, labels=labels)
        tr_loss += output[0]

        nb_tr_steps += 1
        nb_tr_examples += labels.size(0)
           
        # compute training accuracy
        flattened_targets = labels.view(-1) # shape (batch_size * seq_len,)
        active_logits = output[1].view(-1, model.num_labels) # shape (batch_size * seq_len, num_labels)
        flattened_predictions = torch.argmax(active_logits, axis=1) # shape (batch_size * seq_len,)
        
        # only compute accuracy at active labels
        active_accuracy = labels.view(-1) != -100 # shape (batch_size, seq_len)
        #active_labels = torch.where(active_accuracy, labels.view(-1), torch.tensor(-100).type_as(labels))
        
        labels = torch.masked_select(flattened_targets, active_accuracy)
        predictions = torch.masked_select(flattened_predictions, active_accuracy)

        tr_labels.extend(labels)
        tr_preds.extend(predictions)

        tmp_tr_accuracy = accuracy_score(labels.cpu().numpy(), predictions.cpu().numpy())
        tr_accuracy += tmp_tr_accuracy
        
        # Compute Precision
        tmp_tr_precision = precision_score(labels.cpu().numpy(), predictions.cpu().numpy(), average = 'macro', zero_division=0 )
        tr_precision += tmp_tr_precision
        
        # Compute Recall
        tmp_tr_recall = recall_score(labels.cpu().numpy(), predictions.cpu().numpy(), average = 'macro', zero_division=0)
        tr_recall += tmp_tr_recall
        
        # Compute f1score
        tmp_tr_f1score = f1_score(labels.cpu().numpy(), predictions.cpu().numpy(), average= 'macro', zero_division=0)
        tr_f1score += tmp_tr_f1score
    
        # gradient clipping
        torch.nn.utils.clip_grad_norm_(
            parameters=model.parameters(), max_norm=max_grad_norm
        )
        
        # backward pass
        output['loss'].backward()
        if (idx + 1) % grad_step == 0:
            optimizer.step()
            optimizer.zero_grad()

    epoch_loss = tr_loss / nb_tr_steps
    tr_accuracy = tr_accuracy / nb_tr_steps
    tr_precision = tr_precision / nb_tr_steps
    tr_recall = tr_recall / nb_tr_steps
    tr_f1score= tr_f1score / nb_tr_steps
    #print(f"Training loss epoch: {epoch_loss}")
    #print(f"Training accuracy epoch: {tr_accuracy}")

    return model

# %%
def testing(model, testing_loader, labels_to_ids, device):
    # put model in evaluation mode
    model.eval()
    
    eval_loss, eval_accuracy = 0, 0
    eval_precision, eval_recall = 0, 0
    eval_f1score = 0
    nb_eval_examples, nb_eval_steps = 0, 0
    eval_preds, eval_labels = [], []
     
    
    ids_to_labels = dict((v,k) for k,v in labels_to_ids.items())

    with torch.no_grad():
        for idx, batch in enumerate(testing_loader):
            
            ids = batch['input_ids'].to(device, dtype = torch.long)
            mask = batch['attention_mask'].to(device, dtype = torch.long)
            labels = batch['labels'].to(device, dtype = torch.long)
            
            #loss, eval_logits = model(input_ids=ids, attention_mask=mask, labels=labels)
            output = model(input_ids=ids, attention_mask=mask, labels=labels)

            eval_loss += output['loss'].item()

            nb_eval_steps += 1
            nb_eval_examples += labels.size(0)
        
            if idx % 100==0:
                loss_step = eval_loss/nb_eval_steps
                print(f"Validation loss per 100 evaluation steps: {loss_step}")
              
            # compute evaluation accuracy
            flattened_targets = labels.view(-1) # shape (batch_size * seq_len,)
            active_logits = output[1].view(-1, model.num_labels) # shape (batch_size * seq_len, num_labels)
            flattened_predictions = torch.argmax(active_logits, axis=1) # shape (batch_size * seq_len,)
            
            # only compute accuracy at active labels
            active_accuracy = labels.view(-1) != -100 # shape (batch_size, seq_len)
        
            labels = torch.masked_select(flattened_targets, active_accuracy)
            predictions = torch.masked_select(flattened_predictions, active_accuracy)
            
            eval_labels.extend(labels)
            eval_preds.extend(predictions)
            
            tmp_eval_accuracy = accuracy_score(labels.cpu().numpy(), predictions.cpu().numpy())
            eval_accuracy += tmp_eval_accuracy
            
            # Compute Precision
            tmp_eval_precision = precision_score(labels.cpu().numpy(), predictions.cpu().numpy(), average = 'macro', zero_division=0)
            eval_precision += tmp_eval_precision
            
            # Compute Recall
            tmp_eval_recall = recall_score(labels.cpu().numpy(), predictions.cpu().numpy(), average = 'macro', zero_division=0)
            eval_recall += tmp_eval_recall
            
            # Compute f1score
            tmp_eval_f1score = f1_score(labels.cpu().numpy(), predictions.cpu().numpy(), average='macro', zero_division=0)
            eval_f1score += tmp_eval_f1score

    labels = [ids_to_labels[id.item()] for id in eval_labels]
    predictions = [ids_to_labels[id.item()] for id in eval_preds]
    
    eval_loss = eval_loss / nb_eval_steps
    eval_accuracy = eval_accuracy / nb_eval_steps
    eval_precision = eval_precision / nb_eval_steps
    eval_recall = eval_recall / nb_eval_steps
    eval_f1score = eval_f1score / nb_eval_steps
    #print(f"Validation Loss: {eval_loss}")
    #print(f"Validation Accuracy: {eval_accuracy}")

    return labels, predictions, eval_accuracy, eval_precision, eval_recall, eval_f1score

# %%
def main(n_epochs, model_name, model_save_flag, model_save_location, model_load_flag, model_load_location):
    #Initialization training parameters
    max_len = 256
    batch_size = 32
    grad_step = 1
    learning_rate = 1e-05
    initialization_input = (max_len, batch_size)

    #Reading datasets and initializing data loaders
    dataset_location = '../datasets/task_a/'

    train_data = read_task(dataset_location , split = 'tam_train_negative_augmented')
    dev_data = read_task(dataset_location , split = 'tam_sentiment_dev')
    #test_data = read_task(dataset_location , split = 'dev')#load test set
    labels_to_ids = labels_to_ids_tam
    #input_data = (train_data, dev_data, labels_to_ids)

    #Define tokenizer, model and optimizer
    device = 'cuda' if cuda.is_available() else 'cpu' #save the processing time
    if model_load_flag:
        tokenizer = AutoTokenizer.from_pretrained(model_load_location)
        model = AutoModelForSequenceClassification.from_pretrained(model_load_location)
    else: 
        tokenizer =  AutoTokenizer.from_pretrained(model_name, add_prefix_space=True)
        model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=len(labels_to_ids))
    optimizer = torch.optim.Adam(params=model.parameters(), lr=learning_rate)
    model.to(device)

    #Get dataloaders
    train_loader = initialize_data(tokenizer, initialization_input, train_data, labels_to_ids, shuffle = True)
    dev_loader = initialize_data(tokenizer, initialization_input, dev_data, labels_to_ids, shuffle = True)
    #test_loader = initialize_data(tokenizer, initialization_input, test_data, labels_to_ids, shuffle = True)#create test loader

    best_dev_acc = 0
    best_test_acc = 0
    best_dev_precision = 0
    best_test_precision = 0
    best_dev_recall = 0
    best_test_recall = 0
    best_dev_f1score = 0
    best_test_f1score = 0
    best_epoch = -1
    
    list_dev_acc = [] 
    list_test_acc = []  
    list_dev_precision = []  
    list_test_precision  = []  
    list_dev_recall = []  
    list_test_recall = []  
    list_dev_f1score = []  
    list_test_f1score = []
    
    for epoch in range(n_epochs):
        start = time.time()
        print(f"Training epoch: {epoch + 1}")

        #train model
        if not model_load_flag:
            model = train(epoch, train_loader, model, optimizer, device, grad_step)
        
        #testing and logging
        labels_dev, predictions_dev, dev_accuracy, dev_precision, dev_recall, dev_f1score = testing(model, dev_loader, labels_to_ids, device)
        print('DEV ACC:', dev_accuracy)
        print('DEV Precision:' , dev_precision)
        print('DEV Recall:' , dev_recall)
        print('DEV F1Score:' , dev_f1score)
        
        list_dev_acc.append(dev_accuracy)     
        list_dev_precision.append(dev_precision)   
        list_dev_recall.append(dev_recall)  
        list_dev_f1score.append(dev_f1score)  
        
        
        #labels_test, predictions_test, test_accuracy, test_precision, test_recall, test_f1score = testing(model, test_loader, labels_to_ids, device)
        #print('TEST ACC:', test_accuracy)
        #print('TEST Precision:' , test_precision)
        #print('TEST Recall:' , test_recall)
        #print('TEST F1Score:' , test_f1score)
        
        #list_test_acc.append(test_accuracy) 
        #list_test_precision.append(test_precision)  
        #list_test_recall.append(test_recall)
        #list_test_f1score.append(test_f1score) 

        #saving model
        if dev_accuracy > best_dev_acc:
            best_dev_acc = dev_accuracy
            #best_test_acc = test_accuracy
        if dev_precision > best_dev_precision:
            best_dev_precision = dev_precision
            #best_test_precision = test_precision
        if dev_recall > best_dev_recall:
            best_dev_recall = dev_recall
            #best_test_recall = test_recall
        if dev_f1score > best_dev_f1score:
            best_dev_f1score = dev_f1score
            #best_test_f1score = test_f1score
            best_epoch = epoch
            
            if model_save_flag:
                os.makedirs(model_save_location, exist_ok=True)
                tokenizer.save_pretrained(model_save_location)
                model.save_pretrained(model_save_location)

        now = time.time()
        print('BEST ACCURACY --> ', 'DEV:', round(best_dev_acc, 5))
        print('BEST PRECISION --> ', 'DEV:', round(best_dev_precision, 5))
        print('BEST RECALL --> ', 'DEV:', round(best_dev_recall, 5))
        print('BEST F1SCORE --> ', 'DEV:', round(best_dev_f1score, 5))
        print('TIME PER EPOCH:', (now-start)/60 )
        print()

    return best_dev_acc, best_test_acc, best_epoch, best_dev_precision, best_test_precision, best_dev_recall, best_test_recall, best_dev_f1score, best_test_f1score, list_dev_acc, list_test_acc, list_dev_precision, list_test_precision, list_dev_recall, list_test_recall, list_dev_f1score, list_test_f1score

# %%
if __name__ == '__main__':
    n_epochs = 10
    models = ['ai4bharat/indic-bert']
    
    #model saving parameters
    model_save_flag = True
    model_load_flag = False
    
    overall_list_dev_acc = [] 
    overall_list_test_acc = []    
    overall_list_dev_precision = []  
    overall_list_test_precision  = []  
    overall_list_dev_recall = []  
    overall_list_test_recall = []  
    overall_list_dev_f1score = []  
    overall_list_test_f1score = [] 
    
    for i in range(5):
        
        for model_name in models:

            model_save_location = 'saved_models/' + model_name + 'Tamil' + 'Augmented' +str(i)
            model_load_location = None

            best_dev_acc, best_test_acc, best_epoch, best_dev_precision, best_test_precision, best_dev_recall, best_test_recall, best_dev_f1score, best_test_f1score, list_dev_acc, list_test_acc, list_dev_precision, list_test_precision, list_dev_recall, list_test_recall, list_dev_f1score, list_test_f1score = main(n_epochs, model_name, model_save_flag, model_save_location, model_load_flag, model_load_location)
            
            overall_list_dev_acc.append(list_dev_acc) 
            overall_list_test_acc.append(list_test_acc) 
            overall_list_dev_precision.append(list_dev_precision)  
            overall_list_test_precision.append(list_test_precision) 
            overall_list_dev_recall.append(list_dev_recall)  
            overall_list_test_recall.append(list_test_recall)  
            overall_list_dev_f1score.append(list_dev_f1score)  
            overall_list_test_f1score.append(list_test_f1score)
# Out:
# Some weights of the model checkpoint at ai4bharat/indic-bert were not used when initializing AlbertForSequenceClassification: ['predictions.decoder.weight', 'predictions.bias', 'predictions.decoder.bias', 'predictions.LayerNorm.bias', 'predictions.LayerNorm.weight', 'sop_classifier.classifier.weight', 'predictions.dense.weight', 'predictions.dense.bias', 'sop_classifier.classifier.bias']
# - This IS expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of AlbertForSequenceClassification were not initialized from the model checkpoint at ai4bharat/indic-bert and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Training epoch: 1
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.2274540662765503
# Validation loss per 100 evaluation steps: 1.069845186011626
# DEV ACC: 0.5953202543424317
# DEV Precision: 0.35371979387057334
# DEV Recall: 0.32105151142818766
# DEV F1Score: 0.2982397478124217
# BEST ACCURACY -->  DEV: 0.59532
# BEST PRECISION -->  DEV: 0.35372
# BEST RECALL -->  DEV: 0.32105
# BEST F1SCORE -->  DEV: 0.29824
# TIME PER EPOCH: 26.901429597536723
#
# Training epoch: 2
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.0599579811096191
# Validation loss per 100 evaluation steps: 1.0620017783476574
# DEV ACC: 0.5985189205955336
# DEV Precision: 0.41093679736028205
# DEV Recall: 0.3930204585807906
# DEV F1Score: 0.36810616452164846
# BEST ACCURACY -->  DEV: 0.59852
# BEST PRECISION -->  DEV: 0.41094
# BEST RECALL -->  DEV: 0.39302
# BEST F1SCORE -->  DEV: 0.36811
# TIME PER EPOCH: 27.320377270380657
#
# Training epoch: 3
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.1508735418319702
# Validation loss per 100 evaluation steps: 1.0168490893769973
# DEV ACC: 0.6132521712158808
# DEV Precision: 0.4591244766722839
# DEV Recall: 0.42342030168724815
# DEV F1Score: 0.4084091076568696
# BEST ACCURACY -->  DEV: 0.61325
# BEST PRECISION -->  DEV: 0.45912
# BEST RECALL -->  DEV: 0.42342
# BEST F1SCORE -->  DEV: 0.40841
# TIME PER EPOCH: 26.376306863625846
#
# Training epoch: 4
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 0.9418866038322449
# Validation loss per 100 evaluation steps: 1.2267163714559952
# DEV ACC: 0.5689361042183623
# DEV Precision: 0.42059820526583164
# DEV Recall: 0.4088743658721507
# DEV F1Score: 0.39296545009152745
# BEST ACCURACY -->  DEV: 0.61697
# BEST PRECISION -->  DEV: 0.45912
# BEST RECALL -->  DEV: 0.44067
# BEST F1SCORE -->  DEV: 0.40841
# TIME PER EPOCH: 26.439333089192708
#
# Training epoch: 7
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.165780782699585
# Validation loss per 100 evaluation steps: 1.398127810789807
# DEV ACC: 0.5669781327543425
# DEV Precision: 0.42265994282657743
# DEV Recall: 0.4256219969464799
# DEV F1Score: 0.40259832908076065
# BEST ACCURACY -->  DEV: 0.61697
# BEST PRECISION -->  DEV: 0.45912
# BEST RECALL -->  DEV: 0.44067
# BEST F1SCORE -->  DEV: 0.40841
# TIME PER EPOCH: 27.042728507518767
#
# Training epoch: 8
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.6431477069854736
# Validation loss per 100 evaluation steps: 1.5558683500431552
# DEV ACC: 0.5696146091811414
# DEV Precision: 0.4247946921617539
# DEV Recall: 0.4099768160715673
# DEV F1Score: 0.39068431330657444
# BEST ACCURACY -->  DEV: 0.61697
# BEST PRECISION -->  DEV: 0.45912
# BEST RECALL -->  DEV: 0.44067
# BEST F1SCORE -->  DEV: 0.40841
# TIME PER EPOCH: 27.224638426303862
#
# Training epoch: 9
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.8957728147506714
# Validation loss per 100 evaluation steps: 1.7324736944519648
# DEV ACC: 0.5554241625310175
# DEV Precision: 0.4117320542391591
# DEV Recall: 0.4045670596656128
# DEV F1Score: 0.3873395256300141
# BEST ACCURACY -->  DEV: 0.61697
# BEST PRECISION -->  DEV: 0.45912
# BEST RECALL -->  DEV: 0.44067
# BEST F1SCORE -->  DEV: 0.40841
# TIME PER EPOCH: 26.67334551413854
#
# Training epoch: 10
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.6667227745056152
# Validation loss per 100 evaluation steps: 1.8969665812973928
# DEV ACC: 0.5458087779156328
# DEV Precision: 0.4122909212700312
# DEV Recall: 0.41513743958987637
# DEV F1Score: 0.39040385485345197
# BEST ACCURACY -->  DEV: 0.61697
# BEST PRECISION -->  DEV: 0.45912
# BEST RECALL -->  DEV: 0.44067
# BEST F1SCORE -->  DEV: 0.40841
# TIME PER EPOCH: 26.946424571673074
# Some weights of the model checkpoint at ai4bharat/indic-bert were not used when initializing AlbertForSequenceClassification: ['predictions.decoder.weight', 'predictions.bias', 'predictions.decoder.bias', 'predictions.LayerNorm.bias', 'predictions.LayerNorm.weight', 'sop_classifier.classifier.weight', 'predictions.dense.weight', 'predictions.dense.bias', 'sop_classifier.classifier.bias']
# - This IS expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of AlbertForSequenceClassification were not initialized from the model checkpoint at ai4bharat/indic-bert and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Training epoch: 1
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 0.976007342338562
# Validation loss per 100 evaluation steps: 1.0734440890869292
# DEV ACC: 0.5893687965260547
# DEV Precision: 0.37270986895599073
# DEV Recall: 0.3360400022458409
# DEV F1Score: 0.32437491703204147
# BEST ACCURACY -->  DEV: 0.58937
# BEST PRECISION -->  DEV: 0.37271
# BEST RECALL -->  DEV: 0.33604
# BEST F1SCORE -->  DEV: 0.32437
# TIME PER EPOCH: 26.14166746934255
#
# Training epoch: 2
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.0929038524627686
# Validation loss per 100 evaluation steps: 1.0375950902995497
# DEV ACC: 0.6092005272952854
# DEV Precision: 0.421842004367548
# DEV Recall: 0.4014000900610577
# DEV F1Score: 0.38013267460312805
# BEST ACCURACY -->  DEV: 0.6092
# BEST PRECISION -->  DEV: 0.42184
# BEST RECALL -->  DEV: 0.4014
# BEST F1SCORE -->  DEV: 0.38013
# TIME PER EPOCH: 26.916741426785787
#
# Training epoch: 3
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.352694034576416
# Validation loss per 100 evaluation steps: 1.014798086468536
# DEV ACC: 0.6257366625310175
# DEV Precision: 0.4656464006651307
# DEV Recall: 0.3881556218052006
# DEV F1Score: 0.38707940197892315
# BEST ACCURACY -->  DEV: 0.62574
# BEST PRECISION -->  DEV: 0.46565
# BEST RECALL -->  DEV: 0.4014
# BEST F1SCORE -->  DEV: 0.38708
# TIME PER EPOCH: 27.01670330365499
#
# Training epoch: 4
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.093914270401001
# Validation loss per 100 evaluation steps: 1.0020360220776927
# DEV ACC: 0.6234103598014888
# DEV Precision: 0.4849724941498583
# DEV Recall: 0.41476771552395797
# DEV F1Score: 0.410680074654421
# BEST ACCURACY -->  DEV: 0.62574
# BEST PRECISION -->  DEV: 0.48497
# BEST RECALL -->  DEV: 0.41477
# BEST F1SCORE -->  DEV: 0.41068
# TIME PER EPOCH: 26.482758605480193
#
# Training epoch: 5
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.0780391693115234
# Validation loss per 100 evaluation steps: 1.0666008143141719
# DEV ACC: 0.6116431451612904
# DEV Precision: 0.4666507346097096
# DEV Recall: 0.4355865140534827
# DEV F1Score: 0.4195161405964698
# BEST ACCURACY -->  DEV: 0.62574
# BEST PRECISION -->  DEV: 0.48497
# BEST RECALL -->  DEV: 0.43559
# BEST F1SCORE -->  DEV: 0.41952
# TIME PER EPOCH: 25.932984145482383
#
# Training epoch: 6
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 0.6778609156608582
# Validation loss per 100 evaluation steps: 1.0977257165578331
# DEV ACC: 0.5966578784119106
# DEV Precision: 0.4415539000884402
# DEV Recall: 0.43645862789225537
# DEV F1Score: 0.41417661959798807
# BEST ACCURACY -->  DEV: 0.62574
# BEST PRECISION -->  DEV: 0.48497
# BEST RECALL -->  DEV: 0.43646
# BEST F1SCORE -->  DEV: 0.41952
# TIME PER EPOCH: 27.338822603225708
#
# Training epoch: 7
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.4257242679595947
# Validation loss per 100 evaluation steps: 1.2356936087702761
# DEV ACC: 0.592935794044665
# DEV Precision: 0.43917005709126017
# DEV Recall: 0.4371781321875999
# DEV F1Score: 0.41231748049206707
# BEST ACCURACY -->  DEV: 0.62574
# BEST PRECISION -->  DEV: 0.48497
# BEST RECALL -->  DEV: 0.43718
# BEST F1SCORE -->  DEV: 0.41952
# TIME PER EPOCH: 26.309422405560813
#
# Training epoch: 8
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 2.124570369720459
# Validation loss per 100 evaluation steps: 1.4417078471419835
# DEV ACC: 0.5768067617866005
# DEV Precision: 0.412703907662177
# DEV Recall: 0.40951523542778034
# DEV F1Score: 0.3888020122406328
# BEST ACCURACY -->  DEV: 0.62574
# BEST PRECISION -->  DEV: 0.48497
# BEST RECALL -->  DEV: 0.43718
# BEST F1SCORE -->  DEV: 0.41952
# TIME PER EPOCH: 27.00325038830439
#
# Training epoch: 9
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.6554441452026367
# Validation loss per 100 evaluation steps: 1.579009189464078
# DEV ACC: 0.5840376861042184
# DEV Precision: 0.42845286289993256
# DEV Recall: 0.41480116166922926
# DEV F1Score: 0.40049007748993165
# BEST ACCURACY -->  DEV: 0.62574
# BEST PRECISION -->  DEV: 0.48497
# BEST RECALL -->  DEV: 0.43718
# BEST F1SCORE -->  DEV: 0.41952
# TIME PER EPOCH: 26.336726184686025
#
# Training epoch: 10
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.7828041315078735
# Validation loss per 100 evaluation steps: 1.7672603620160925
# DEV ACC: 0.5712430210918114
# DEV Precision: 0.4290078252287576
# DEV Recall: 0.41210902254007886
# DEV F1Score: 0.39980677953128174
# BEST ACCURACY -->  DEV: 0.62574
# BEST PRECISION -->  DEV: 0.48497
# BEST RECALL -->  DEV: 0.43718
# BEST F1SCORE -->  DEV: 0.41952
# TIME PER EPOCH: 26.476569553216297
# Some weights of the model checkpoint at ai4bharat/indic-bert were not used when initializing AlbertForSequenceClassification: ['predictions.decoder.weight', 'predictions.bias', 'predictions.decoder.bias', 'predictions.LayerNorm.bias', 'predictions.LayerNorm.weight', 'sop_classifier.classifier.weight', 'predictions.dense.weight', 'predictions.dense.bias', 'sop_classifier.classifier.bias']
# - This IS expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of AlbertForSequenceClassification were not initialized from the model checkpoint at ai4bharat/indic-bert and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Training epoch: 1
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 0.8882874846458435
# Validation loss per 100 evaluation steps: 1.0823675647820576
# DEV ACC: 0.5898340570719603
# DEV Precision: 0.3923143402543396
# DEV Recall: 0.3495257934591903
# DEV F1Score: 0.3329104165542503
# BEST ACCURACY -->  DEV: 0.58983
# BEST PRECISION -->  DEV: 0.39231
# BEST RECALL -->  DEV: 0.34953
# BEST F1SCORE -->  DEV: 0.33291
# TIME PER EPOCH: 26.324597255388895
#
# Training epoch: 2
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.1479134559631348
# Validation loss per 100 evaluation steps: 1.073597542720266
# DEV ACC: 0.5718827543424317
# DEV Precision: 0.4149174557086493
# DEV Recall: 0.4447202385857609
# DEV F1Score: 0.4016638182192444
# BEST ACCURACY -->  DEV: 0.58983
# BEST PRECISION -->  DEV: 0.41492
# BEST RECALL -->  DEV: 0.44472
# BEST F1SCORE -->  DEV: 0.40166
# TIME PER EPOCH: 27.010514354705812
#
# Training epoch: 3
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.1521048545837402
# Validation loss per 100 evaluation steps: 1.0130696278987545
# DEV ACC: 0.6099178039702233
# DEV Precision: 0.4269380491415747
# DEV Recall: 0.4287259085113381
# DEV F1Score: 0.40597637003087
# BEST ACCURACY -->  DEV: 0.60992
# BEST PRECISION -->  DEV: 0.42694
# BEST RECALL -->  DEV: 0.44472
# BEST F1SCORE -->  DEV: 0.40598
# TIME PER EPOCH: 26.54636551539103
#
# Training epoch: 4
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# ...
# DEV Recall: 0.304911021084961
# DEV F1Score: 0.27793752805979266
# BEST ACCURACY -->  DEV: 0.58538
# BEST PRECISION -->  DEV: 0.32048
# BEST RECALL -->  DEV: 0.30491
# BEST F1SCORE -->  DEV: 0.27794
# TIME PER EPOCH: 26.76659914255142
#
# Training epoch: 2
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.0096395015716553
# Validation loss per 100 evaluation steps: 1.0397446751594543
# DEV ACC: 0.6062151054590571
# DEV Precision: 0.4553362577659674
# DEV Recall: 0.43070066739523166
# DEV F1Score: 0.40391995822014554
# BEST ACCURACY -->  DEV: 0.60622
# BEST PRECISION -->  DEV: 0.45534
# BEST RECALL -->  DEV: 0.4307
# BEST F1SCORE -->  DEV: 0.40392
# TIME PER EPOCH: 26.827183655897777
#
# Training epoch: 3
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.062550663948059
# Validation loss per 100 evaluation steps: 1.034092622228188
# DEV ACC: 0.6044509925558313
# DEV Precision: 0.4331387650413809
# DEV Recall: 0.4354626658489961
# DEV F1Score: 0.40669509912291424
# BEST ACCURACY -->  DEV: 0.60622
# BEST PRECISION -->  DEV: 0.45534
# BEST RECALL -->  DEV: 0.43546
# BEST F1SCORE -->  DEV: 0.4067
# TIME PER EPOCH: 26.752520044644672
#
# Training epoch: 4
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.1518256664276123
# Validation loss per 100 evaluation steps: 1.0489716429521543
# DEV ACC: 0.6129613833746897
# DEV Precision: 0.475965794186423
# DEV Recall: 0.46538278030770774
# DEV F1Score: 0.43956932746403987
# BEST ACCURACY -->  DEV: 0.61296
# BEST PRECISION -->  DEV: 0.47597
# BEST RECALL -->  DEV: 0.46538
# BEST F1SCORE -->  DEV: 0.43957
# TIME PER EPOCH: 27.428726283709207
#
# Training epoch: 5
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.2544143199920654
# Validation loss per 100 evaluation steps: 1.0835115272219817
# DEV ACC: 0.5966191066997518
# DEV Precision: 0.4301133181197129
# DEV Recall: 0.41805332252805705
# DEV F1Score: 0.39979355144869083
# BEST ACCURACY -->  DEV: 0.61296
# BEST PRECISION -->  DEV: 0.47597
# BEST RECALL -->  DEV: 0.46538
# BEST F1SCORE -->  DEV: 0.43957
# TIME PER EPOCH: 26.695114354292553
#
# Training epoch: 6
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.2732844352722168
# Validation loss per 100 evaluation steps: 1.1833160177315816
# DEV ACC: 0.6135623449131514
# DEV Precision: 0.45131612255069264
# DEV Recall: 0.4097561108678868
# DEV F1Score: 0.39994818134707155
# BEST ACCURACY -->  DEV: 0.61356
# BEST PRECISION -->  DEV: 0.47597
# BEST RECALL -->  DEV: 0.46538
# BEST F1SCORE -->  DEV: 0.43957
# TIME PER EPOCH: 26.309284989039103
#
# Training epoch: 7
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 0.9504672884941101
# Validation loss per 100 evaluation steps: 1.2172697139258433
# DEV ACC: 0.5836693548387096
# DEV Precision: 0.4380517924904071
# DEV Recall: 0.43175867525007944
# DEV F1Score: 0.4144714164011313
# BEST ACCURACY -->  DEV: 0.61356
# BEST PRECISION -->  DEV: 0.47597
# BEST RECALL -->  DEV: 0.46538
# BEST F1SCORE -->  DEV: 0.43957
# TIME PER EPOCH: 26.45155560572942
#
# Training epoch: 8
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 2.0010688304901123
# Validation loss per 100 evaluation steps: 1.378863262658072
# DEV ACC: 0.5914236972704715
# DEV Precision: 0.4497730190443589
# DEV Recall: 0.42835324446319356
# DEV F1Score: 0.41537644113915423
# BEST ACCURACY -->  DEV: 0.61356
# BEST PRECISION -->  DEV: 0.47597
# BEST RECALL -->  DEV: 0.46538
# BEST F1SCORE -->  DEV: 0.43957
# TIME PER EPOCH: 27.12925428946813
#
# Training epoch: 9
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218

# %%
print(best_dev_acc)

# %%
print(best_epoch)

# %%
print(best_dev_precision)

# %%
print(best_dev_recall)

# %%
print(best_dev_f1score)

# %%
print(overall_list_dev_acc)

# %%
print(overall_list_dev_precision)

# %%
print(overall_list_dev_recall)

# %%
print(overall_list_dev_f1score)

# %%
#The best model is
