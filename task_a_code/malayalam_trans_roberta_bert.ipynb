# %%
import pandas as pd
import numpy as np
import torch
from torch import cuda
from torch.utils.data import Dataset, DataLoader
from transformers import pipeline
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from sklearn.metrics import accuracy_score, classification_report, precision_score, recall_score, f1_score
from load_data import initialize_data
from reading_datasets import read_task
from labels_to_ids import labels_to_ids_mal
import time
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
def train(epoch, train_loader, model, optimizer, device, grad_step = 1, max_grad_norm = 10):
    tr_loss, tr_accuracy = 0, 0
    tr_precision, tr_recall = 0, 0
    tr_f1score = 0
    nb_tr_examples, nb_tr_steps = 0, 0
    tr_preds, tr_labels = [], []
    # put model in training mode
    model.train()
    optimizer.zero_grad()
    
    for idx, batch in enumerate(train_loader):
        ids = batch['input_ids'].to(device, dtype = torch.long)
        mask = batch['attention_mask'].to(device, dtype = torch.long)
        labels = batch['labels'].to(device, dtype = torch.long)

        if (idx + 1) % 20 == 0:
            print('FINSIHED BATCH:', idx, 'of', len(train_loader))

        #loss, tr_logits = model(input_ids=ids, attention_mask=mask, labels=labels)
        output = model(input_ids=ids, attention_mask=mask, labels=labels)
        tr_loss += output[0]

        nb_tr_steps += 1
        nb_tr_examples += labels.size(0)
           
        # compute training accuracy
        flattened_targets = labels.view(-1) # shape (batch_size * seq_len,)
        active_logits = output[1].view(-1, model.num_labels) # shape (batch_size * seq_len, num_labels)
        flattened_predictions = torch.argmax(active_logits, axis=1) # shape (batch_size * seq_len,)
        
        # only compute accuracy at active labels
        active_accuracy = labels.view(-1) != -100 # shape (batch_size, seq_len)
        #active_labels = torch.where(active_accuracy, labels.view(-1), torch.tensor(-100).type_as(labels))
        
        labels = torch.masked_select(flattened_targets, active_accuracy)
        predictions = torch.masked_select(flattened_predictions, active_accuracy)

        tr_labels.extend(labels)
        tr_preds.extend(predictions)

        tmp_tr_accuracy = accuracy_score(labels.cpu().numpy(), predictions.cpu().numpy())
        tr_accuracy += tmp_tr_accuracy
        
        # Compute Precision
        tmp_tr_precision = precision_score(labels.cpu().numpy(), predictions.cpu().numpy(), average = 'macro', zero_division=0 )
        tr_precision += tmp_tr_precision
        
        # Compute Recall
        tmp_tr_recall = recall_score(labels.cpu().numpy(), predictions.cpu().numpy(), average = 'macro', zero_division=0)
        tr_recall += tmp_tr_recall
        
        # Compute f1score
        tmp_tr_f1score = f1_score(labels.cpu().numpy(), predictions.cpu().numpy(), average= 'macro', zero_division=0)
        tr_f1score += tmp_tr_f1score
    
        # gradient clipping
        torch.nn.utils.clip_grad_norm_(
            parameters=model.parameters(), max_norm=max_grad_norm
        )
        
        # backward pass
        output['loss'].backward()
        if (idx + 1) % grad_step == 0:
            optimizer.step()
            optimizer.zero_grad()

    epoch_loss = tr_loss / nb_tr_steps
    tr_accuracy = tr_accuracy / nb_tr_steps
    tr_precision = tr_precision / nb_tr_steps
    tr_recall = tr_recall / nb_tr_steps
    tr_f1score= tr_f1score / nb_tr_steps
    #print(f"Training loss epoch: {epoch_loss}")
    #print(f"Training accuracy epoch: {tr_accuracy}")

    return model

# %%
def testing(model, testing_loader, labels_to_ids, device):
    # put model in evaluation mode
    model.eval()
    
    eval_loss, eval_accuracy = 0, 0
    eval_precision, eval_recall = 0, 0
    eval_f1score = 0
    nb_eval_examples, nb_eval_steps = 0, 0
    eval_preds, eval_labels = [], []
     
    
    ids_to_labels = dict((v,k) for k,v in labels_to_ids.items())

    with torch.no_grad():
        for idx, batch in enumerate(testing_loader):
            
            ids = batch['input_ids'].to(device, dtype = torch.long)
            mask = batch['attention_mask'].to(device, dtype = torch.long)
            labels = batch['labels'].to(device, dtype = torch.long)
            
            #loss, eval_logits = model(input_ids=ids, attention_mask=mask, labels=labels)
            output = model(input_ids=ids, attention_mask=mask, labels=labels)

            eval_loss += output['loss'].item()

            nb_eval_steps += 1
            nb_eval_examples += labels.size(0)
        
            if idx % 100==0:
                loss_step = eval_loss/nb_eval_steps
                print(f"Validation loss per 100 evaluation steps: {loss_step}")
              
            # compute evaluation accuracy
            flattened_targets = labels.view(-1) # shape (batch_size * seq_len,)
            active_logits = output[1].view(-1, model.num_labels) # shape (batch_size * seq_len, num_labels)
            flattened_predictions = torch.argmax(active_logits, axis=1) # shape (batch_size * seq_len,)
            
            # only compute accuracy at active labels
            active_accuracy = labels.view(-1) != -100 # shape (batch_size, seq_len)
        
            labels = torch.masked_select(flattened_targets, active_accuracy)
            predictions = torch.masked_select(flattened_predictions, active_accuracy)
            
            eval_labels.extend(labels)
            eval_preds.extend(predictions)
            
            tmp_eval_accuracy = accuracy_score(labels.cpu().numpy(), predictions.cpu().numpy())
            eval_accuracy += tmp_eval_accuracy
            
            # Compute Precision
            tmp_eval_precision = precision_score(labels.cpu().numpy(), predictions.cpu().numpy(), average = 'macro', zero_division=0)
            eval_precision += tmp_eval_precision
            
            # Compute Recall
            tmp_eval_recall = recall_score(labels.cpu().numpy(), predictions.cpu().numpy(), average = 'macro', zero_division=0)
            eval_recall += tmp_eval_recall
            
            # Compute f1score
            tmp_eval_f1score = f1_score(labels.cpu().numpy(), predictions.cpu().numpy(), average='macro', zero_division=0)
            eval_f1score += tmp_eval_f1score

    labels = [ids_to_labels[id.item()] for id in eval_labels]
    predictions = [ids_to_labels[id.item()] for id in eval_preds]
    
    eval_loss = eval_loss / nb_eval_steps
    eval_accuracy = eval_accuracy / nb_eval_steps
    eval_precision = eval_precision / nb_eval_steps
    eval_recall = eval_recall / nb_eval_steps
    eval_f1score = eval_f1score / nb_eval_steps
    #print(f"Validation Loss: {eval_loss}")
    #print(f"Validation Accuracy: {eval_accuracy}")

    return labels, predictions, eval_accuracy, eval_precision, eval_recall, eval_f1score

# %%
def main(n_epochs, model_name, model_save_flag, model_save_location, model_load_flag, model_load_location):
    #Initialization training parameters
    max_len = 256
    batch_size = 32
    grad_step = 1
    learning_rate = 1e-05
    initialization_input = (max_len, batch_size)

    #Reading datasets and initializing data loaders
    dataset_location = '../datasets/task_a/transliterated/'

    train_data = read_task(dataset_location , split = 'mal_train_trans')
    dev_data = read_task(dataset_location , split = 'mal_dev_trans')
    #test_data = read_task(dataset_location , split = 'dev')#load test set
    labels_to_ids = labels_to_ids_mal
    #input_data = (train_data, dev_data, labels_to_ids)

    #Define tokenizer, model and optimizer
    device = 'cuda' if cuda.is_available() else 'cpu' #save the processing time
    if model_load_flag:
        tokenizer = AutoTokenizer.from_pretrained(model_load_location)
        model = AutoModelForSequenceClassification.from_pretrained(model_load_location)
    else: 
        tokenizer =  AutoTokenizer.from_pretrained(model_name, add_prefix_space=True)
        model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=len(labels_to_ids))
    optimizer = torch.optim.Adam(params=model.parameters(), lr=learning_rate)
    model.to(device)

    #Get dataloaders
    train_loader = initialize_data(tokenizer, initialization_input, train_data, labels_to_ids, shuffle = True)
    dev_loader = initialize_data(tokenizer, initialization_input, dev_data, labels_to_ids, shuffle = True)
    #test_loader = initialize_data(tokenizer, initialization_input, test_data, labels_to_ids, shuffle = True)#create test loader

    best_dev_acc = 0
    best_test_acc = 0
    best_dev_precision = 0
    best_test_precision = 0
    best_dev_recall = 0
    best_test_recall = 0
    best_dev_f1score = 0
    best_test_f1score = 0
    best_epoch = -1
    
    list_dev_acc = [] 
    list_test_acc = []  
    list_dev_precision = []  
    list_test_precision  = []  
    list_dev_recall = []  
    list_test_recall = []  
    list_dev_f1score = []  
    list_test_f1score = []
    
    for epoch in range(n_epochs):
        start = time.time()
        print(f"Training epoch: {epoch + 1}")

        #train model
        if not model_load_flag:
            model = train(epoch, train_loader, model, optimizer, device, grad_step)
        
        #testing and logging
        labels_dev, predictions_dev, dev_accuracy, dev_precision, dev_recall, dev_f1score = testing(model, dev_loader, labels_to_ids, device)
        print('DEV ACC:', dev_accuracy)
        print('DEV Precision:' , dev_precision)
        print('DEV Recall:' , dev_recall)
        print('DEV F1Score:' , dev_f1score)
        
        list_dev_acc.append(dev_accuracy)     
        list_dev_precision.append(dev_precision)   
        list_dev_recall.append(dev_recall)  
        list_dev_f1score.append(dev_f1score)  
        
        
        #labels_test, predictions_test, test_accuracy, test_precision, test_recall, test_f1score = testing(model, test_loader, labels_to_ids, device)
        #print('TEST ACC:', test_accuracy)
        #print('TEST Precision:' , test_precision)
        #print('TEST Recall:' , test_recall)
        #print('TEST F1Score:' , test_f1score)
        
        #list_test_acc.append(test_accuracy) 
        #list_test_precision.append(test_precision)  
        #list_test_recall.append(test_recall)
        #list_test_f1score.append(test_f1score) 

        #saving model
        if dev_accuracy > best_dev_acc:
            best_dev_acc = dev_accuracy
            #best_test_acc = test_accuracy
        if dev_precision > best_dev_precision:
            best_dev_precision = dev_precision
            #best_test_precision = test_precision
        if dev_recall > best_dev_recall:
            best_dev_recall = dev_recall
            #best_test_recall = test_recall
        if dev_f1score > best_dev_f1score:
            best_dev_f1score = dev_f1score
            #best_test_f1score = test_f1score
            best_epoch = epoch
            
            if model_save_flag:
                os.makedirs(model_save_location, exist_ok=True)
                tokenizer.save_pretrained(model_save_location)
                model.save_pretrained(model_save_location)

        now = time.time()
        print('BEST ACCURACY --> ', 'DEV:', round(best_dev_acc, 5))
        print('BEST PRECISION --> ', 'DEV:', round(best_dev_precision, 5))
        print('BEST RECALL --> ', 'DEV:', round(best_dev_recall, 5))
        print('BEST F1SCORE --> ', 'DEV:', round(best_dev_f1score, 5))
        print('TIME PER EPOCH:', (now-start)/60 )
        print()

    return best_dev_acc, best_test_acc, best_epoch, best_dev_precision, best_test_precision, best_dev_recall, best_test_recall, best_dev_f1score, best_test_f1score, list_dev_acc, list_test_acc, list_dev_precision, list_test_precision, list_dev_recall, list_test_recall, list_dev_f1score, list_test_f1score

# %%
if __name__ == '__main__':
    n_epochs = 10
    models = ['xlm-roberta-base']
    
    #model saving parameters
    model_save_flag = True
    model_load_flag = False
    
    overall_list_dev_acc = [] 
    overall_list_test_acc = []    
    overall_list_dev_precision = []  
    overall_list_test_precision  = []  
    overall_list_dev_recall = []  
    overall_list_test_recall = []  
    overall_list_dev_f1score = []  
    overall_list_test_f1score = [] 
    
    for i in range(5):
        
        for model_name in models:

            model_save_location = 'saved_models/' + model_name + 'Malayalam' + 'transliterated' + str(i)
            model_load_location = None

            best_dev_acc, best_test_acc, best_epoch, best_dev_precision, best_test_precision, best_dev_recall, best_test_recall, best_dev_f1score, best_test_f1score, list_dev_acc, list_test_acc, list_dev_precision, list_test_precision, list_dev_recall, list_test_recall, list_dev_f1score, list_test_f1score = main(n_epochs, model_name, model_save_flag, model_save_location, model_load_flag, model_load_location)
            
            overall_list_dev_acc.append(list_dev_acc) 
            overall_list_test_acc.append(list_test_acc) 
            overall_list_dev_precision.append(list_dev_precision)  
            overall_list_test_precision.append(list_test_precision) 
            overall_list_dev_recall.append(list_dev_recall)  
            overall_list_test_recall.append(list_test_recall)  
            overall_list_dev_f1score.append(list_dev_f1score)  
            overall_list_test_f1score.append(list_test_f1score)
# Out:
# Some weights of the model checkpoint at xlm-roberta-base were not used when initializing XLMRobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'roberta.pooler.dense.bias', 'lm_head.dense.bias']
# - This IS expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['classifier.out_proj.bias', 'classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Training epoch: 1
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.7248393297195435
# DEV ACC: 0.5602678571428571
# DEV Precision: 0.423917595208918
# DEV Recall: 0.42837569962348804
# DEV F1Score: 0.3921767143227927
# BEST ACCURACY -->  DEV: 0.56027
# BEST PRECISION -->  DEV: 0.42392
# BEST RECALL -->  DEV: 0.42838
# BEST F1SCORE -->  DEV: 0.39218
# TIME PER EPOCH: 12.305933757623036
#
# Training epoch: 2
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 1.0923364162445068
# DEV ACC: 0.6711309523809524
# DEV Precision: 0.537318718720926
# DEV Recall: 0.5497722758438426
# DEV F1Score: 0.5183037645379232
# BEST ACCURACY -->  DEV: 0.67113
# BEST PRECISION -->  DEV: 0.53732
# BEST RECALL -->  DEV: 0.54977
# BEST F1SCORE -->  DEV: 0.5183
# TIME PER EPOCH: 12.466048467159272
#
# Training epoch: 3
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.8272401094436646
# DEV ACC: 0.6787574404761905
# DEV Precision: 0.5566165362139212
# DEV Recall: 0.5985684236544266
# DEV F1Score: 0.5611584083149738
# BEST ACCURACY -->  DEV: 0.67876
# BEST PRECISION -->  DEV: 0.55662
# BEST RECALL -->  DEV: 0.59857
# BEST F1SCORE -->  DEV: 0.56116
# TIME PER EPOCH: 12.458889985084534
#
# Training epoch: 4
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.6169248223304749
# DEV ACC: 0.7003348214285714
# DEV Precision: 0.6109689178701784
# DEV Recall: 0.6264520374729144
# DEV F1Score: 0.603868970060242
# BEST ACCURACY -->  DEV: 0.70033
# BEST PRECISION -->  DEV: 0.61097
# BEST RECALL -->  DEV: 0.62645
# BEST F1SCORE -->  DEV: 0.60387
# TIME PER EPOCH: 12.483368706703185
#
# Training epoch: 5
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.7041141986846924
# DEV ACC: 0.7036830357142857
# DEV Precision: 0.6033791895983336
# DEV Recall: 0.6173566542001415
# DEV F1Score: 0.5908997621961518
# BEST ACCURACY -->  DEV: 0.70368
# BEST PRECISION -->  DEV: 0.61097
# BEST RECALL -->  DEV: 0.62645
# BEST F1SCORE -->  DEV: 0.60387
# TIME PER EPOCH: 12.400057864189147
#
# Training epoch: 6
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.7548773288726807
# DEV ACC: 0.7075892857142857
# DEV Precision: 0.6541192973631608
# DEV Recall: 0.6325938324047568
# DEV F1Score: 0.6150544441225979
# BEST ACCURACY -->  DEV: 0.70759
# BEST PRECISION -->  DEV: 0.65412
# BEST RECALL -->  DEV: 0.63259
# BEST F1SCORE -->  DEV: 0.61505
# TIME PER EPOCH: 12.468369996547699
#
# Training epoch: 7
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 1.3217729330062866
# DEV ACC: 0.712797619047619
# DEV Precision: 0.6473338724943725
# DEV Recall: 0.5962074819039381
# DEV F1Score: 0.592575380097978
# BEST ACCURACY -->  DEV: 0.7128
# BEST PRECISION -->  DEV: 0.65412
# BEST RECALL -->  DEV: 0.63259
# BEST F1SCORE -->  DEV: 0.61505
# TIME PER EPOCH: 12.400982733567556
#
# Training epoch: 8
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.6187940835952759
# DEV ACC: 0.7122395833333333
# DEV Precision: 0.6510084269913644
# DEV Recall: 0.6343243369608915
# DEV F1Score: 0.6196197512531738
# BEST ACCURACY -->  DEV: 0.7128
# BEST PRECISION -->  DEV: 0.65412
# BEST RECALL -->  DEV: 0.63432
# BEST F1SCORE -->  DEV: 0.61962
# TIME PER EPOCH: 12.398965887228648
#
# Training epoch: 9
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.7215909957885742
# DEV ACC: 0.7180059523809524
# DEV Precision: 0.6458050223908111
# DEV Recall: 0.6408296759846129
# DEV F1Score: 0.6225165615346369
# BEST ACCURACY -->  DEV: 0.71801
# BEST PRECISION -->  DEV: 0.65412
# BEST RECALL -->  DEV: 0.64083
# BEST F1SCORE -->  DEV: 0.62252
# TIME PER EPOCH: 12.463839948177338
#
# Training epoch: 10
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.59229975938797
# DEV ACC: 0.6975446428571429
# DEV Precision: 0.6324273489990403
# DEV Recall: 0.6560435226683914
# DEV F1Score: 0.617849059712519
# BEST ACCURACY -->  DEV: 0.71801
# BEST PRECISION -->  DEV: 0.65412
# BEST RECALL -->  DEV: 0.65604
# BEST F1SCORE -->  DEV: 0.62252
# TIME PER EPOCH: 12.402013989289602
# Some weights of the model checkpoint at xlm-roberta-base were not used when initializing XLMRobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'roberta.pooler.dense.bias', 'lm_head.dense.bias']
# - This IS expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['classifier.out_proj.bias', 'classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Training epoch: 1
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 1.0144116878509521
# DEV ACC: 0.5892857142857143
# DEV Precision: 0.37170599409252114
# DEV Recall: 0.4516824787898842
# DEV F1Score: 0.3942743039412897
# BEST ACCURACY -->  DEV: 0.58929
# BEST PRECISION -->  DEV: 0.37171
# BEST RECALL -->  DEV: 0.45168
# BEST F1SCORE -->  DEV: 0.39427
# TIME PER EPOCH: 12.454740965366364
#
# Training epoch: 2
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.9616944193840027
# DEV ACC: 0.6276041666666667
# DEV Precision: 0.4991877773836807
# DEV Recall: 0.5746324335616959
# DEV F1Score: 0.5094086441532287
# BEST ACCURACY -->  DEV: 0.6276
# BEST PRECISION -->  DEV: 0.49919
# BEST RECALL -->  DEV: 0.57463
# BEST F1SCORE -->  DEV: 0.50941
# TIME PER EPOCH: 12.469581476847331
#
# Training epoch: 3
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.8681248426437378
# DEV ACC: 0.6850818452380952
# DEV Precision: 0.5972349879687197
# DEV Recall: 0.5572140595441957
# DEV F1Score: 0.5488014466920653
# BEST ACCURACY -->  DEV: 0.68508
# BEST PRECISION -->  DEV: 0.59723
# BEST RECALL -->  DEV: 0.57463
# BEST F1SCORE -->  DEV: 0.5488
# TIME PER EPOCH: 12.448808070023855
#
# Training epoch: 4
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 1.2907371520996094
# DEV ACC: 0.6943824404761905
# DEV Precision: 0.6108218750019944
# DEV Recall: 0.5927275079765683
# DEV F1Score: 0.579845857535442
# BEST ACCURACY -->  DEV: 0.69438
# BEST PRECISION -->  DEV: 0.61082
# BEST RECALL -->  DEV: 0.59273
# BEST F1SCORE -->  DEV: 0.57985
# TIME PER EPOCH: 12.459079960982004
#
# Training epoch: 5
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.9066285490989685
# DEV ACC: 0.7157738095238095
# DEV Precision: 0.6508529634141332
# DEV Recall: 0.6267614482418843
# DEV F1Score: 0.6128457720685444
# BEST ACCURACY -->  DEV: 0.71577
# BEST PRECISION -->  DEV: 0.65085
# BEST RECALL -->  DEV: 0.62676
# BEST F1SCORE -->  DEV: 0.61285
# TIME PER EPOCH: 12.561721762021383
#
# Training epoch: 6
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.9538130760192871
# DEV ACC: 0.7146577380952381
# DEV Precision: 0.6396597712626642
# DEV Recall: 0.6208196314656399
# DEV F1Score: 0.6091357676817312
# BEST ACCURACY -->  DEV: 0.71577
# BEST PRECISION -->  DEV: 0.65085
# BEST RECALL -->  DEV: 0.62676
# BEST F1SCORE -->  DEV: 0.61285
# TIME PER EPOCH: 12.427496472994486
#
# Training epoch: 7
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.35867640376091003
# DEV ACC: 0.7202380952380952
# DEV Precision: 0.6685742718906972
# DEV Recall: 0.6387134167478179
# DEV F1Score: 0.6303482252717558
# BEST ACCURACY -->  DEV: 0.72024
# BEST PRECISION -->  DEV: 0.66857
# BEST RECALL -->  DEV: 0.63871
# BEST F1SCORE -->  DEV: 0.63035
# TIME PER EPOCH: 12.431704020500183
#
# Training epoch: 8
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.8354945182800293
# DEV ACC: 0.7239583333333333
# DEV Precision: 0.6729838671525271
# DEV Recall: 0.6383652448642013
# DEV F1Score: 0.6302327549245658
# BEST ACCURACY -->  DEV: 0.72396
# BEST PRECISION -->  DEV: 0.67298
# BEST RECALL -->  DEV: 0.63871
# BEST F1SCORE -->  DEV: 0.63035
# TIME PER EPOCH: 12.400013109048208
#
# Training epoch: 9
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.6803674697875977
# DEV ACC: 0.7222842261904762
# DEV Precision: 0.6722086649051002
# DEV Recall: 0.6571338998886267
# DEV F1Score: 0.6443531147748602
# BEST ACCURACY -->  DEV: 0.72396
# BEST PRECISION -->  DEV: 0.67298
# BEST RECALL -->  DEV: 0.65713
# BEST F1SCORE -->  DEV: 0.64435
# TIME PER EPOCH: 12.41747746070226
#
# Training epoch: 10
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.321567177772522
# DEV ACC: 0.7241443452380952
# DEV Precision: 0.6545781272882113
# DEV Recall: 0.655148716246405
# DEV F1Score: 0.6327513175464891
# BEST ACCURACY -->  DEV: 0.72414
# BEST PRECISION -->  DEV: 0.67298
# BEST RECALL -->  DEV: 0.65713
# BEST F1SCORE -->  DEV: 0.64435
# TIME PER EPOCH: 12.390643413861593
# Some weights of the model checkpoint at xlm-roberta-base were not used when initializing XLMRobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'roberta.pooler.dense.bias', 'lm_head.dense.bias']
# - This IS expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['classifier.out_proj.bias', 'classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Training epoch: 1
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 1.0610289573669434
# DEV ACC: 0.5872395833333333
# DEV Precision: 0.38842541751549114
# DEV Recall: 0.4525252502086592
# DEV F1Score: 0.4023896624540371
# BEST ACCURACY -->  DEV: 0.58724
# BEST PRECISION -->  DEV: 0.38843
# BEST RECALL -->  DEV: 0.45253
# BEST F1SCORE -->  DEV: 0.40239
# TIME PER EPOCH: 12.40911873181661
#
# Training epoch: 2
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 1.1632468700408936
# DEV ACC: 0.6568080357142857
# DEV Precision: 0.5284843203092178
# DEV Recall: 0.5379968647071146
# DEV F1Score: 0.5138364711306104
# BEST ACCURACY -->  DEV: 0.65681
# BEST PRECISION -->  DEV: 0.52848
# BEST RECALL -->  DEV: 0.538
# BEST F1SCORE -->  DEV: 0.51384
# TIME PER EPOCH: 12.511444103717803
#
# Training epoch: 3
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.896496593952179
# DEV ACC: 0.6923363095238095
# DEV Precision: 0.591749637903407
# DEV Recall: 0.5924198293099293
# DEV F1Score: 0.5654180624733283
# BEST ACCURACY -->  DEV: 0.69234
# BEST PRECISION -->  DEV: 0.59175
# BEST RECALL -->  DEV: 0.59242
# BEST F1SCORE -->  DEV: 0.56542
# TIME PER EPOCH: 12.463562305768331
#
# Training epoch: 4
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.7261710166931152
# DEV ACC: 0.6899181547619048
# DEV Precision: 0.5937699088959594
# DEV Recall: 0.6018509744024589
# DEV F1Score: 0.5792416936438621
# BEST ACCURACY -->  DEV: 0.69234
# BEST PRECISION -->  DEV: 0.59377
# BEST RECALL -->  DEV: 0.60185
# BEST F1SCORE -->  DEV: 0.57924
# TIME PER EPOCH: 12.457262591520946
#
# Training epoch: 5
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.9113214612007141
# DEV ACC: 0.6867559523809524
# DEV Precision: 0.6140315266709598
# DEV Recall: 0.6325617028571334
# DEV F1Score: 0.5972089383165257
# BEST ACCURACY -->  DEV: 0.69234
# BEST PRECISION -->  DEV: 0.61403
# BEST RECALL -->  DEV: 0.63256
# BEST F1SCORE -->  DEV: 0.59721
# TIME PER EPOCH: 12.483612442016602
#
# Training epoch: 6
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 1.085932731628418
# DEV ACC: 0.7235863095238095
# DEV Precision: 0.641104758290876
# DEV Recall: 0.6040460326260303
# DEV F1Score: 0.6014151397896893
# BEST ACCURACY -->  DEV: 0.72359
# BEST PRECISION -->  DEV: 0.6411
# BEST RECALL -->  DEV: 0.63256
# BEST F1SCORE -->  DEV: 0.60142
# TIME PER EPOCH: 12.533224300543468
#
# Training epoch: 7
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 1.2659049034118652
# DEV ACC: 0.6994047619047619
# DEV Precision: 0.6418931659202143
# DEV Recall: 0.636613650045345
# DEV F1Score: 0.6172924239350396
# BEST ACCURACY -->  DEV: 0.72359
# BEST PRECISION -->  DEV: 0.64189
# BEST RECALL -->  DEV: 0.63661
# BEST F1SCORE -->  DEV: 0.61729
# TIME PER EPOCH: 12.54783835808436
#
# Training epoch: 8
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.9841558337211609
# DEV ACC: 0.7248883928571429
# DEV Precision: 0.6384328496458087
# DEV Recall: 0.6266704645183127
# DEV F1Score: 0.6147462683916957
# BEST ACCURACY -->  DEV: 0.72489
# BEST PRECISION -->  DEV: 0.64189
# BEST RECALL -->  DEV: 0.63661
# BEST F1SCORE -->  DEV: 0.61729
# TIME PER EPOCH: 12.368226901690166
#
# Training epoch: 9
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.7556811571121216
# DEV ACC: 0.71875
# DEV Precision: 0.6442762969613989
# DEV Recall: 0.6318611286297735
# DEV F1Score: 0.6173743845874636
# BEST ACCURACY -->  DEV: 0.72489
# BEST PRECISION -->  DEV: 0.64428
# BEST RECALL -->  DEV: 0.63661
# BEST F1SCORE -->  DEV: 0.61737
# TIME PER EPOCH: 12.414079181353252
#
# Training epoch: 10
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 1.1116539239883423
# DEV ACC: 0.7131696428571429
# DEV Precision: 0.6509904666995003
# DEV Recall: 0.6377285313892456
# DEV F1Score: 0.6275725460616127
# BEST ACCURACY -->  DEV: 0.72489
# BEST PRECISION -->  DEV: 0.65099
# BEST RECALL -->  DEV: 0.63773
# BEST F1SCORE -->  DEV: 0.62757
# TIME PER EPOCH: 12.461414508024852
# Some weights of the model checkpoint at xlm-roberta-base were not used when initializing XLMRobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'roberta.pooler.dense.bias', 'lm_head.dense.bias']
# - This IS expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['classifier.out_proj.bias', 'classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Training epoch: 1
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.9460113644599915
# DEV ACC: 0.5755208333333333
# DEV Precision: 0.42914920931445033
# DEV Recall: 0.44686326987548786
# DEV F1Score: 0.4077427037414921
# BEST ACCURACY -->  DEV: 0.57552
# BEST PRECISION -->  DEV: 0.42915
# BEST RECALL -->  DEV: 0.44686
# BEST F1SCORE -->  DEV: 0.40774
# TIME PER EPOCH: 12.444334312280018
#
# Training epoch: 2
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.8455772995948792
# DEV ACC: 0.6709449404761905
# DEV Precision: 0.547692036543485
# DEV Recall: 0.5522234294051936
# DEV F1Score: 0.5268415680480298
# BEST ACCURACY -->  DEV: 0.67094
# BEST PRECISION -->  DEV: 0.54769
# BEST RECALL -->  DEV: 0.55222
# BEST F1SCORE -->  DEV: 0.52684
# TIME PER EPOCH: 12.455428020159404
#
# Training epoch: 3
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.9061750173568726
# DEV ACC: 0.6873139880952381
# DEV Precision: 0.5717289579692139
# DEV Recall: 0.6038713583366112
# DEV F1Score: 0.5693617472042609
# BEST ACCURACY -->  DEV: 0.68731
# BEST PRECISION -->  DEV: 0.57173
# BEST RECALL -->  DEV: 0.60387
# BEST F1SCORE -->  DEV: 0.56936
# TIME PER EPOCH: 12.476616271336873
#
# Training epoch: 4
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.4685722291469574
# DEV ACC: 0.7085193452380952
# DEV Precision: 0.6216465782117042
# DEV Recall: 0.5945400540905847
# DEV F1Score: 0.5815503173317352
# BEST ACCURACY -->  DEV: 0.70852
# BEST PRECISION -->  DEV: 0.62165
# BEST RECALL -->  DEV: 0.60387
# BEST F1SCORE -->  DEV: 0.58155
# TIME PER EPOCH: 12.44145988225937
#
# Training epoch: 5
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.7945463061332703
# DEV ACC: 0.6999627976190476
# DEV Precision: 0.6000499624383554
# DEV Recall: 0.6056717162542847
# DEV F1Score: 0.5829702746581507
# BEST ACCURACY -->  DEV: 0.70852
# BEST PRECISION -->  DEV: 0.62165
# BEST RECALL -->  DEV: 0.60567
# BEST F1SCORE -->  DEV: 0.58297
# TIME PER EPOCH: 12.461372129122417
#
# Training epoch: 6
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.7280144095420837
# DEV ACC: 0.7057291666666667
# DEV Precision: 0.6200094044986723
# DEV Recall: 0.6140540650864487
# DEV F1Score: 0.5957475658247197
# BEST ACCURACY -->  DEV: 0.70852
# BEST PRECISION -->  DEV: 0.62165
# BEST RECALL -->  DEV: 0.61405
# BEST F1SCORE -->  DEV: 0.59575
# TIME PER EPOCH: 12.46884245077769
#
# Training epoch: 7
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.8734139800071716
# DEV ACC: 0.7062872023809524
# DEV Precision: 0.6198126477848528
# DEV Recall: 0.6246523540214455
# DEV F1Score: 0.6016262672539948
# BEST ACCURACY -->  DEV: 0.70852
# BEST PRECISION -->  DEV: 0.62165
# BEST RECALL -->  DEV: 0.62465
# BEST F1SCORE -->  DEV: 0.60163
# TIME PER EPOCH: 12.450354611873626
#
# Training epoch: 8
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 1.7421513795852661
# DEV ACC: 0.7217261904761905
# DEV Precision: 0.6554513610744263
# DEV Recall: 0.6213558266055775
# DEV F1Score: 0.6121055678559936
# BEST ACCURACY -->  DEV: 0.72173
# BEST PRECISION -->  DEV: 0.65545
# BEST RECALL -->  DEV: 0.62465
# BEST F1SCORE -->  DEV: 0.61211
# TIME PER EPOCH: 12.518251327673594
#
# Training epoch: 9
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 1.0408838987350464
# DEV ACC: 0.716703869047619
# DEV Precision: 0.6518366366643884
# DEV Recall: 0.6261670050335189
# DEV F1Score: 0.6160462989933626
# BEST ACCURACY -->  DEV: 0.72173
# BEST PRECISION -->  DEV: 0.65545
# BEST RECALL -->  DEV: 0.62617
# BEST F1SCORE -->  DEV: 0.61605
# TIME PER EPOCH: 12.437533684571584
#
# Training epoch: 10
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.819510817527771
# DEV ACC: 0.7183779761904762
# DEV Precision: 0.6517326462697703
# DEV Recall: 0.6362136236827677
# DEV F1Score: 0.6217562330162966
# BEST ACCURACY -->  DEV: 0.72173
# BEST PRECISION -->  DEV: 0.65545
# BEST RECALL -->  DEV: 0.63621
# BEST F1SCORE -->  DEV: 0.62176
# TIME PER EPOCH: 12.480761921405792
# Some weights of the model checkpoint at xlm-roberta-base were not used when initializing XLMRobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'roberta.pooler.dense.bias', 'lm_head.dense.bias']
# - This IS expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['classifier.out_proj.bias', 'classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Training epoch: 1
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 1.058260202407837
# DEV ACC: 0.5671502976190477
# DEV Precision: 0.38409360153811184
# DEV Recall: 0.4138545312808292
# DEV F1Score: 0.3772121514803522
# BEST ACCURACY -->  DEV: 0.56715
# BEST PRECISION -->  DEV: 0.38409
# BEST RECALL -->  DEV: 0.41385
# BEST F1SCORE -->  DEV: 0.37721
# TIME PER EPOCH: 12.463916007677714
#
# Training epoch: 2
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 1.1609196662902832
# DEV ACC: 0.6558779761904762
# DEV Precision: 0.5158571650082249
# DEV Recall: 0.5608404885655343
# DEV F1Score: 0.5232294489905637
# BEST ACCURACY -->  DEV: 0.65588
# BEST PRECISION -->  DEV: 0.51586
# BEST RECALL -->  DEV: 0.56084
# BEST F1SCORE -->  DEV: 0.52323
# TIME PER EPOCH: 12.466558237870535
#
# Training epoch: 3
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.8760468363761902
# DEV ACC: 0.6614583333333333
# DEV Precision: 0.5653165048377342
# DEV Recall: 0.6033587970444587
# DEV F1Score: 0.5608367656763502
# BEST ACCURACY -->  DEV: 0.66146
# BEST PRECISION -->  DEV: 0.56532
# BEST RECALL -->  DEV: 0.60336
# BEST F1SCORE -->  DEV: 0.56084
# TIME PER EPOCH: 12.512434669335683
#
# Training epoch: 4
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.537022054195404
# DEV ACC: 0.7023809523809524
# DEV Precision: 0.6342171102584083
# DEV Recall: 0.6084535817532142
# DEV F1Score: 0.5986393253492046
# BEST ACCURACY -->  DEV: 0.70238
# BEST PRECISION -->  DEV: 0.63422
# BEST RECALL -->  DEV: 0.60845
# BEST F1SCORE -->  DEV: 0.59864
# TIME PER EPOCH: 12.477626732985179
#
# Training epoch: 5
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.9892919659614563
# DEV ACC: 0.7126116071428571
# DEV Precision: 0.6400730108476955
# DEV Recall: 0.6087278556067256
# DEV F1Score: 0.6014190081939994
# BEST ACCURACY -->  DEV: 0.71261
# BEST PRECISION -->  DEV: 0.64007
# BEST RECALL -->  DEV: 0.60873
# BEST F1SCORE -->  DEV: 0.60142
# TIME PER EPOCH: 12.489057457447052
#
# Training epoch: 6
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.6472569704055786
# DEV ACC: 0.7178199404761905
# DEV Precision: 0.6455184461873633
# DEV Recall: 0.6274962057229649
# DEV F1Score: 0.6111668637654075
# BEST ACCURACY -->  DEV: 0.71782
# BEST PRECISION -->  DEV: 0.64552
# BEST RECALL -->  DEV: 0.6275
# BEST F1SCORE -->  DEV: 0.61117
# TIME PER EPOCH: 12.460737999280294
#
# Training epoch: 7
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.8156023621559143
# DEV ACC: 0.7271205357142857
# DEV Precision: 0.6614597360306531
# DEV Recall: 0.6288909058670088
# DEV F1Score: 0.6203434801348423
# BEST ACCURACY -->  DEV: 0.72712
# BEST PRECISION -->  DEV: 0.66146
# BEST RECALL -->  DEV: 0.62889
# BEST F1SCORE -->  DEV: 0.62034
# TIME PER EPOCH: 12.44799458583196
#
# Training epoch: 8
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.6247646808624268
# DEV ACC: 0.7113095238095238
# DEV Precision: 0.6484505624073639
# DEV Recall: 0.649802178462478
# DEV F1Score: 0.6275939589095446
# BEST ACCURACY -->  DEV: 0.72712
# BEST PRECISION -->  DEV: 0.66146
# BEST RECALL -->  DEV: 0.6498
# BEST F1SCORE -->  DEV: 0.62759
# TIME PER EPOCH: 12.593887150287628
#
# Training epoch: 9
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 0.939992368221283
# DEV ACC: 0.7191220238095238
# DEV Precision: 0.6467673645300039
# DEV Recall: 0.6462141738711494
# DEV F1Score: 0.6271855516365036
# BEST ACCURACY -->  DEV: 0.72712
# BEST PRECISION -->  DEV: 0.66146
# BEST RECALL -->  DEV: 0.6498
# BEST F1SCORE -->  DEV: 0.62759
# TIME PER EPOCH: 12.431549521287282
#
# Training epoch: 10
# FINSIHED BATCH: 19 of 497
# FINSIHED BATCH: 39 of 497
# FINSIHED BATCH: 59 of 497
# FINSIHED BATCH: 79 of 497
# FINSIHED BATCH: 99 of 497
# FINSIHED BATCH: 119 of 497
# FINSIHED BATCH: 139 of 497
# FINSIHED BATCH: 159 of 497
# FINSIHED BATCH: 179 of 497
# FINSIHED BATCH: 199 of 497
# FINSIHED BATCH: 219 of 497
# FINSIHED BATCH: 239 of 497
# FINSIHED BATCH: 259 of 497
# FINSIHED BATCH: 279 of 497
# FINSIHED BATCH: 299 of 497
# FINSIHED BATCH: 319 of 497
# FINSIHED BATCH: 339 of 497
# FINSIHED BATCH: 359 of 497
# FINSIHED BATCH: 379 of 497
# FINSIHED BATCH: 399 of 497
# FINSIHED BATCH: 419 of 497
# FINSIHED BATCH: 439 of 497
# FINSIHED BATCH: 459 of 497
# FINSIHED BATCH: 479 of 497
# Validation loss per 100 evaluation steps: 1.1016898155212402
# DEV ACC: 0.7291666666666667
# DEV Precision: 0.6626615154557715
# DEV Recall: 0.658351291977468
# DEV F1Score: 0.638579905944784
# BEST ACCURACY -->  DEV: 0.72917
# BEST PRECISION -->  DEV: 0.66266
# BEST RECALL -->  DEV: 0.65835
# BEST F1SCORE -->  DEV: 0.63858
# TIME PER EPOCH: 12.474111851056417

# %%
print(best_dev_acc)
# Out:
# 0.7291666666666667

# %%
print(best_epoch)
# Out:
# 9

# %%
print(best_dev_precision)
# Out:
# 0.6626615154557715

# %%
print(best_dev_recall)
# Out:
# 0.658351291977468

# %%
print(best_dev_f1score)
# Out:
# 0.638579905944784

# %%
print(overall_list_dev_acc)
# Out:
# [[0.5602678571428571, 0.6711309523809524, 0.6787574404761905, 0.7003348214285714, 0.7036830357142857, 0.7075892857142857, 0.712797619047619, 0.7122395833333333, 0.7180059523809524, 0.6975446428571429], [0.5892857142857143, 0.6276041666666667, 0.6850818452380952, 0.6943824404761905, 0.7157738095238095, 0.7146577380952381, 0.7202380952380952, 0.7239583333333333, 0.7222842261904762, 0.7241443452380952], [0.5872395833333333, 0.6568080357142857, 0.6923363095238095, 0.6899181547619048, 0.6867559523809524, 0.7235863095238095, 0.6994047619047619, 0.7248883928571429, 0.71875, 0.7131696428571429], [0.5755208333333333, 0.6709449404761905, 0.6873139880952381, 0.7085193452380952, 0.6999627976190476, 0.7057291666666667, 0.7062872023809524, 0.7217261904761905, 0.716703869047619, 0.7183779761904762], [0.5671502976190477, 0.6558779761904762, 0.6614583333333333, 0.7023809523809524, 0.7126116071428571, 0.7178199404761905, 0.7271205357142857, 0.7113095238095238, 0.7191220238095238, 0.7291666666666667]]

# %%
print(overall_list_dev_precision)
# Out:
# [[0.423917595208918, 0.537318718720926, 0.5566165362139212, 0.6109689178701784, 0.6033791895983336, 0.6541192973631608, 0.6473338724943725, 0.6510084269913644, 0.6458050223908111, 0.6324273489990403], [0.37170599409252114, 0.4991877773836807, 0.5972349879687197, 0.6108218750019944, 0.6508529634141332, 0.6396597712626642, 0.6685742718906972, 0.6729838671525271, 0.6722086649051002, 0.6545781272882113], [0.38842541751549114, 0.5284843203092178, 0.591749637903407, 0.5937699088959594, 0.6140315266709598, 0.641104758290876, 0.6418931659202143, 0.6384328496458087, 0.6442762969613989, 0.6509904666995003], [0.42914920931445033, 0.547692036543485, 0.5717289579692139, 0.6216465782117042, 0.6000499624383554, 0.6200094044986723, 0.6198126477848528, 0.6554513610744263, 0.6518366366643884, 0.6517326462697703], [0.38409360153811184, 0.5158571650082249, 0.5653165048377342, 0.6342171102584083, 0.6400730108476955, 0.6455184461873633, 0.6614597360306531, 0.6484505624073639, 0.6467673645300039, 0.6626615154557715]]

# %%
print(overall_list_dev_recall)
# Out:
# [[0.42837569962348804, 0.5497722758438426, 0.5985684236544266, 0.6264520374729144, 0.6173566542001415, 0.6325938324047568, 0.5962074819039381, 0.6343243369608915, 0.6408296759846129, 0.6560435226683914], [0.4516824787898842, 0.5746324335616959, 0.5572140595441957, 0.5927275079765683, 0.6267614482418843, 0.6208196314656399, 0.6387134167478179, 0.6383652448642013, 0.6571338998886267, 0.655148716246405], [0.4525252502086592, 0.5379968647071146, 0.5924198293099293, 0.6018509744024589, 0.6325617028571334, 0.6040460326260303, 0.636613650045345, 0.6266704645183127, 0.6318611286297735, 0.6377285313892456], [0.44686326987548786, 0.5522234294051936, 0.6038713583366112, 0.5945400540905847, 0.6056717162542847, 0.6140540650864487, 0.6246523540214455, 0.6213558266055775, 0.6261670050335189, 0.6362136236827677], [0.4138545312808292, 0.5608404885655343, 0.6033587970444587, 0.6084535817532142, 0.6087278556067256, 0.6274962057229649, 0.6288909058670088, 0.649802178462478, 0.6462141738711494, 0.658351291977468]]

# %%
print(overall_list_dev_f1score)
# Out:
# [[0.3921767143227927, 0.5183037645379232, 0.5611584083149738, 0.603868970060242, 0.5908997621961518, 0.6150544441225979, 0.592575380097978, 0.6196197512531738, 0.6225165615346369, 0.617849059712519], [0.3942743039412897, 0.5094086441532287, 0.5488014466920653, 0.579845857535442, 0.6128457720685444, 0.6091357676817312, 0.6303482252717558, 0.6302327549245658, 0.6443531147748602, 0.6327513175464891], [0.4023896624540371, 0.5138364711306104, 0.5654180624733283, 0.5792416936438621, 0.5972089383165257, 0.6014151397896893, 0.6172924239350396, 0.6147462683916957, 0.6173743845874636, 0.6275725460616127], [0.4077427037414921, 0.5268415680480298, 0.5693617472042609, 0.5815503173317352, 0.5829702746581507, 0.5957475658247197, 0.6016262672539948, 0.6121055678559936, 0.6160462989933626, 0.6217562330162966], [0.3772121514803522, 0.5232294489905637, 0.5608367656763502, 0.5986393253492046, 0.6014190081939994, 0.6111668637654075, 0.6203434801348423, 0.6275939589095446, 0.6271855516365036, 0.638579905944784]]

# %%
#The best model is 0
