# %%
import pandas as pd
import numpy as np
import torch
from torch import cuda
from torch.utils.data import Dataset, DataLoader
from transformers import pipeline
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from sklearn.metrics import accuracy_score, classification_report, precision_score, recall_score, f1_score
from load_data import initialize_data
from reading_datasets import read_task
from labels_to_ids import labels_to_ids_tam
import time
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
def train(epoch, train_loader, model, optimizer, device, grad_step = 1, max_grad_norm = 10):
    tr_loss, tr_accuracy = 0, 0
    tr_precision, tr_recall = 0, 0
    tr_f1score = 0
    nb_tr_examples, nb_tr_steps = 0, 0
    tr_preds, tr_labels = [], []
    # put model in training mode
    model.train()
    optimizer.zero_grad()
    
    for idx, batch in enumerate(train_loader):
        ids = batch['input_ids'].to(device, dtype = torch.long)
        mask = batch['attention_mask'].to(device, dtype = torch.long)
        labels = batch['labels'].to(device, dtype = torch.long)

        if (idx + 1) % 20 == 0:
            print('FINSIHED BATCH:', idx, 'of', len(train_loader))

        #loss, tr_logits = model(input_ids=ids, attention_mask=mask, labels=labels)
        output = model(input_ids=ids, attention_mask=mask, labels=labels)
        tr_loss += output[0]

        nb_tr_steps += 1
        nb_tr_examples += labels.size(0)
           
        # compute training accuracy
        flattened_targets = labels.view(-1) # shape (batch_size * seq_len,)
        active_logits = output[1].view(-1, model.num_labels) # shape (batch_size * seq_len, num_labels)
        flattened_predictions = torch.argmax(active_logits, axis=1) # shape (batch_size * seq_len,)
        
        # only compute accuracy at active labels
        active_accuracy = labels.view(-1) != -100 # shape (batch_size, seq_len)
        #active_labels = torch.where(active_accuracy, labels.view(-1), torch.tensor(-100).type_as(labels))
        
        labels = torch.masked_select(flattened_targets, active_accuracy)
        predictions = torch.masked_select(flattened_predictions, active_accuracy)

        tr_labels.extend(labels)
        tr_preds.extend(predictions)

        tmp_tr_accuracy = accuracy_score(labels.cpu().numpy(), predictions.cpu().numpy())
        tr_accuracy += tmp_tr_accuracy
        
        # Compute Precision
        tmp_tr_precision = precision_score(labels.cpu().numpy(), predictions.cpu().numpy(), average = 'macro', zero_division=0 )
        tr_precision += tmp_tr_precision
        
        # Compute Recall
        tmp_tr_recall = recall_score(labels.cpu().numpy(), predictions.cpu().numpy(), average = 'macro', zero_division=0)
        tr_recall += tmp_tr_recall
        
        # Compute f1score
        tmp_tr_f1score = f1_score(labels.cpu().numpy(), predictions.cpu().numpy(), average= 'macro', zero_division=0)
        tr_f1score += tmp_tr_f1score
    
        # gradient clipping
        torch.nn.utils.clip_grad_norm_(
            parameters=model.parameters(), max_norm=max_grad_norm
        )
        
        # backward pass
        output['loss'].backward()
        if (idx + 1) % grad_step == 0:
            optimizer.step()
            optimizer.zero_grad()

    epoch_loss = tr_loss / nb_tr_steps
    tr_accuracy = tr_accuracy / nb_tr_steps
    tr_precision = tr_precision / nb_tr_steps
    tr_recall = tr_recall / nb_tr_steps
    tr_f1score= tr_f1score / nb_tr_steps
    #print(f"Training loss epoch: {epoch_loss}")
    #print(f"Training accuracy epoch: {tr_accuracy}")

    return model

# %%
def testing(model, testing_loader, labels_to_ids, device):
    # put model in evaluation mode
    model.eval()
    
    eval_loss, eval_accuracy = 0, 0
    eval_precision, eval_recall = 0, 0
    eval_f1score = 0
    nb_eval_examples, nb_eval_steps = 0, 0
    eval_preds, eval_labels = [], []
     
    
    ids_to_labels = dict((v,k) for k,v in labels_to_ids.items())

    with torch.no_grad():
        for idx, batch in enumerate(testing_loader):
            
            ids = batch['input_ids'].to(device, dtype = torch.long)
            mask = batch['attention_mask'].to(device, dtype = torch.long)
            labels = batch['labels'].to(device, dtype = torch.long)
            
            #loss, eval_logits = model(input_ids=ids, attention_mask=mask, labels=labels)
            output = model(input_ids=ids, attention_mask=mask, labels=labels)

            eval_loss += output['loss'].item()

            nb_eval_steps += 1
            nb_eval_examples += labels.size(0)
        
            if idx % 100==0:
                loss_step = eval_loss/nb_eval_steps
                print(f"Validation loss per 100 evaluation steps: {loss_step}")
              
            # compute evaluation accuracy
            flattened_targets = labels.view(-1) # shape (batch_size * seq_len,)
            active_logits = output[1].view(-1, model.num_labels) # shape (batch_size * seq_len, num_labels)
            flattened_predictions = torch.argmax(active_logits, axis=1) # shape (batch_size * seq_len,)
            
            # only compute accuracy at active labels
            active_accuracy = labels.view(-1) != -100 # shape (batch_size, seq_len)
        
            labels = torch.masked_select(flattened_targets, active_accuracy)
            predictions = torch.masked_select(flattened_predictions, active_accuracy)
            
            eval_labels.extend(labels)
            eval_preds.extend(predictions)
            
            tmp_eval_accuracy = accuracy_score(labels.cpu().numpy(), predictions.cpu().numpy())
            eval_accuracy += tmp_eval_accuracy
            
            # Compute Precision
            tmp_eval_precision = precision_score(labels.cpu().numpy(), predictions.cpu().numpy(), average = 'macro', zero_division=0)
            eval_precision += tmp_eval_precision
            
            # Compute Recall
            tmp_eval_recall = recall_score(labels.cpu().numpy(), predictions.cpu().numpy(), average = 'macro', zero_division=0)
            eval_recall += tmp_eval_recall
            
            # Compute f1score
            tmp_eval_f1score = f1_score(labels.cpu().numpy(), predictions.cpu().numpy(), average='macro', zero_division=0)
            eval_f1score += tmp_eval_f1score

    labels = [ids_to_labels[id.item()] for id in eval_labels]
    predictions = [ids_to_labels[id.item()] for id in eval_preds]
    
    eval_loss = eval_loss / nb_eval_steps
    eval_accuracy = eval_accuracy / nb_eval_steps
    eval_precision = eval_precision / nb_eval_steps
    eval_recall = eval_recall / nb_eval_steps
    eval_f1score = eval_f1score / nb_eval_steps
    #print(f"Validation Loss: {eval_loss}")
    #print(f"Validation Accuracy: {eval_accuracy}")

    return labels, predictions, eval_accuracy, eval_precision, eval_recall, eval_f1score

# %%
def main(n_epochs, model_name, model_save_flag, model_save_location, model_load_flag, model_load_location):
    #Initialization training parameters
    max_len = 256
    batch_size = 32
    grad_step = 1
    learning_rate = 1e-05
    initialization_input = (max_len, batch_size)

    #Reading datasets and initializing data loaders
    dataset_location = '../datasets/task_a/'

    train_data = read_task(dataset_location , split = 'tam_train_negative_augmented')
    dev_data = read_task(dataset_location , split = 'tam_sentiment_dev')
    #test_data = read_task(dataset_location , split = 'dev')#load test set
    labels_to_ids = labels_to_ids_tam
    #input_data = (train_data, dev_data, labels_to_ids)

    #Define tokenizer, model and optimizer
    device = 'cuda' if cuda.is_available() else 'cpu' #save the processing time
    if model_load_flag:
        tokenizer = AutoTokenizer.from_pretrained(model_load_location)
        model = AutoModelForSequenceClassification.from_pretrained(model_load_location)
    else: 
        tokenizer =  AutoTokenizer.from_pretrained(model_name, add_prefix_space=True)
        model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=len(labels_to_ids))
    optimizer = torch.optim.Adam(params=model.parameters(), lr=learning_rate)
    model.to(device)

    #Get dataloaders
    train_loader = initialize_data(tokenizer, initialization_input, train_data, labels_to_ids, shuffle = True)
    dev_loader = initialize_data(tokenizer, initialization_input, dev_data, labels_to_ids, shuffle = True)
    #test_loader = initialize_data(tokenizer, initialization_input, test_data, labels_to_ids, shuffle = True)#create test loader

    best_dev_acc = 0
    best_test_acc = 0
    best_dev_precision = 0
    best_test_precision = 0
    best_dev_recall = 0
    best_test_recall = 0
    best_dev_f1score = 0
    best_test_f1score = 0
    best_epoch = -1
    
    list_dev_acc = [] 
    list_test_acc = []  
    list_dev_precision = []  
    list_test_precision  = []  
    list_dev_recall = []  
    list_test_recall = []  
    list_dev_f1score = []  
    list_test_f1score = []
    
    for epoch in range(n_epochs):
        start = time.time()
        print(f"Training epoch: {epoch + 1}")

        #train model
        if not model_load_flag:
            model = train(epoch, train_loader, model, optimizer, device, grad_step)
        
        #testing and logging
        labels_dev, predictions_dev, dev_accuracy, dev_precision, dev_recall, dev_f1score = testing(model, dev_loader, labels_to_ids, device)
        print('DEV ACC:', dev_accuracy)
        print('DEV Precision:' , dev_precision)
        print('DEV Recall:' , dev_recall)
        print('DEV F1Score:' , dev_f1score)
        
        list_dev_acc.append(dev_accuracy)     
        list_dev_precision.append(dev_precision)   
        list_dev_recall.append(dev_recall)  
        list_dev_f1score.append(dev_f1score)  
        
        
        #labels_test, predictions_test, test_accuracy, test_precision, test_recall, test_f1score = testing(model, test_loader, labels_to_ids, device)
        #print('TEST ACC:', test_accuracy)
        #print('TEST Precision:' , test_precision)
        #print('TEST Recall:' , test_recall)
        #print('TEST F1Score:' , test_f1score)
        
        #list_test_acc.append(test_accuracy) 
        #list_test_precision.append(test_precision)  
        #list_test_recall.append(test_recall)
        #list_test_f1score.append(test_f1score) 

        #saving model
        if dev_accuracy > best_dev_acc:
            best_dev_acc = dev_accuracy
            #best_test_acc = test_accuracy
        if dev_precision > best_dev_precision:
            best_dev_precision = dev_precision
            #best_test_precision = test_precision
        if dev_recall > best_dev_recall:
            best_dev_recall = dev_recall
            #best_test_recall = test_recall
        if dev_f1score > best_dev_f1score:
            best_dev_f1score = dev_f1score
            #best_test_f1score = test_f1score
            best_epoch = epoch
            
            if model_save_flag:
                os.makedirs(model_save_location, exist_ok=True)
                tokenizer.save_pretrained(model_save_location)
                model.save_pretrained(model_save_location)

        now = time.time()
        print('BEST ACCURACY --> ', 'DEV:', round(best_dev_acc, 5))
        print('BEST PRECISION --> ', 'DEV:', round(best_dev_precision, 5))
        print('BEST RECALL --> ', 'DEV:', round(best_dev_recall, 5))
        print('BEST F1SCORE --> ', 'DEV:', round(best_dev_f1score, 5))
        print('TIME PER EPOCH:', (now-start)/60 )
        print()

    return best_dev_acc, best_test_acc, best_epoch, best_dev_precision, best_test_precision, best_dev_recall, best_test_recall, best_dev_f1score, best_test_f1score, list_dev_acc, list_test_acc, list_dev_precision, list_test_precision, list_dev_recall, list_test_recall, list_dev_f1score, list_test_f1score

# %%
if __name__ == '__main__':
    n_epochs = 10
    models = ['bert-base-multilingual-uncased']
    
    #model saving parameters
    model_save_flag = True
    model_load_flag = False
    
    overall_list_dev_acc = [] 
    overall_list_test_acc = []    
    overall_list_dev_precision = []  
    overall_list_test_precision  = []  
    overall_list_dev_recall = []  
    overall_list_test_recall = []  
    overall_list_dev_f1score = []  
    overall_list_test_f1score = [] 
    
    for i in range(5):
        
        for model_name in models:

            model_save_location = 'saved_models/' + model_name + 'Tamil' + 'Augmented' +str(i)
            model_load_location = None

            best_dev_acc, best_test_acc, best_epoch, best_dev_precision, best_test_precision, best_dev_recall, best_test_recall, best_dev_f1score, best_test_f1score, list_dev_acc, list_test_acc, list_dev_precision, list_test_precision, list_dev_recall, list_test_recall, list_dev_f1score, list_test_f1score = main(n_epochs, model_name, model_save_flag, model_save_location, model_load_flag, model_load_location)
            
            overall_list_dev_acc.append(list_dev_acc) 
            overall_list_test_acc.append(list_test_acc) 
            overall_list_dev_precision.append(list_dev_precision)  
            overall_list_test_precision.append(list_test_precision) 
            overall_list_dev_recall.append(list_dev_recall)  
            overall_list_test_recall.append(list_test_recall)  
            overall_list_dev_f1score.append(list_dev_f1score)  
            overall_list_test_f1score.append(list_test_f1score)
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-uncased were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Training epoch: 1
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.0417486429214478
# Validation loss per 100 evaluation steps: 1.0047988159821766
# DEV ACC: 0.6189322270471465
# DEV Precision: 0.4399324180935694
# DEV Recall: 0.41428885100182117
# DEV F1Score: 0.40120773822174455
# BEST ACCURACY -->  DEV: 0.61893
# BEST PRECISION -->  DEV: 0.43993
# BEST RECALL -->  DEV: 0.41429
# BEST F1SCORE -->  DEV: 0.40121
# TIME PER EPOCH: 27.601120058695475
#
# Training epoch: 2
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 0.5393351912498474
# Validation loss per 100 evaluation steps: 0.970373827041966
# DEV ACC: 0.6265702543424317
# DEV Precision: 0.44045263858254946
# DEV Recall: 0.4174027529530227
# DEV F1Score: 0.39580276492415484
# BEST ACCURACY -->  DEV: 0.62657
# BEST PRECISION -->  DEV: 0.44045
# BEST RECALL -->  DEV: 0.4174
# BEST F1SCORE -->  DEV: 0.40121
# TIME PER EPOCH: 28.153889179229736
#
# Training epoch: 3
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.4082599878311157
# Validation loss per 100 evaluation steps: 0.9531541508023101
# DEV ACC: 0.6450062034739453
# DEV Precision: 0.48873305369381936
# DEV Recall: 0.448701850229139
# DEV F1Score: 0.44159994641343997
# BEST ACCURACY -->  DEV: 0.64501
# BEST PRECISION -->  DEV: 0.48873
# BEST RECALL -->  DEV: 0.4487
# BEST F1SCORE -->  DEV: 0.4416
# TIME PER EPOCH: 28.017267819245657
#
# Training epoch: 4
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.0012845993041992
# Validation loss per 100 evaluation steps: 0.9896065994064407
# DEV ACC: 0.6464019851116626
# DEV Precision: 0.5009650393647178
# DEV Recall: 0.4753776549822689
# DEV F1Score: 0.4574204319275205
# BEST ACCURACY -->  DEV: 0.6464
# BEST PRECISION -->  DEV: 0.50097
# BEST RECALL -->  DEV: 0.47538
# BEST F1SCORE -->  DEV: 0.45742
# TIME PER EPOCH: 27.607181775569916
#
# Training epoch: 5
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 0.669486939907074
# Validation loss per 100 evaluation steps: 1.020151942083151
# DEV ACC: 0.6329675868486353
# DEV Precision: 0.4786376102210104
# DEV Recall: 0.4613407535268272
# DEV F1Score: 0.4437649772290651
# BEST ACCURACY -->  DEV: 0.6464
# BEST PRECISION -->  DEV: 0.50097
# BEST RECALL -->  DEV: 0.47538
# BEST F1SCORE -->  DEV: 0.45742
# TIME PER EPOCH: 28.16996355454127
#
# Training epoch: 6
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.1188275814056396
# Validation loss per 100 evaluation steps: 1.093066131124402
# DEV ACC: 0.625814205955335
# DEV Precision: 0.48506165602812223
# DEV Recall: 0.45819591692787415
# DEV F1Score: 0.44571648821051674
# BEST ACCURACY -->  DEV: 0.6464
# BEST PRECISION -->  DEV: 0.50097
# BEST RECALL -->  DEV: 0.47538
# BEST F1SCORE -->  DEV: 0.45742
# TIME PER EPOCH: 27.891270784536996
#
# Training epoch: 7
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.1758145093917847
# Validation loss per 100 evaluation steps: 1.1917761157054712
# DEV ACC: 0.6247285980148883
# DEV Precision: 0.47092842627348663
# DEV Recall: 0.4682642640065486
# DEV F1Score: 0.4431002986117413
# BEST ACCURACY -->  DEV: 0.6464
# BEST PRECISION -->  DEV: 0.50097
# BEST RECALL -->  DEV: 0.47538
# BEST F1SCORE -->  DEV: 0.45742
# TIME PER EPOCH: 29.043948177496592
#
# Training epoch: 8
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 0.9730567336082458
# Validation loss per 100 evaluation steps: 1.2692638924806425
# DEV ACC: 0.6222859801488834
# DEV Precision: 0.47266200607650327
# DEV Recall: 0.4457323448014963
# DEV F1Score: 0.43758391409989245
# BEST ACCURACY -->  DEV: 0.6464
# BEST PRECISION -->  DEV: 0.50097
# BEST RECALL -->  DEV: 0.47538
# BEST F1SCORE -->  DEV: 0.45742
# TIME PER EPOCH: 28.044196490446726
#
# Training epoch: 9
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 0.6553303003311157
# Validation loss per 100 evaluation steps: 1.478727606263491
# DEV ACC: 0.6135041873449131
# DEV Precision: 0.46496902704530124
# DEV Recall: 0.45109843643489894
# DEV F1Score: 0.4324113443554988
# BEST ACCURACY -->  DEV: 0.6464
# BEST PRECISION -->  DEV: 0.50097
# BEST RECALL -->  DEV: 0.47538
# BEST F1SCORE -->  DEV: 0.45742
# TIME PER EPOCH: 28.35198756456375
#
# Training epoch: 10
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 2.0790133476257324
# Validation loss per 100 evaluation steps: 1.5127115467987438
# DEV ACC: 0.6078047456575683
# DEV Precision: 0.4674737551064616
# DEV Recall: 0.4604459778371154
# DEV F1Score: 0.4388087925545645
# BEST ACCURACY -->  DEV: 0.6464
# BEST PRECISION -->  DEV: 0.50097
# BEST RECALL -->  DEV: 0.47538
# BEST F1SCORE -->  DEV: 0.45742
# TIME PER EPOCH: 28.75606336990992
# Some weights of the model checkpoint at bert-base-multilingual-uncased were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Training epoch: 1
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 0.8458038568496704
# Validation loss per 100 evaluation steps: 0.9914006337080852
# DEV ACC: 0.6282374379652605
# DEV Precision: 0.47161140758488845
# DEV Recall: 0.41718391662075127
# DEV F1Score: 0.4060818685221501
# BEST ACCURACY -->  DEV: 0.62824
# BEST PRECISION -->  DEV: 0.47161
# BEST RECALL -->  DEV: 0.41718
# BEST F1SCORE -->  DEV: 0.40608
# TIME PER EPOCH: 29.149911590417226
#
# Training epoch: 2
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.014150857925415
# Validation loss per 100 evaluation steps: 0.9713549360190288
# DEV ACC: 0.6227124689826303
# DEV Precision: 0.4450132544296462
# DEV Recall: 0.45274495094192146
# DEV F1Score: 0.4187959226858566
# BEST ACCURACY -->  DEV: 0.62824
# BEST PRECISION -->  DEV: 0.47161
# BEST RECALL -->  DEV: 0.45274
# BEST F1SCORE -->  DEV: 0.4188
# TIME PER EPOCH: 27.536670152346293
#
# Training epoch: 3
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 0.7221388816833496
# Validation loss per 100 evaluation steps: 0.9662973172593825
# DEV ACC: 0.641245347394541
# DEV Precision: 0.4940805362679943
# DEV Recall: 0.45083114616583136
# DEV F1Score: 0.42940351871771515
# BEST ACCURACY -->  DEV: 0.64125
# BEST PRECISION -->  DEV: 0.49408
# BEST RECALL -->  DEV: 0.45274
# BEST F1SCORE -->  DEV: 0.4294
# TIME PER EPOCH: 27.633454279104868
#
# Training epoch: 4
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.0512773990631104
# Validation loss per 100 evaluation steps: 0.9812534601971654
# DEV ACC: 0.6393649193548387
# DEV Precision: 0.47994578175871416
# DEV Recall: 0.45258402060578967
# DEV F1Score: 0.43730799665646586
# BEST ACCURACY -->  DEV: 0.64125
# BEST PRECISION -->  DEV: 0.49408
# BEST RECALL -->  DEV: 0.45274
# BEST F1SCORE -->  DEV: 0.43731
# TIME PER EPOCH: 28.342498338222505
#
# Training epoch: 5
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.0180459022521973
# Validation loss per 100 evaluation steps: 1.056452182850035
# DEV ACC: 0.6086577233250621
# DEV Precision: 0.4639471200781316
# DEV Recall: 0.46764961784624093
# DEV F1Score: 0.4387103857200681
# BEST ACCURACY -->  DEV: 0.64125
# BEST PRECISION -->  DEV: 0.49408
# BEST RECALL -->  DEV: 0.46765
# BEST F1SCORE -->  DEV: 0.43871
# TIME PER EPOCH: 29.08834911584854
#
# Training epoch: 6
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.0662572383880615
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.4396287202835083
# Validation loss per 100 evaluation steps: 1.2135465269041534
# DEV ACC: 0.6122634925558313
# DEV Precision: 0.47118616160903987
# DEV Recall: 0.45199217731214925
# DEV F1Score: 0.4358603422996139
# BEST ACCURACY -->  DEV: 0.64125
# BEST PRECISION -->  DEV: 0.49408
# BEST RECALL -->  DEV: 0.46765
# BEST F1SCORE -->  DEV: 0.43871
# TIME PER EPOCH: 28.290040214856464
#
# Training epoch: 8
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 0.7863233089447021
# Validation loss per 100 evaluation steps: 1.3546197314073545
# DEV ACC: 0.6131940136476427
# DEV Precision: 0.4760485187401096
# DEV Recall: 0.4535963530267742
# DEV F1Score: 0.4396809750053562
# BEST ACCURACY -->  DEV: 0.64125
# BEST PRECISION -->  DEV: 0.49408
# BEST RECALL -->  DEV: 0.46765
# BEST F1SCORE -->  DEV: 0.43968
# TIME PER EPOCH: 28.245805128415427
#
# Training epoch: 9
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 0.8021594285964966
# Validation loss per 100 evaluation steps: 1.4502713556336884
# DEV ACC: 0.6000504032258065
# DEV Precision: 0.4693149131137603
# DEV Recall: 0.4630231226213053
# DEV F1Score: 0.44162030262309604
# BEST ACCURACY -->  DEV: 0.64125
# BEST PRECISION -->  DEV: 0.49408
# BEST RECALL -->  DEV: 0.46765
# BEST F1SCORE -->  DEV: 0.44162
# TIME PER EPOCH: 27.30345685482025
#
# Training epoch: 10
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 0.9824196696281433
# Validation loss per 100 evaluation steps: 1.554549761927954
# DEV ACC: 0.5810716501240695
# DEV Precision: 0.4564688627446618
# DEV Recall: 0.45705778147094905
# DEV F1Score: 0.4345397700539614
# BEST ACCURACY -->  DEV: 0.64125
# BEST PRECISION -->  DEV: 0.49408
# BEST RECALL -->  DEV: 0.46765
# BEST F1SCORE -->  DEV: 0.44162
# TIME PER EPOCH: 29.316013975938162
# Some weights of the model checkpoint at bert-base-multilingual-uncased were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Training epoch: 1
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 0.7411209344863892
# Validation loss per 100 evaluation steps: 1.0796271574379195
# DEV ACC: 0.5945448200992556
# DEV Precision: 0.4365858532381963
# DEV Recall: 0.4403509441781415
# DEV F1Score: 0.3951167578721958
# BEST ACCURACY -->  DEV: 0.59454
# BEST PRECISION -->  DEV: 0.43659
# BEST RECALL -->  DEV: 0.44035
# BEST F1SCORE -->  DEV: 0.39512
# TIME PER EPOCH: 28.006159230073294
#
# Training epoch: 2
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# ...
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.2936407327651978
# Validation loss per 100 evaluation steps: 1.4108392460511463
# DEV ACC: 0.6059824751861042
# DEV Precision: 0.46814191435118124
# DEV Recall: 0.45392516077825557
# DEV F1Score: 0.43446369716332506
# BEST ACCURACY -->  DEV: 0.64516
# BEST PRECISION -->  DEV: 0.49067
# BEST RECALL -->  DEV: 0.48188
# BEST F1SCORE -->  DEV: 0.45634
# TIME PER EPOCH: 28.08151782353719
#
# Training epoch: 10
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 2.3347768783569336
# Validation loss per 100 evaluation steps: 1.5605088366140234
# DEV ACC: 0.6101310483870968
# DEV Precision: 0.4668703819293725
# DEV Recall: 0.4588030778162424
# DEV F1Score: 0.4421305752061435
# BEST ACCURACY -->  DEV: 0.64516
# BEST PRECISION -->  DEV: 0.49067
# BEST RECALL -->  DEV: 0.48188
# BEST F1SCORE -->  DEV: 0.45634
# TIME PER EPOCH: 28.201990036169686
# Some weights of the model checkpoint at bert-base-multilingual-uncased were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Training epoch: 1
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 0.7028924226760864
# Validation loss per 100 evaluation steps: 0.9890949914951136
# DEV ACC: 0.6159855769230769
# DEV Precision: 0.43504798604631173
# DEV Recall: 0.4543614371594778
# DEV F1Score: 0.42038655358068405
# BEST ACCURACY -->  DEV: 0.61599
# BEST PRECISION -->  DEV: 0.43505
# BEST RECALL -->  DEV: 0.45436
# BEST F1SCORE -->  DEV: 0.42039
# TIME PER EPOCH: 28.23527813355128
#
# Training epoch: 2
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.3997560739517212
# Validation loss per 100 evaluation steps: 0.9423723061486046
# DEV ACC: 0.6384537841191067
# DEV Precision: 0.47485895988418314
# DEV Recall: 0.47200530748412056
# DEV F1Score: 0.4442278866976046
# BEST ACCURACY -->  DEV: 0.63845
# BEST PRECISION -->  DEV: 0.47486
# BEST RECALL -->  DEV: 0.47201
# BEST F1SCORE -->  DEV: 0.44423
# TIME PER EPOCH: 28.663323974609376
#
# Training epoch: 3
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 0.8209524750709534
# Validation loss per 100 evaluation steps: 0.9453923501590691
# DEV ACC: 0.6360111662531017
# DEV Precision: 0.48279204298416173
# DEV Recall: 0.46916741811248547
# DEV F1Score: 0.4436480917822955
# BEST ACCURACY -->  DEV: 0.63845
# BEST PRECISION -->  DEV: 0.48279
# BEST RECALL -->  DEV: 0.47201
# BEST F1SCORE -->  DEV: 0.44423
# TIME PER EPOCH: 28.703423285484313
#
# Training epoch: 4
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 0.6458730101585388
# Validation loss per 100 evaluation steps: 0.9931234085913931
# DEV ACC: 0.6147061104218362
# DEV Precision: 0.48352068196398623
# DEV Recall: 0.4919592480054063
# DEV F1Score: 0.4622863204789358
# BEST ACCURACY -->  DEV: 0.63845
# BEST PRECISION -->  DEV: 0.48352
# BEST RECALL -->  DEV: 0.49196
# BEST F1SCORE -->  DEV: 0.46229
# TIME PER EPOCH: 28.06798930565516
#
# Training epoch: 5
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218
# FINSIHED BATCH: 939 of 1218
# FINSIHED BATCH: 959 of 1218
# FINSIHED BATCH: 979 of 1218
# FINSIHED BATCH: 999 of 1218
# FINSIHED BATCH: 1019 of 1218
# FINSIHED BATCH: 1039 of 1218
# FINSIHED BATCH: 1059 of 1218
# FINSIHED BATCH: 1079 of 1218
# FINSIHED BATCH: 1099 of 1218
# FINSIHED BATCH: 1119 of 1218
# FINSIHED BATCH: 1139 of 1218
# FINSIHED BATCH: 1159 of 1218
# FINSIHED BATCH: 1179 of 1218
# FINSIHED BATCH: 1199 of 1218
# Validation loss per 100 evaluation steps: 1.0417393445968628
# Validation loss per 100 evaluation steps: 1.0099847104289743
# DEV ACC: 0.6402178970223324
# DEV Precision: 0.5002900030574043
# DEV Recall: 0.45345829377583124
# DEV F1Score: 0.4475041069197446
# BEST ACCURACY -->  DEV: 0.64022
# BEST PRECISION -->  DEV: 0.50029
# BEST RECALL -->  DEV: 0.49196
# BEST F1SCORE -->  DEV: 0.46229
# TIME PER EPOCH: 28.136528074741364
#
# Training epoch: 6
# FINSIHED BATCH: 19 of 1218
# FINSIHED BATCH: 39 of 1218
# FINSIHED BATCH: 59 of 1218
# FINSIHED BATCH: 79 of 1218
# FINSIHED BATCH: 99 of 1218
# FINSIHED BATCH: 119 of 1218
# FINSIHED BATCH: 139 of 1218
# FINSIHED BATCH: 159 of 1218
# FINSIHED BATCH: 179 of 1218
# FINSIHED BATCH: 199 of 1218
# FINSIHED BATCH: 219 of 1218
# FINSIHED BATCH: 239 of 1218
# FINSIHED BATCH: 259 of 1218
# FINSIHED BATCH: 279 of 1218
# FINSIHED BATCH: 299 of 1218
# FINSIHED BATCH: 319 of 1218
# FINSIHED BATCH: 339 of 1218
# FINSIHED BATCH: 359 of 1218
# FINSIHED BATCH: 379 of 1218
# FINSIHED BATCH: 399 of 1218
# FINSIHED BATCH: 419 of 1218
# FINSIHED BATCH: 439 of 1218
# FINSIHED BATCH: 459 of 1218
# FINSIHED BATCH: 479 of 1218
# FINSIHED BATCH: 499 of 1218
# FINSIHED BATCH: 519 of 1218
# FINSIHED BATCH: 539 of 1218
# FINSIHED BATCH: 559 of 1218
# FINSIHED BATCH: 579 of 1218
# FINSIHED BATCH: 599 of 1218
# FINSIHED BATCH: 619 of 1218
# FINSIHED BATCH: 639 of 1218
# FINSIHED BATCH: 659 of 1218
# FINSIHED BATCH: 679 of 1218
# FINSIHED BATCH: 699 of 1218
# FINSIHED BATCH: 719 of 1218
# FINSIHED BATCH: 739 of 1218
# FINSIHED BATCH: 759 of 1218
# FINSIHED BATCH: 779 of 1218
# FINSIHED BATCH: 799 of 1218
# FINSIHED BATCH: 819 of 1218
# FINSIHED BATCH: 839 of 1218
# FINSIHED BATCH: 859 of 1218
# FINSIHED BATCH: 879 of 1218
# FINSIHED BATCH: 899 of 1218
# FINSIHED BATCH: 919 of 1218

# %%
print(best_dev_acc)

# %%
print(best_epoch)

# %%
print(best_dev_precision)

# %%
print(best_dev_recall)

# %%
print(best_dev_f1score)

# %%
print(overall_list_dev_acc)

# %%
print(overall_list_dev_precision)

# %%
print(overall_list_dev_recall)

# %%
print(overall_list_dev_f1score)

# %%
#The best model is 3
